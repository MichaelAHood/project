# %%
from bs4 import BeautifulSoup as BS

# %%
h = '''

<!DOCTYPE html><html itemscope="" itemtype="http://schema.org/Organization" class="no-js zsg-theme-modernized" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml" >
<head>
<meta http-equiv="x-dns-prefetch-control" content="on"/><link rel="dns-prefetch" href="http://fonts.googleapis.com"/><link rel="dns-prefetch" href="http://photos1.zillowstatic.com"/><link rel="dns-prefetch" href="http://photos2.zillowstatic.com"/><link rel="dns-prefetch" href="http://photos3.zillowstatic.com"/><meta charset="utf-8"/><title>16312 SE 48th St, Bellevue, WA 98006  | Zillow</title><meta name="description" content="Zillow has 15 homes for sale. View listing photos, review sales history, and use our detailed real estate filters to find the perfect place."></meta><meta name="author" content="Zillow, Inc."/><meta name="Copyright" content="Copyright (c) 2006-2014 Zillow, Inc."/><script>var UI_INIT_AT = Date.now ? Date.now() : +(new Date());</script><link href="http://www.zillowstatic.com/static-zsg/13bacaa/static-zsg/zsg/zsg-core.css" type="text/css" rel="stylesheet" media="all"/><link href="http://www.zillowstatic.com/static-zsg/13bacaa/static-zsg/zsg/zsg-opt.css" type="text/css" rel="stylesheet" media="all"/><link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,700&subset=latin" rel="stylesheet" type="text/css"/><link href="http://www.zillowstatic.com/vstatic/34794f0/static/css/z-pages/hdp.css" type="text/css" rel="stylesheet" media="all"/><link rel="stylesheet" media="all" href="http://www.zillowstatic.com/c/34794f0/lib?css/z-modules/top-nav.css&amp;css/z-modules/nav-hoverable.css&amp;css/z-modules/top-nav-wide.css&amp;css/z-modules/header.css&amp;css/z-modules/header-wide.css&amp;css/z-modules/sub-nav-wide.css&amp;css/z-modules/lightbox-blocks.css&amp;css/z-modules/signature-refactor.css&amp;css/z-modules/contact-form-template-refactor.css&amp;css/z-modules/pal-signature.css&amp;css/z-modules/gallery-upsell.css&amp;css/z-modules/hdp-carousel-ad-upsell.css&amp;css/z-modules/hdp-component-prop-notes.css&amp;css/z-themes/desktop-hdp-collapsed.css&amp;css/z-modules/z-comps-entry-point.css&amp;css/z-modules/z-comps-price-graph.css&amp;css/z-modules/zss-sel-metrics-widget.css&amp;css/z-modules/schools-nearby-schools.css" type="text/css"></link><link rel="stylesheet" media="all" href="http://www.zillowstatic.com/c/static-search/0f6b122/lib?css/search-subnav.css&amp;css/search-list.css&amp;css/property-listing.css&amp;css/map-button.css&amp;css/search-map.css&amp;css/map-bubble.css&amp;css/search-map-type-control.css&amp;css/schools-great-school-badges.css&amp;css/local-school-search-filters.css&amp;css/school-bubble.css&amp;css/tabview-simple.css&amp;css/map-button-addon-layers.css&amp;css/search-affordability-filter-exposed.css&amp;css/user-uss-lightbox.css&amp;css/search-layout.css" type="text/css"></link><meta name="msapplication-config" content="none"/><meta name="ROBOTS" content="NOINDEX"/><meta name="ROBOTS" content="NOYDIR"/><meta name="ROBOTS" content="NOODP"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-status-bar-style" content="black-translucent"/><meta name="format-detection" content="telephone=no"/><link rel="apple-touch-icon" href="http://www.zillowstatic.com/static/images/m/apple-touch-icon.png"></link><meta name="msapplication-TileColor" content="#3366b8"/><meta name="msapplication-TileImage" content="http://www.zillowstatic.com/static/images/logos/zillow-logo-win8-tile.png"></meta><meta name="verify-v1" content="/8Me6HBNZX/rt2n5/y1Lo3ZIrkcvkTBimqviTDiurR4="/><meta name="y_key" content="7cb4abe457d82ae8"/><link rel="canonical" href="http://www.zillow.com/homes/for_sale/"></link><meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no"></meta><meta itemprop="name" content="Zillow Real Estate, Rentals, and Mortgage"/><meta itemprop="description" content="The most trafficked website about home sales and rentals, with real estate values for almost every U.S. home. 1,000,000 listings that you won't find on MLS."/><meta itemprop="image" content="http://www.zillowstatic.com/static/images/social/share_thumbnail.png"></meta><link rel="start" title="Zillow home" href="/"/><!--[if gte IE 9]><link rel="shortcut icon" href="/static/images/ie9_favicon.ico" type="image/x-icon"/><![endif]--><meta name="google-translate-customization" content="691f1bfccade71b5-c065751219a379dd-g64cedb67f5ea020a-a"></meta><meta property="fb:app_id" content="172285552816089"/><meta property="og:url" content="http://www.zillow.com/homes/48749340_zpid/?hdpRedirected=true"/><meta property="og:site_name" content="Zillow"/><meta property="og:title" content="16312 SE 48th St, Bellevue, WA 98006  | Zillow"/><meta property="og:image" content="http://www.zillowstatic.com/static/images/m/apple-touch-icon.png"/><meta property="og:description" content="Zillow has 15 homes for sale. View listing photos, review sales history, and use our detailed real estate filters to find the perfect place."/><meta name="google-signin-clientid" content="238648973530.apps.googleusercontent.com"></meta><meta name="google-signin-scope" content="https://www.googleapis.com/auth/plus.login https://www.googleapis.com/auth/plus.profile.emails.read"></meta><meta name="google-signin-cookiepolicy" content="http://zillow.com"></meta><link rel="alternate" href="android-app://com.zillow.android.zillowmap/http/www.zillow.com/homes/for_sale/Bellevue-Washington/48749340_zpid/"></link><script>"use strict";(function(){var a=typeof window!="undefined"?window:exports,e=[],f=a.requestAnimationFrame||(function(g){setTimeout(g,0)}),d=function(g){e.push({name:g,entryType:"mark",startTime:a.performance.now(),duration:0})},b=function(g){return g==="mark"?e:undefined};a.performance||(a.performance={});a.performance.now||(a.performance.now=performance.now||performance.webkitNow||performance.msNow||performance.mozNow);if(!a.performance.now){var c=a.UI_INIT_AT||Date.now?Date.now():+(new Date());if(performance.timing&&performance.timing.navigationStart){c=performance.timing.navigationStart}a.performance.now=(function(){var g=Date.now?Date.now():+(new Date());return g-c})}a.performance.mark||(a.performance.mark=a.performance.webkitMark?a.performance.webkitMark:(d));a.performance.getEntriesByType||(a.performance.getEntriesByType=a.performance.webkitGetEntriesByType?a.performance.webkitGetEntriesByType:(b));a.ClientProfiler={};a.ClientProfiler.profile=function(g){f(function(){if("mark" in performance){a.performance.mark(g)}else{d(g)}})};a.ClientProfiler.profileInterval=function(g){};a.ClientProfiler.__profiled={};a.ClientProfiler.getProfiles=function(){var n=ClientProfiler,h,j=[],o,m,k;if("getEntriesByType" in performance){h=a.performance.getEntriesByType("mark")}else{h=b("mark")}for(var l=0,g=h.length;l<g;l++){o=h[l];m=Math.round(o.startTime);k=o.name;if(m>=0&&m<3600000&&!n.__profiled[k]){n.__profiled[k]=o;j.push(m+" "+k)}}return j}}());</script><script>if(typeof ZILLOW==="undefined"){var ZILLOW={}}(function(w,d){if(top!=self){top.location.replace(self.location.href)}var h=d.getElementsByTagName("html")[0];h.className=h.className.replace(/(?:^|\s)no-js(?!\S)/g,"");var l=w.location,a=l.hash,sn,snr=/scrnnm=[^&\}]+/;if(a&&a.indexOf("scrnnm")>0&&(sn=a.match(snr)[0])){a=l.hash.replace(snr,"");a=a.replace(/&&/,"&").replace(/\{&/,"{").replace(/&\}/,"}").replace(/\{\}/,"");w.location=l.protocol+"//"+l.host+l.pathname+(l.search?l.search+"&"+sn:"?"+sn)+a}ZILLOW.facebookSdkUrl="//connect.facebook.net/en_US/all.js";
/*@cc_on
            var q=d.createElement('div');q.innerHTML='<z>i</z>';q.childNodes.length!==1&&('abbr article aside audio canvas details figcaption '+
            'figure footer header hgroup mark meter nav output progress section summary time video').replace(/\w+/g,function(n){d.createElement(n)});
            @*/
})(this,document);var oldErr=window.onerror;window.cpErrors=0;window.onerror=function(f,c,b){try{cpErrors++;if(window.zonLog){var a="c=uncaught&m="+encodeURI(f)+"&u="+encodeURI(c)+"&l="+encodeURI(b)+"&r="+encodeURI(document.referrer);window.zonLog("Unhandled Error: "+a)}if(oldErr){return oldErr(errorMsg,c,lineNumber)}return false}catch(d){if(console&&console.error){console.error("Couldn't process error.",d)}}};if(document.addEventListener){document.addEventListener("DOMContentLoaded",function ProfileDOMContentLoadedEvent(a){ClientProfiler.profile("DOMContentLoaded");document.removeEventListener("DOMContentLoaded",ProfileDOMContentLoadedEvent)})}if(window.addEventListener){window.addEventListener("load",function ProfileLoadEvent(a){ClientProfiler.profile("native browser onload");window.removeEventListener("load",ProfileLoadEvent)})}var _gaq=_gaq||[],_gaqBackup=_gaqBackup||[];</script><link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"/></head>
<body class="map-list search-page map-left page-list-standard zsg-layout_full hotel-california building-hotel-california hdp-collapse  tengage wide">
<svg xmlns="http://www.w3.org/2000/svg" style="display:none"><symbol id="logo-text-svg" viewBox="0 0 100 100"><path d="M61.2 81.8c1.1-1.2 1.5-2.6 1.5-4.7c0-2-0.4-3.3-1.4-4.5c-1.1-1.2-2.4-1.8-4.2-1.8c-3.3 0-5.5 2.6-5.5 6.4 c0 3.9 2.2 6.4 5.5 6.4C59 83.5 60.3 82.9 61.2 81.8z M58.6 73.7c0.4 0.6 0.7 1.6 0.7 3.3c0 2.9-0.6 4.1-2 4.1c-0.6 0-1.3-0.3-1.6-1 c-0.3-0.6-0.4-1.7-0.4-3.1c0-1.2 0.1-2.1 0.3-2.7c0.3-0.8 0.9-1.2 1.7-1.2C57.8 73.1 58.3 73.3 58.6 73.7z M76.8 83.2L80.4 71H77 l-0.9 4.4c-0.3 1.6-0.6 3.5-0.7 4c0 0-0.4-2.1-0.9-4.3l-1-4.1h-3l-1.2 4.1c-0.6 2.1-0.9 4.3-0.9 4.3S68 77 67.7 75.5l-1-4.6h-3.3 l3.4 12.3h3l0.6-2.5c0.3-1.1 0.8-3.3 1.1-4.3c0.2-0.9 0.2-1.1 0.3-1.6c0.1 0.5 0.1 0.6 
span></a>   </li>  <li>    <a href="http://www.zillow.com/bellevue-wa-98006/real-estate-agent-reviews/?service=Selling"  title="Find a seller&#39;s agent" class=""  ><span>Find a seller&#39;s agent</span></a>   </li>  </ul>   </li>  </ul>   </li>  <li>   <header class="nav-sub-header">  Post a home for sale </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/post-real-estate-listings/"  title="For sale by agent" class=""  data-za-action="FSBA"  ><span>For sale by agent</span></a>   </li>  <li>    <a href="http://www.zillow.com/for-sale-by-owner/"  title="For sale by owner" class=""  data-za-action="FSBO"  ><span>For sale by owner</span></a>   </li>  <li>    <a href="http://www.zillow.com/coming-soon/"  title="Coming Soon" class=""  ><span>Coming soon</span></a>   </li>  <li>    <a href="http://www.zillow.com/make-me-move/"  title="Make Me Move" class=""  ><span>Make me move</span></a>   </li>  </ul>   </li>  </ul>   </li>  </ul>  </section>  <section class="nav-section nav-dropdown nav-section_wide ">  <header class="nav-header">  <a href="http://www.zillow.com/mortgage-rates/"  title="Mortgages" class=""  ><span>Mortgages</span></a>    <span class="zsg-icon-expando-down"></span>  </header>   <ul class="nav-content">  <li>   <header class="nav-sub-header">  Shop mortgages </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/pre-approval/"  title="Get pre-approved" class=""  ><span>Get pre-approved</span></a>   </li>  <li>    <a href="http://www.zillow.com/home-loans/"  title="Find a lender" class=""  ><span>Find a lender</span></a>   </li>  <li>    <a href="http://www.zillow.com/mortgage-rates/"  title="Mortgage rates" class=""  ><span>Mortgage rates</span></a>   </li>  <li>    <a href="http://www.zillow.com/mortgage-rates/wa/"  title="WA mortgage rates" class=""  data-za-action="State Mortgage Rates"  ><span>WA mortgage rates</span></a>   </li>  <li>    <a href="http://www.zillow.com/mortgage-rates/wa/bellevue/"  title="Bellevue mortgage rates" class=""  data-za-action="City Mortgage Rates"  ><span>Bellevue mortgage rates</span></a>   </li>  </ul>   </li>  </ul>   </li>  <li>   <header class="nav-sub-header">  Refinance </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/refinance/"  title="Refinance rates" class=""  ><span>Refinance rates</span></a>   </li>  <li>    <a href="http://www.zillow.com/refinance/wa/"  title="WA refinance rates" class=""  data-za-action="State Refinance Rates"  ><span>WA refinance rates</span></a>   </li>  <li>    <a href="http://www.zillow.com/refinance/wa/bellevue/"  title="Bellevue refinance rates" class=""  data-za-action="City Refinance Rates"  ><span>Bellevue refinance rates</span></a>   </li>  <li>    <a href="http://www.zillow.com/mortgage-calculator/harp-eligibility/"  title="HARP program" class=""  ><span>HARP program</span></a>   </li>  </ul>   </li>  </ul>   </li>  <li>   <header class="nav-sub-header">  Calculators </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/mortgage-calculator/"  title="Mortgage calculator" class=""  ><span>Mortgage calculator</span></a>   </li>  <li>    <a href="http://www.zillow.com/mortgage-calculator/house-affordability/"  title="Affordability calculator" class=""  ><span>Affordability calculator</span></a>   </li>  <li>    <a href="http://www.zillow.com/mortgage-calculator/refinance-calculator/"  title="Refinance calculator" class=""  ><span>Refinance calculator</span></a>   </li>  </ul>   </li>  </ul>   </li>  <li>   <header class="nav-sub-header">  Resources </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/mortgage-rates/learn/"  title="Mortgage education center" class=""  ><span>Mortgage education center</span></a>   </li>  <li>    <a href="http://www.zillow.com/mobile/mortgages/"  title="Mortgages app" class=""  ><span>Mortgages app</span></a>   </li>  </ul>   </li>  </ul>   </li>  </ul>  </section>  <section class="nav-section nav-dropdown nav-section_wide ">  <header class="nav-header">  <a href="http://www.zillow.com/bellevue-wa-98006/real-estate-agent-reviews/"  title="Agent finder" class=""  ><span>Agent finder</span></a>    <span class="zsg-icon-expando-down"></span>  </header>   <ul class="nav-content">  <li>   <header class="nav-sub-header">  Looking for pros? </header>  <ul class="nav-link-section list-drawer" data-visible-count="1" data-show-more-text="See more" data-show-less-text="See less">  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/bellevue-wa-98006/real-estate-agent-reviews/"  title="Real estate agents" class=""  ><span>Real estate agents</span></a>   </li>  <li>    <a href="http://www.zillow.com/bellevue-wa-98006/mortgage-lender-reviews/"  title="Mortgage lenders" class=""  ><span>Mortgage lenders</span></a>   </li>  <li>    <a href="http://www.zillow.com/bellevue-wa-98006/property-manager-reviews/"  title="Property managers" class=""  ><span>Property managers</span></a>   </li>  </ul>   </li>  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/bellevue-wa-98006/home-improvement-reviews/"  title="Home improvement pros" class=""  ><span>Home improvement pros</span></a>   </li>  <li>    <a href="http://www.zillow.com/bellevue-wa-98006/real-estate-services-reviews/"  title="Other pros" class=""  ><span>Other pros</span></a>   </li>  </ul>   </li>  </ul>   </li>  <li>   <header class="nav-sub-header">  I&#39;m a pro </header>  <ul class="nav-link-section list-drawer" data-visible-count="1" data-show-more-text="See more" data-show-less-text="See less">  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/agent-advertising/"  title="Agent advertising" class=""  ><span>Agent advertising</span></a>   </li>  <li>    <a href="http://www.zillow.com/search/ResurrectionSearchPageWithHomeDetail,searchPageWrapper.$ui$TopNav2014.canonicalLinksService.joinDirectoryLink.sdirect?form:search/ResurrectionSearchPageWithHomeDetail=ZH4sIAAAAAAAAALVUPW8TQRCdM6TgI1ICEkUEEoXrEyAKGiQSImSL
span></a>   </li>  </ul>   </li>  </ul>   </li>  <li>   <header class="nav-sub-header">  Find a pro </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/directory/Somerset-Bellevue-WA-98006/home-improvement/"  title="98006 home improvement pros" class=""  ><span>98006 home improvement pros</span></a>   </li>  </ul>   </li>  </ul>   </li>  </ul>  </section>  <section class="nav-section nav-dropdown nav-section_wide ">  <header class="nav-header">   <a  tabindex="0"><span>More</span>  </a>   <span class="zsg-icon-expando-down"></span>  </header>   <ul class="nav-content">  <li>   <header class="nav-sub-header">  Blogs </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/blog/"  title="Zillow blog" class=""  ><span>Zillow blog</span></a>   </li>  <li>    <a href="http://engineering.zillow.com/"  title="Zillow engineering blog" class=""  ><span>Zillow engineering blog</span></a>   </li>  </ul>   </li>  </ul>   </li>  <li>   <header class="nav-sub-header">  Partners </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://www.zillow.com/affiliate/"  title="Affiliates" class=""  ><span>Zillow affiliates</span></a>   </li>  <li>    <a href="http://www.zillow.com/broker-partners/"  title="Brokers and Zillow" class=""  ><span>Brokers and Zillow</span></a>   </li>  <li>    <a href="http://www.zillow.com/mls-partners/"  title="MLS and Zillow" class=""  ><span>MLS and Zillow</span></a>   </li>  <li>    <a href="http://www.zillow.com/webtools/"  title="Widgets and data" class=""  ><span>Widgets and data</span></a>   </li>  </ul>   </li>  </ul>   </li>  <li>   <header class="nav-sub-header">  Other </header>  <ul class="nav-link-section " >  <li>   <ul class="nav-link-list">  <li>    <a href="http://rentalpages.zillow.com/featured-properties/"  title="Rental pro real estate advertising" class=""  ><span>Rental advertising</span></a>   </li>  <li>    <a href="http://www.zillow.com/research/"  title="Zillow research" class=""  ><span>Zillow research</span></a>   </li>  <li>    <a href="http://www.zillow.com/visuals/"  title="Zillow visuals" class=""  ><span>Zillow visuals</span></a>   </li>  <li>    <a href="http://www.zillow.com/help/"  title="Zillow help center" class=""  ><span>Zillow help center</span></a>   </li>  </ul>   </li>  </ul>   </li>  </ul>  </section>  </div><div class="user-nav nav-top-group nav_hoverable">   <section class="user-nav-placeholder nav-section nav-dropdown nav-dropdown_right logged-in" id="login-block"><header class="nav-header"><a tabindex="0"><span>My Zillow</span></a><span class="zsg-icon-expando-down"></span></header></section>     <section class="nav-section nav-section-help nav-top-narrow_hidden"><div class="nav-header-content"><a href="/help/" title="Zillow Help Center"><span class="zsg-icon-circle-question"></span></a></div></section></div></div></nav></header><div class="zsg-nav-sub-wrapper"><div id="search-anchor" class="zsg-nav-sub"><div id="search-bar-container" class="zsg-toolbar"><ul class="zsg-toolbar-left zsg-toolbar-tabs zsg-tabs"><li class="search-box-content"><form class="zsg-searchbox" role="search" method="get" action="/search/RealEstateSearch.htm"><label class="hide-visually" for="citystatezip">Search</label><input autocorrect="off" name="citystatezip" id="citystatezip" placeholder="Address, Neighborhood, or ZIP" type="text" value="Bellevue Washington"></input><button type="submit" aria-label="Submit" class="zsg-search-button"><i class="zsg-icon-searchglass"></i></button></form></li><li id="search-sort-bar" class="zsg-nav-item hide"></li></ul><ul class="zsg-toolbar-right"><li id="save-search-button"><fieldset class="filter-menu save-search"><legend data-za-label="Save search"><a data-za-href="!ignore" data-za-action="Saved Search" data-za-category="Saved Search" data-za-label-submit="Save Search Toolbox submit" href="#saved-search-lightbox" class="zsg-lightbox-show za-track-event" data-za-label="Save search"><div> Save Search </div></a></legend></fieldset></li><li id="fav-control-back"><a data-za-Category="Followed Homes" data-za-action="Back Search Click" rel="nofollow" href="/homes/" title="Back to Search" class="zsg-toolbar-button zsg-button_primary track-ga-event" data-za-label="SavedHomes Map"><span class="leftarrow"></span>Back to Search</a></li><li id="fav-control-myhome" class="search-nav-button"><a data-za-Category="Search" data-za-action="Saved Homes Click" rel="nofollow" data-after-auth-action-type="" id="saved-homes-button" href="/savedhomes/" title="Saved Homes" class="zsg-toolbar-button zsg-button_primary track-ga-event async" data-za-label="SavedHomes Map"> Saved Homes (<span data-count="0" id="saved-homes-count">0</span>) </a></li></ul><div id="hdp-action-bar-container"><div id="actionBar" class="zsg-toolbar"><!----><ul class="zsg-toolbar-left"><li id="contact-menu"><div id="contact-lightbox_src" class="template hide"><!--<div id="contact\-lightbox_content" class="ajax\-form  wide\-format  dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"><div id="contact\-lightbox\-confirm" class="lightbox\-block current"><div class=" generic\-box yui3\-widget\-stdmod module"><div class="module\-body yui3\-widget\-bd clearfix"><div class="bal\-refactor   featured ">  <h2 class="form\-title">Contact Agent</h2>    <form id="lead\-form_contact" action="https://www.zillow.com/contact/ContactSubmit.htm" class="multi\-zuid\-select zsg\-form validation\-above contact" method="get">    <div id="premier\-tooltip\-contact" class="zsg\-tooltip"><p> Premier Agents specialize in this area and can assist you in seeing a home or answer your questions. </p><p> Are you an agent looking for more exposure for yourself or your listings? Call Zillow at <span class="phone">866\-324\-4005</span></p></div>    <div class="column ">   <div class="signature\-refactor has\-pal " data\-zuid="X1\-ZUz2z8gewe87bd_6msnz"><div class="zsg\-form\-field zsg\-form\-field_checkbox sig\-col ">   <div class="photo sig\-col">   <a href="/profile/torij/">  <img alt="Profile picture for Tori Johnson" src="http://photos3.zillowstatic.com/h_n/ISz4zqs412yx7n.jpg" width="60px" height="60px" class="zsg\-image\-profile"/>   </a>  </div>  </div>       <div class="badge\-tooltip\-wrapper"><div class="zsg\-tooltip\-launch zsg\-link badged" data\-target\-id="premier\-tooltip\-contact">  <span class="contact\-badge Premier Agent  ">Premier Agent</span>  </div></div>       <div class="info flat\-star\-ratings sig\-col">  <span class="snl name notranslate"><a href="/profile/torij/">Tori Johnson</a></span>    <span class="snl lender\-rating\-large">   <a href="/profile/torij/Reviews/" class="rating"><span class="zsg\-rating r500 zsg\-rating_500"></span></a>       <span class="reviews">(<a href="/profile/torij/Reviews/">7</a>)</span>   </span>   <span class="snl past\-sales">  <a href="/profile/torij/"><span class="sales\-count">27</span> Recent sales</a>   </span>    <span class="snl company\-name">John L Scott Real Estate</span>      <span class="snl phone">(206) 430\-5019 </span>     </div>   <span class='hide agent\-type'>Premier Agent</span>    <span class='hide first\-name'>Tori</span>   </div>     </div><div class="column ajax\-form\-content">   <div class="form\-input\-fields">   <div class="form\-input contact\-fields zsg\-form\-field field\-name  "><input id="name_contact" type="text" title="Please enter your name." placeholder="Your Name" name="name" required="required" value="Michael Hood" pattern=^[^!@#$%&amp;*+=]+$  ></div>  <div class="form\-input contact\-fields zsg\-form\-field field\-phone  "><input id="phone_contact" type="tel" title="Please enter a valid phone number, beginning with + for international numbers." placeholder="Phone" name="phone" required="required"   data\-intl="true" maxlength="23"></div>  <div class="form\-input contact\-fields zsg\-form\-field field\-email  "><input id="email_contact" type="email" title="Please enter a valid email address." placeholder="Email" name="email" required="required" value="hoodmichaelallen@gmail.com"   ></div> <div class="form\-input zsg\-form\-field form_textarea">  <textarea id="message_contact" maxlength="500" rows="3" name="message" data\-edited="0">I am interested in 16312 SE 48th St, Bellevue, WA 98006.</textarea>  </div></div>   <div class="lender\-details form\-input show\-border lender\-details\-above">  <div class="form\-preferred\-lender pal\-lender\-box hdp\-pal"> <div class="pals\-tooltip"><a href="#preferred\-lender\-contact" class="zsg\-tooltip\-launch zsg\-icon\-circle\-question" data\-placement="auto"></a><div id="preferred\-lender\-contact" class="zsg\-tooltip"><h4>What is a Premier Lender?</h4><p> The premier lender and the agent have a financial relationship and pay to advertise on this page. Zillow and the agents do not recommend or endorse any of the premier lenders. For more information on Zillow advertising practices, see Zillow’s Terms of Use &amp; Privacy. <a href="/comarketing/lender/" rel="nofollow" href="@">Learn more here</a></p></div></div> <div class="pal\-signature\-image">  <a href="/profile/Greg\-Legas/"><img alt="Profile picture for Greg Legas" src="http://photos2.zillowstatic.com/h_b/IS9hf8dc28lkqq1000000000.jpg"></a></div><div class="pal\-signature\-info\-list"><div class="preferred\-lender\-title">Premier Lender</div><div class="pal\-lender\-name"><a class="name" href="/profile/Greg\-Legas/">Greg Legas</a></div><div class="pal\-lender\-phone">   (253) 431\-2651     | NMLS 16690  </div></div></div>   <div class="zsg\-form\-field zsg\-form\-field_checkbox "><input id="preapproval\-cb\-contact" class="preapproval_toggle lender_autocheck " type="checkbox" name="preapproval" value="true"  checked="checked"/><label for="preapproval\-cb\-contact" id="preapproval\-label" class="preapproval\-label preapproval " for="preapproval\-cb\-contact" data\-edited="0">I want financing information   </label><div class="preapproval\-enabled zsg\-fineprint">A Zillow confirmed lender will contact you.</div></div>  </div>    <div class="form\-input zsg\-form\-actions zsg\-form\-actions_collapsed "><p class="validation\-above\-messaging zsg\-form\-error\-text"></p>  <button id="lead\-form\-submit\-button_contact" class="contact\-submit zsg\-button_primary" type="submit">Contact Agent</button>    </div>   </div>  <div class="hide">  <input type="hidden" name="variant" value="featured"/>  <input type="hidden" name="zpid" value="48749340"/>  <input type="hidden" name="mlsCode" value="811989"/>  <input type="hidden" name="onlyPreapprovalContact" value="false"/>  <input type="hidden" name="showNameField" value="true"/>  <input type="hidden" name="showPhoneField" value="true"/>  <input type="hidden" name="showPhoneMandatoryField" value="true"/>  <input type="hidden" name="palZuids" value="{&quot;X1\-ZUz2z8gewe87bd_6msnz&quot;:&quot;X1\-ZU10dt3ti60cd1l_68qz9&quot;}"/>  <input type="hidden" name="pcm" value="1"/>  <input type="hidden" name="subject" value="2"/>  <input type="hidden" name="pixelId" value="0ccf2066\-c3ab\-4efa\-83be\-aa3fb750013e"/>  <input type="hidden" name="formLocationType" value="43"/>  </div>  <div class='preapproval\-info hide'><span class='property\-value'>679500</span><span class='zipcode'>98006</span><span class='state\-abbr'>WA</span></div>     </form>   <div class="tips"> <p><span class="zsg\-tooltip\-launch zsg\-link bal\-agent\-upsell\-trigger" data\-target\-id="bal\-agent\-upsell\-tooltip\-43"> Learn how to appear as the agent above </span></p><div class="zsg\-tooltip" id="bal\-agent\-upsell\-tooltip\-43"> Want to learn more about appearing in the list of agents above? <a href="/feedback/AdvertiserSignup.htm?action=BAL+Popup+\-+Inside&source=Agent+Leads&label=Contact+us+here" class="bal\-agent\-upsell\-inside">Contact us here</a> or call us at 
            (855) 840\-3292 </div> </div>  <div class="footer lead\-form\-footer ">   </div>    </div></div></div></div><div id="contact\-lightbox\-success" class="lightbox\-block"><h4>Contact Successful!</h4><p class="message"></p><div class="zmm\-hdp\-upsell\-copy success zmm\-upsell\-msg default\-zmm\-msg"><div>Are you pre\-approved already?</div><p>Find out how much house you can afford and get pre\-approved for a mortgage in minutes.</p><ul><li><span class="fne icon"></span><span>Fast &amp; Easy</span></li><li><span class="tnl icon"></span><span>Top\-Notch Lenders</span></li><li><span class="sns icon"></span><span>Safe &amp; Secure</span></li></ul><p class="button\-wrapper"><a href="/mortgage\-rates/" data\-za\-category="Mortgages" class="get\-pre\-approved\-now button zsg\-button_primary za\-track\-event" data\-za\-label="HDP:PostAgentContact" data\-za\-action="Upsell click"> Get Pre\-Approved </a></p></div><div class="zmm\-hdp\-upsell\-copy success zmm\-upsell\-msg pre\-approved\-zmm\-msg lender\-upsell\-msg"><div>Next: Get Pre\-Approved</div><p>A Lender can assist you with pre\-approval process and answer any question you have.</p><p class="button\-wrapper"><a class="button pre\-approval\-button zsg\-button_primary">Yes, contact me</a></p></div><div class="zmm\-hdp\-upsell\-copy success zmm\-upsell\-msg agent\-lender\-confirmation\-zmm\-msg thanks\-pals\-msg"><p>A Lender will also be calling you back to assist with pre\-approval.</p><p><strong>Thanks for using Zillow!</strong></p></div><div class="zmm\-hdp\-upsell\-copy success zmm\-upsell\-msg thanks\-zmm\-msg"><p>We'll send you an email with a link to get pre\-approved on Zillow or you can get started by clicking below.</p><p class="button\-wrapper"><a href="/mortgage\-rates/" data\-za\-category="Mortgages" class="get\-pre\-approved\-now button zsg\-button_primary za\-track\-event" data\-za\-label="HDP:PostAgentContact" data\-za\-action="Upsell click"> Get Pre\-Approved </a></p></div><div class="zmm\-hdp\-upsell\-copy success zmm\-upsell\-msg pals\-error\-msg"><p>We weren't able to process your pre\-approval request. Please go to Zillow Mortgage Marketplace directly by clicking below.</p><p class="button\-wrapper"><a href="/mortgage\-rates/" data\-za\-category="Mortgages" class="get\-pre\-approved\-now button zsg\-button_primary za\-track\-event" data\-za\-label="HDP:PostAgentContact" data\-za\-action="Upsell click"> Get Pre\-Approved </a></p></div></div><div id="contact\-lightbox\-failure" class="lightbox\-block"><div class="zsg\-notification\-text\-error failure message\-wrap"><div><h4>Submission failed!</h4><p class="message">Unable to send email. Please try again later.</p></div></div></div></div></div>--></div><a rel="nofollow" href="#contact-lightbox" data-reason="1" class="show-lightbox zsg-toolbar-button zsg-button">Contact<span class='zsg-md-hide zsg-sm-hide'> agent</span></a></li><li id="save-menu" data-zpid="48749340" class="hide-when-property-hidden save stick-focus saveOneClick"><input type="hidden" id="oneClickSaveFavorite" name="oneClickSaveFavorite" value="true"/><a id="oneClickfavoriteButton"><span href="/myzillow/UpdateFavorites.htm?zpid=48749340&amp;operation=add&amp;ajax=false" rel="nofollow" data-fm-zpid="48749340" data-fm-callback="newHomeDetailsSaveFavoriteSuccessHandler" data-za-label="Save home" class="fm-save-event save-button  zsg-toolbar-button zsg-button  FS" id="auth_SaveFavoriteAuthCheck"><span class="zsg-icon-heart-line"></span><span class="optional-action-label"> Save</span></span></a><span id="addFavoriteButton" class="hide"><span href="/myzillow/UpdateFavorites.htm?zpid=48749340&amp;operation=add&amp;ajax=false" rel="nofollow" data-fm-zpid="48749340" data-fm-callback="newHomeDetailsSaveFavoriteSuccessHandler" data-za-label="Save home" class="fm-save-event save-button  zsg-toolbar-button zsg-button  FS" id="auth_SaveFavoriteAuthCheck_0"><span class="zsg-icon-heart-line"></span><span class="optional-action-label"> Save</span></span></span><span id="removeFavoriteButton" class="hide"><span data-fm-zpid="48749340" href="#" data-fm-callback="newHomeDetailsRemoveFavoriteSuccessHandler" class="fm-remove-event save-button zsg-toolbar-button zsg-button" data-za-label="Save home"><span class="zsg-icon-heart-filled"></span><span class="optional-action-label"> Saved</span></span></span><div id="add-note-code_src" class="template hide"><!--<div id="add\-note\-code_content" class="add\-note dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"><div id="add\-note\-section" class="generic\-box yui3\-widget\-stdmod module"><div class="module\-body yui3\-widget\-bd clearfix"><div class="module\-content"><h2 class="add\-note\-code\-header">Add a note</h2><p><label> This note will be visible only to you. </label><textarea class="favorite\-note" tabindex="10" cols="50" maxlength="512" frameborder="no">
                            
                        </textarea></p><ul class="zsg\-list_inline"><li><a href="/myzillow/UpdateFavorites.htm?zpid=48749340&operation=saveNote&ajax=false" rel="nofollow" data\-fm\-zpid="48749340" data\-fm\-callback="homeDetailsSaveNoteSuccessHandler" data\-fm\-redirect="true" data\-fm\-save\-note="true" tabindex="10" data\-za\-label="hdp\-save\-as\-favorite\-note" class="fm\-save\-event zsg\-button_primary" id="auth_SaveFavoriteAuthCheck_1"><span>Save</span></a></li><li><a data\-fm\-zpid="48749340" href="#" class="delete\-hdp\-fav\-note fm\-remove\-note zsg\-button_primary hide">Delete this note</a></li></ul><p class="one\-click\-error\-msg\-container hide">&nbsp;</p><p id="noteSaved48749340" class="note\-saved hide"></p></div></div></div></div></div>--></div></li><li class="save hideOneClick"><input type="hidden" id="oneClickHideProperty" name="oneClickHideProperty" value="true"/><a id="oneClickHideButton"><span href="/myzillow/UpdateHiddenProperty.htm?hidezpid=48749340&amp;hideop=hide" rel="nofollow" data-hpm-zpid="48749340" data-hpm-callback="hdpHidePropertySuccessHandler" data-za-label="HiddenHomes HDP:Action Bar" class="hpm-hide-event hide-button  zsg-toolbar-button zsg-button" id="auth_HidePropertyAuthCheck"><span class="zsg-icon-circle-hide"></span><span class="optional-action-label"> Hide</span></span></a><span id="hidePropertyButton" class="hide"><span href="/myzillow/UpdateHiddenProperty.htm?hidezpid=48749340&amp;hideop=hide" rel="nofollow" data-hpm-zpid="48749340" data-hpm-callback="hdpHidePropertySuccessHandler" data-za-label="HiddenHomes HDP:Action Bar" class="hpm-hide-event hide-button  zsg-toolbar-button zsg-button" id="auth_HidePropertyAuthCheck_0"><span class="zsg-icon-circle-hide"></span><span class="optional-action-label"> Hide</span></span></span><span id="unhidePropertyButton" class="hide"><span rel="nofollow" href="#" class="hide-button hpm-unhide-event zsg-toolbar-button zsg-button" data-hpm-zpid="48749340" data-za-label="HiddenHomes HDP:Action Bar" data-hpm-callback="hdpUnhidePropertySuccessHandler"><span class="zsg-icon-circle-hide optional-action-label"></span><span class=""> Hidden</span></span></span></li><!--Modernize: This case is no longer used?--><li data-zpid="48749340" class="hide-when-property-hidden default-ids hide new-email"><a href="#send-to-friend-lightbox" class="show-lightbox zsg-toolbar-button zsg-button" data-zpid="48749340">Share <span class="default-email-ids"></span></a></li><!--Modernize: This case is no longer used?--><li data-zpid="48749340" class="hide-when-property-hidden new-email"><a href="#send-to-friend-lightbox" class="show-lightbox zsg-toolbar-button zsg-button" data-zpid="48749340">Share </a></li><div id="send-to-friend-lightbox_src" class="template hide"><!--<div id="send\-to\-friend\-lightbox_content" class="shareable ajax\-form email\-a\-friend dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"><div id="send\-to\-friend\-lightbox\-confirm" class="lightbox\-block current"><div id="send\-to\-friend"><h2>Email this home</h2><form action="/email/EmailAFriendRequest.htm" class="lead\-form zsg\-separator zsg\-content\-item"><div class="ajax\-form\-content"><div class="captcha\-field zsg\-form\-field"><p>Please complete the Captcha below.</p><div id="send\-to\-friend\-recaptcha"></div><p class="zsg\-form\-error\-text">There was an issue with the captcha result.<br/>Please try again.</p></div><div class="zsg\-form\-field"><label for="remail">Recipient's email</label><input multiple="5" name="remail" id="remail" type="email" title="Please enter up to five valid email addresses." class="required" required="required"></input><p class="zsg\-form\-help\-text">Separate multiple addresses with a comma.</p></div><div class="zsg\-form\-field"><label for="semail">Your email</label><input name="semail" id="semail" type="email" title="Please enter a valid email address." value="hoodmichaelallen@gmail.com" class="required" required="required"></input></div><div class="zsg\-form\-field"><label for="smsg">Include message <span class="de\-emph">(optional)</span></label><textarea id="smsg" name="smsg" maxlength="2000" data\-error="URLs cannot be included in your message.">Check out this home I found on Zillow.</textarea></div><div class="lead\-form\-footer zsg\-form\-actions zsg\-form\-field"><button type="submit" id="submit\-button" class="zsg\-button_primary zsg\-content\-item">Send email</button></div></div><input name="eplink" id="eplink" type="hidden" value="http://www.zillow.com/homedetails/16312\-SE\-48th\-St\-Bellevue\-WA\-98006/48749340_zpid/"></input><input type="hidden" id="sts" name="sts" value="true"/><input name="kval" id="kval" type="hidden" value="0gOw629LJcxdfoBB12ku4jJJaRge_0Fa14Pga54v3OQ"></input><input name="saddr" id="saddr" type="hidden" value="16312 SE 48th St"></input><input name="csaddr" id="csaddr" type="hidden" value="Bellevue, WA"></input><input name="ngbrhood" id="ngbrhood" type="hidden" value="Somerset"></input><input name="ls" id="ls" type="hidden" value="For Sale"></input><input name="lp" id="lp" type="hidden" value="$679,500"></input><input name="pz" id="pz" type="hidden" value="$681K"></input><input name="bed" id="bed" type="hidden" value="4"></input><input name="bath" id="bath" type="hidden" value="2.5"></input><input name="sqft" id="sqft" type="hidden" value="2,180"></input><input name="iu" id="iu" type="hidden" value="http://photos1.zillowstatic.com/p_b/ISpximk0uuc31d0000000000.jpg"></input><input name="zpid" id="zpid" type="hidden" value="48749340"></input></form><div class="social\-buttons\-block zsg\-content\-item"><span>Share this home:</span><a data\-za\-action="Share on Facebook" rel="nofollow" data\-za\-category="Share" shareUrl="http://u.zillow.com/p3IXvg/" href="javascript: void(0);" title="Share on Facebook" class=" zsg\-icon\-facebook fb_share za\-track\-event" data\-za\-label="HDP: Share"><span>Share on Facebook</span></a><a data\-za\-href="!ignore" data\-share\-message="Check out this 4bd 2.5ba 2180 sqft home at 16312 SE 48th St that I found on #Zillow http://u.zillow.com/p3IXvg/" data\-za\-action="Share on Twitter" rel="nofollow" data\-za\-category="Share" href="#" title="Share on Twitter" class=" zsg\-icon\-twitter share\-on\-twitter za\-track\-event" data\-za\-label="HDP: Share"><span>Tweet this home</span></a><a data\-za\-action="Share on Google Plus" data\-za\-category="Share" href="https://plus.google.com/share?url=http://u.zillow.com/p3IXvg/" class="zsg\-icon\-google\-plus za\-track\-event" data\-za\-label="HDP: Share"><span>Share on Google+</span></a></div></div></div><div id="send\-to\-friend\-lightbox\-success" class="lightbox\-block"><div id="send\-to\-friend\-success" class="emailafriend\-lightbox\-success"><h2>Email has been sent!</h2><p>Tip: Save this home as a favorite and receive email updates and notifications on Zillow and your mobile apps.</p><div class="success\-lightbox\-address zsg\-content\-item">16312 SE 48th St<br/>Bellevue, WA 98006</div><a id="save\-this\-home\-link" class="button zsg\-button_primary">Save this home</a></div></div><div id="send\-to\-friend\-lightbox\-failure" class="lightbox\-block"><div id="send\-to\-friend\-failure" class="emailafriend\-lightbox\-failure"><h2>Email send failed!</h2><button class="zsg\-button_primary" id="back\-to\-form">Back to message</button></div></div><div id="send\-to\-friend\-lightbox\-favoriteSuccess" class="lightbox\-block"><div id="favorite\-success" class="emailafriend\-lightbox\-success"><h2>This home has been saved!</h2><p>Go to <b>My Zillow</b> in the top right corner to see your saved homes.</p></div></div></div></div>--></div><li id="more-menu" class="more-menu"><a name="moreMenu" href="#hdp-action-bar-more" class="dropdown-trigger-ico zsg-menu-launch zsg-toolbar-button zsg-button"><span class="more-label">more </span><span class="zsg-icon-arrow-menu-down"></span></a><div class="zsg-menu" id="hdp-action-bar-more"><ul class="zsg-menu-linklist"><li class="print"><a href="/homedetails/48749340_zpid/?print=true" rel="nofollow" name="printMenu">Print</a></li><li data-zpid="48749340" class="hide-when-property-hidden"><a data-default-selection="PropertyLightboxSubscription.DEFAULT_SELECTION.PROPERTY_ALERTS" data-za-href="!ignore" data-za-action="Property Alert" rel="nofollow" data-za-category="Alerts" href="#property-subscription" data-zpid="48749340" class="hdp-menu-get-updates  NFS-FS  property-subscription za-track-event show-lightbox" data-za-label="HC HDP Click">Get updates on this home</a></li><li><a class="show-lightbox" data-uss-type="similar" data-za-label="Save Search HDP:Action Bar" rel="nofollow" data-za-label-submit="Save Search HDP:Action Bar submit" href="#saved-search-lightbox">Get new listings in email</a></li><li id="add-note-menu" data-zpid="48749340" class="hide-when-property-hidden hide"><a class="show-lightbox" href="#add-note-code">Add note</a></li><li class="zsg-separator zsg-separator-narrow"></li><li data-zpid="48749340" class="hide-when-property-hidden"><a href="#agent-claim-box" class="show-lightbox">Claim this listing</a><div id="claim-config" class="template hide"><!--{ "zpid":48749340, "showErrors":false }--></div><div id="agent-claim-box_src" class="template hide"><!--<div id="agent\-claim\-box_content" class="claim\-lightbox legacy\-lightbox dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"><h2>Claim listing</h2><p>Agent: Is this your listing? Claim it and it will be linked to your Zillow profile. You will first need to <a href="/search/ResurrectionSearchPageWithHomeDetail,initialHomeDetailComponent.$homedetail$toolbox$ActionBar.editAgentClaimMenuItem.$claiming$AgentClaim.$DirectLink.sdirect?sp=48749340">Sign In</a>.</p><p>Homeowner: Since your home is listed by an agent, you will not be able to make changes to it. Please ask your listing agent to make any desired changes.</p><ul class="carrot"><li><a href="/wikipages/About\-Linking\-and\-Claiming\-Listings/" rel="nofollow">Learn about linking listings to your e\-mail address</a></li></ul></div></div>--></div></li><li data-ga-category="Homes" data-ga-action="Report Listing Dropdown Click" class="track-ga-event" data-ga-label="HDP Action Bar"><a rel="nofollow" id="complaint_open-flag_14422068723522625373" title="Report problem with listing" class="flag-content">Report problem with listing</a><div id="complaint_block-flag_14422068723522625373" class="hide inappropriate inappropriate-new complaint-form"><form name="complaint_form-flag_14422068723522625373" id="complaint_form-flag_14422068723522625373" class="zsg-form"><a href="#" class="zbt icon close complaint-form-close"><span class="zsg-icon-x-thin"></span></a><div class="metadata hide"><input name="contentType" type="hidden" value="propertyId"></input><input name="contentId" type="hidden" value="48749340"></input><input name="componentName" type="hidden" value="ActionBar"></input><input name="contentUserId" type="hidden" value="X1-ZUzen0acgrkf7t_3o1g3"></input><input name="originatingURL" type="hidden" value="http://www.zillow.com/homedetails/16312-SE-48th-St-Bellevue-WA-98006/48749340_zpid/"></input><input name="encodedIdType" type="hidden"></input><input name="commentType" type="hidden" value=""></input><input name="userType" type="hidden" value=""></input><span dispute_owner="/claiming/DisputeClaimOptions.htm?cid=1442206872353&amp;zpid=48749340" canDisputeAgent="true" new_reporting_ui="true" class="attr-config"></span></div><div id="user-type-page" class="flagging-page"><div><h2 class="title">Report a Problem</h2><h3 class="second zsg-h3">Please tell us who you are:</h3><div class="zsg-form-field"><ul class="zsg-form-group"><li class="flag-first"><input name="user-type" id="consumer-flag_14422068723522625373" type="radio" value="Consumer"></input><label for="consumer-flag_14422068723522625373">Consumer</label></li><li class="flag-first"><input name="user-type" id="real-estate-pro-flag_14422068723522625373" type="radio" value="Pro"></input><label for="real-estate-pro-flag_14422068723522625373">Real estate professional</label></li></ul></div><div><div class="error-text hide"> Please select user type </div><div class="action zsg-form-action"><a href="#" class="usertype-continue button zsg-button_primary"><span>Continue</span></a></div></div></div></div><div id="init-page" class="flagging-page hide"><div><h2 class="title">Report a Problem</h2><h3 class="second zsg-h3">What's the issue?</h3><input type="hidden" id="home-type" value="FS"/><div class="zsg-form-field"><ul class="zsg-form-group"><li class="flag-first"><input name="flag-first" id="prop_not-for-sale-flag_14422068723522625373" type="radio" value="prop_not-for-sale"></input><label for="prop_not-for-sale-flag_14422068723522625373">Home is no longer available</label></li><li class="flag-first"><input name="flag-first" id="incorrect_info-flag_14422068723522625373" type="radio" value="incorrect_info"></input><label for="incorrect_info-flag_14422068723522625373">Incorrect information/photos</label></li><li class="flag-first"><input name="flag-first" id="spam-flag_14422068723522625373" type="radio" value="spam"></input><label for="spam-flag_14422068723522625373">Fraudulent listing or spam</label></li></ul></div><div><div class="error-text hide"> Please select an issue </div><div class="action zsg-form-action"><ul class="action zsg-button-group"><li><a href="#" class="init-continue button zsg-button_primary"><span>Continue</span></a></li><li><a href="#" class="back-page button zsg-button"><span>Back</span></a></li></ul></div><div class="flag-footer"> Don't see your issue here? Visit our <a class="help-center-link" href="/help/" data-ga-label="Initial Landing Page">Help Center</a></div></div></div></div><div id="sub-issue-page" class="flagging-page hide"><div><h2 class="title">Report a Problem</h2><h3 class="second zsg-h3">What's incorrect?</h3><ul><div class="zsg-form-field"><ul class="zsg-form-group"><li><input name="complaintType" id="wrong_facts-flag_14422068723522625373" type="radio" value="wrong_facts"></input><label for="wrong_facts-flag_14422068723522625373">Home facts (bd, ba, sqft, etc)</label></li><li><input name="complaintType" id="price_change-flag_14422068723522625373" type="radio" value="price_change"></input><label for="price_change-flag_14422068723522625373">Current sale price</label></li><li><input name="complaintType" id="wrong_photo-flag_14422068723522625373" type="radio" value="wrong_photo"></input><label for="wrong_photo-flag_14422068723522625373">Photos</label></li><li><input name="complaintType" id="wrong_location-flag_14422068723522625373" type="radio" value="wrong_location"></input><label for="wrong_location-flag_14422068723522625373">Map location</label></li><li><input name="complaintType" id="price_tax_history-flag_14422068723522625373" type="radio" value="price_tax_history"></input><label for="price_tax_history-flag_14422068723522625373">Price/tax history</label></li><li><input name="complaintType" id="dispute_owner-flag_14422068723522625373" type="radio" value="dispute_owner"></input><label for="dispute_owner-flag_14422068723522625373">Owner claim</label></li><li><input name="complaintType" id="zestimate-flag_14422068723522625373" type="radio" value="zestimate"></input><label for="zestimate-flag_14422068723522625373">Zestimate</label></li><li><input name="complaintType" id="duplicate-flag_14422068723522625373" type="radio" value="duplicate"></input><label for="duplicate-flag_14422068723522625373">This is a duplicate listing</label></li></ul></div></ul></div><div><div class="error-text hide"> Please select an issue </div><div class="zsg-form-action"><ul class="action zsg-button-group"><li><a href="#" class="sub-issue-continue button zsg-button_primary"><span>Continue</span></a></li><li><a href="#" class="back-page button zsg-button"><span>Back</span></a></li></ul></div><div class="flag-footer"> Don't see your issue here? Visit our <a class="help-center-link" href="/help/" data-ga-label="Sub-Issue Page">Help Center</a></div></div></div><div id="self-help-page" class="flagging-page hide"><div><h2 class="title">Report a Problem</h2><h3 class="second zsg-h3">Issue Type: <span class="issue-type"></span></h3><div class="issue-detail"><div class="zestimate hide"><div class="message"> The Zestimate is a starting point in figuring out the true value of a house. The amount of data we have for the house affects the Zestimate accuracy. If your home facts are incorrect or missing, this may affect your Zestimate value. <a href="/zestimate/">More on the Zestimate</a></div><div class="message"><strong>Information about this home is only editable by the listing agent.</strong> If you are the current owner, contact the listing agent to make changes. </div></div><div class="message other hide"> This information is only editable by the listing agent. If you can't get in touch with the listing agent, you can also <a href="#" class="cs-form-link">report the issue to us</a></div></div></div><div><div class="zsg-form-action"><ul class="action zsg-button-group"><li class="done"><a href="#" class="done button zsg-button_primary"><span>Done</span></a></li><li><a href="#" class="back-page button zsg-button"><span>Back</span></a></li></ul></div><div class="flag-footer"><div class="zestimate hide"> Home facts not the problem? <a href="#" class="cs-form-link">Report the issue to us</a></div><div class="other hide"><span class="edit-posting-page">Are you the listing agent? <a href="/postings/EditPosting.htm?cid=1442206872354&amp;section=HomeFacts&amp;zpid=48749340" class="agent-edit">Edit now in Agent Hub</a></span><span class="owner-claim-page hide">Are you the listing agent? <a href="/claiming/ClaimProperty.htm?cid=1442206872354&amp;zpid=48749340" class="agent-edit">Edit now in Agent Hub</a></span></div></div></div></div><div id="cs-feedback-page" class="flagging-page hide"><div><h2 class="title">Report a Problem</h2><h3 class="second zsg-h3">Issue Type: <span class="issue-type"></span></h3><div class="zsg-form-field"><label for="flag_14422068723522625373-comment">Details:</label><textarea name="comment" id="flag_14422068723522625373-comment" placeholder="Describe your issue here (please be as specific as possible)" class="comment-detail"></textarea><p class="flag_14422068723522625373-comment-error error-text hide">Please describe your issue</p></div><div class="zsg-form-field"><label for="flag_14422068723522625373-reporterEmail">Your email:</label><input name="reporterEmail" id="flag_14422068723522625373-reporterEmail" type="text" class="email-info" value="hoodmichaelallen@gmail.com"></input><p class="flag_14422068723522625373-reporterEmail-error error error-text hide">Please enter a valid email address</p></div></div><div class="zsg-form-action"><ul class="action zsg-button-group"><li><a href="#" class="cs-submit button zsg-button_primary"><span>Submit</span></a></li><li><a href="#" class="back-page button zsg-button"><span>Back</span></a></li></ul></div></div><div id="thank-you-page" class="flagging-page hide"><div><h2 class="title">Report a Problem</h2><h3 class="second zsg-h3">Thank you!</h3><div class="message"> We're sorry there's a problem with this listing. We'll look into it. Thank you for your patience, and for using Zillow! </div></div><div><div class="action zsg-form-action"><a href="#" class="done button zsg-button_primary"><span>Done</span></a></div></div></div><div class="action hide"><ul class="zsg-button-group"><li><a href="#" class="button submit primary zsg-button_primary"><span>Submit</span></a>&nbsp; </li><li><a href="#" class="button cancel zsg-button"><span>Cancel</span></a></li></ul></div><div id="complaint_failure-flag_14422068723522625373" class="hide inappropriate complaint-form"><a href="#" class="zsg-icon-button zbt icon close"><span class="zsg-icon-x-thin"></span></a><div><h3 class="zsg-h3">We're Sorry</h3><div>This service is temporarily unavailable. Please come back later and try again.</div></div></div></form></div></li></ul></div></li></ul><ul class="zsg-toolbar-right"><li id="hdp-popout-menu" class="hdp-popout-menu"><a href="/homedetails/48749340_zpid/" target="_blank" class="zsg-toolbar-button zsg-button za-track-event" title="Open in new tab" data-za-action="Hotel California - View Full HDP" data-za-category="Homes" data-za-label="Header click"><span class="zsg-icon-pop-up"></span><span class="optional-action-label">expand</span></a></li><li><button class="zsg-toolbar-button zsg-button hc-back-to-list"><span class="zsg-icon-x-thick"></span> Close</button></li></ul></div></div></div></div></div><span id="HdpRedirected"></span><div id="container" class="search-content-container"><div class="active-view"><div id="c-column" class="property-data-column yui3-u "><div id="inner-c-column" class="inner-property-data-column"><div id="list-container-column" class="search-list-col"><div class="active-view"><div data-zmm-page="Search-List" id="list-results-container" class=""><div id="photoex-viewer" class="photoex hide"><div id="photo-viewer" class="photoex-photos hide"></div><div id="map-viewer" class="mapsViews hide"></div></div><!-- Property results --><div id="list-container" class="list-container has-selected-listing "><div id="inner-list-container"><div role="main" id="list-core-content-container" class="zsg-content-item"><div id="list-loading-message" class="map-list-loader-container loading"><div class="map-list-loader"><span class="zsg-loading-spinner"></span> Updating results... </div></div><div class="list-loading-message-cover"></div><div class="search-title-container zsg-content-item"><h1 id="search-title" class="zsg-content_collapsed">Real Estate</h1><!-- <div class="map-result-count-message-wrapper"> --><div id="map-result-count-message"></div><!-- </div> --></div><div id="sort-control-container"><ul id="property-sort-control" class="zsg-tabs zsg-tabs_lg"><li class=""><a href="/homes/for_sale/featured_sort/47.566232657079624,-122.10983991622925,47.5546487399603,-122.13558912277222_rect/14_zm/1_p/" data-value="featured">Featured</a></li><li class="zsg-tab_active"><a href="/homes/for_sale/47.566232657079624,-122.10983991622925,47.5546487399603,-122.13558912277222_rect/14_zm/1_p/" data-value="days">Newest</a></li><li class="second-unselected"><a href="/homes/for_sale/priced_sort/47.566232657079624,-122.10983991622925,47.5546487399603,-122.13558912277222_rect/14_zm/1_p/" data-value="priced">Cheapest</a></li><li id="property-sort-control-more-btn" class="hide"><a href="#property-sort-options" class="more-btn zsg-menu-launch" data-horizontal-align="right">More</a><div id="property-sort-options" class="zsg-menu"><ul class="zsg-menu-linklist"><li class="second-unselected"><a href="#" data-value="priced">Cheapest</a></li><li class=""><a href="#" data-value="pricea">Price (High to Low)</a></li><li class=""><a href="#" data-value="beds">Bedrooms</a></li><li class=""><a href="#" data-value="baths">Bathrooms</a></li><li class=""><a href="#" data-value="size">Square Feet</a></li><li class=""><a href="#" data-value="built">Year Built</a></li><li class=""><a href="#" data-value="lot">Lot Area</a></li><li class=""><a href="#" data-value="zest">Zestimate (High to Low)</a></li><li class=""><a href="#" data-value="zesta">Zestimate (Low to High)</a></li></ul></div></li></ul></div><div id="list-results" class="loading searchupsellnew"></div><div id="search-pagination-wrapper" class="zsg-content-item"></div></div><div id="list-results-save-search-upsell" class="zsg-content-item footer-save-search-upsell "><a class="zsg-lightbox-show za-track-event" href="#saved-search-lightbox" data-za-category="Saved Search" data-za-action="Saved Search" data-za-label="SearchList:SaveSearch" data-za-label-submit="Save Search Filter submit" data-za-href="!ignore">Save this search</a> to get email alerts when listings hit the market. </div></div></div></div><div class="generic-box ad"><div style="display: none;" data-frame-id="gpt-ad-dc588c86-7158-4f42-ad3a-db3f18affb30" id="gpt-ad-dc588c86-7158-4f42-ad3a-db3f18affb30-config" class="google-ad-config">{"targetDiv":"gpt-ad-dc588c86-7158-4f42-ad3a-db3f18affb30","slot":"zillow/search_results/buy_general/b_right_p1","network":"7449","sizes":"[300,250]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":true,"explicit_defer_ad":false}</div><div id="gpt-ad-dc588c86-7158-4f42-ad3a-db3f18affb30" class="deferred-iframe-target"></div></div><footer id="footer" class="search-page-footer zsg-footer"><div class="zsg-subfooter"><div class="zsg-subfooter-content"><div class="zsg-g"><div id="nearby-results" class="clearfix"></div></div><div id="why-use-zillow" class="clearfix"><h6 class="zsg-subfooter-header">Why use Zillow?</h6><p> Zillow is perfect for searching homes for sale in the United States. By analyzing real estate information on millions of homes for sale across the United States, we calculate home values (Zestimates) and the Zillow Home Value Price Index. </p></div><p class="schools-disclaimer zsg-fineprint"><strong>Disclaimer:</strong> School attendance zone boundaries are supplied by Maponics and are subject to change. Check with the applicable school district prior to making a decision based on these boundaries.</p></div></div><div class="zsg-footer-nav zsg-separator zsg-separator_narrow"><nav class="zsg-footer-row zsg-footer-linklist-container"><ul class="zsg-list_inline zsg-footer-linklist zsg-fineprint-header" data-za-category="Navigation" data-za-action="Footer"><li><a href="/corp/About.htm" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="About">About</a></li><li><a href="/zestimate/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event" data-za-label="Zestimates">Zestimates</a></li><li><a href="/jobs/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Jobs">Jobs</a></li><li><a href="/help/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Help">Help</a></li><li><a href="/advertise/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Advertise">Advertise</a></li><li><a href="/corp/Terms.htm" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Terms">Terms of use &amp; Privacy</a></li><li><a href="/corp/Privacy.htm#behavioralAdvertising" class="za-track-event zsg-link_primary" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Ad Choice">Ad Choice</a></li><li><div id="teconsent" class="za-track-event zsg-link_primary" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Cookie Preferences"></div></li><li><a href="/blog" class="za-track-event zsg-link_primary" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Blog">Blog</a></li><li><a href="/mobile/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Mobile Site">Mobile Apps</a></li></ul><span class="zsg-icon-expando-down zsg-footer-nav-arrow zsg-footer-nav-arrow-open"></span><span class="zsg-icon-expando-up zsg-footer-nav-arrow zsg-footer-nav-arrow-close"></span></nav></div><div class="zsg-footer-copyright zsg-footer-row"><ul class="zsg-list_inline"><li></li><li>&copy; 2006-2015 Zillow</li><li><div class="zsg-footer-follow" data-za-category="Homepage" data-za-action="Social Icon"><span>Follow us</span><a href="http://www.facebook.com/Zillow" target="_blank" class="za-track-event" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Facebook"><span class="zsg-icon-facebook"></span></a><a href="http://twitter.com/zillow" target="_blank" class="za-track-event" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Twitter"><span class="zsg-icon-twitter"></span></a><a href="http://plus.google.com/+Zillow" target="_blank" class="za-track-event" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Google+"><span class="zsg-icon-google-plus"></span></a></div></li></ul></div></footer></div></div><div id="detail-container-column" class="active-hdp-col"><div class="active-view"><div id="hidden-property-hdp-label" class="hide"><div class="zsg-notification-bar messaging"> This property is hidden from your search results. <a class="hpm-unhide-event" data-hpm-zpid="48749340" data-hpm-callback="hdpUnhidePropertySuccessHandler"> Unhide </a></div></div><div data-zmm-page="HDP"><div id="hdp-content" class="zsg-tooltip-viewport prop photos-swap"><div itemtype="http://schema.org/Product" itemscope="" class="zsg-hide"><meta itemprop="name" content="16312 SE 48th St, Bellevue, WA 98006"></meta><div itemprop="offers" itemscope="" itemtype="http://schema.org/Offer"><meta itemprop="priceCurrency" content="USD"></meta><meta itemprop="price" content="$679,500"></meta></div></div><div class="zsg-g zsg-g_gutterless"><div class="zsg-lg-1-1"><div class="zsg-content-item"><div><div id="map-tabs" class="hdp-tabbed-header prop-map-tabs has-photos  tabs-z"><div class="yui3-tabview-panel"><div id="birdseye" class="yui3-tab-panel"><div id="hdp-map-view-birdseye" class="hdp-map-view"><div class="hdp-map-view-map"></div><div class="rotate-container-large hide"><a class="rotate-left-large rotate-major-large" href="#"></a><a class="rotate-right-large rotate-major-large" href="#"></a></div><div class="zoom-container-large"><a class="zoom-in-large zoom-major-large" href="#"></a><a class="zoom-out-large zoom-major-large" href="#"></a></div></div></div><div id="map" class="yui3-tab-panel"><div id="hdp-map-view" class="hdp-map-view"><div class="hdp-map-view-map"></div><div class="rotate-container-large hide"><a class="rotate-left-large rotate-major-large" href="#"></a><a class="rotate-right-large rotate-major-large" href="#"></a></div><div class="zoom-container-large"><a class="zoom-in-large zoom-major-large" href="#"></a><a class="zoom-out-large zoom-major-large" href="#"></a></div></div></div><div id="photos" class="yui3-tab-panel"><div id="home-image-preview" class="clearfix carousel"><div itemtype="http://schema.org/ImageObject" itemscope="" id="hip-content" class="zsg-carousel carousel thumb_target"><span id="save-and-pin-block" class="save-and-pin middle hide"><div class="save-and-pin-wrapper"><a href="#hdp-photo-lightbox" class="show-lightbox za-track-event" data-za-category="Homes" data-za-action="Photo Lighbtox - Open" data-za-href="!ignore"><span class="pintest-item larger">View Larger </span></a></div></span><ol class="photos"><li class="current"><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><meta itemprop="contentLocation" content="Bellevue, WA 98006"></meta><meta itemprop="description" content="16312 SE 48th St,Bellevue, WA 98006 For Sale"></meta><meta itemprop="image" content="http://photos1.zillowstatic.com/p_h/ISpximk0uuc31d0000000000.jpg"></meta><meta itemprop="name" content="16312 SE 48th St, Bellevue, WA 98006"></meta><img src="http://photos1.zillowstatic.com/p_h/ISpximk0uuc31d0000000000.jpg" alt="16312 SE 48th St, Bellevue, WA 98006" id="X1-IA7iy7j0uuc31d0000000000_pa89t" class="hip-photo"></img><span class="zsg-image-caption zsg-image-caption_br view-larger-btn">View larger</span></a></li><li class=""><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><img src="http://photos1.zillowstatic.com/p_h/ISxfaulqxk1lvt1000000000.jpg" alt="16312 SE 48th St, Bellevue, WA 98006" id="X1-IAf0qfkqxk1lvt1000000000_klo15" class="hip-photo"></img><span class="zsg-image-caption zsg-image-caption_br view-larger-btn">View larger</span></a></li><li class=""><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><img alt="16312 SE 48th St, Bellevue, WA 98006" href="http://photos1.zillowstatic.com/p_h/IS9pdc563ixwum1000000000.jpg" id="X1-IAr9tx363ixwum1000000000_mea6v" class="hip-photo"></img><span class="zsg-image-caption zsg-image-caption_br view-larger-btn">View larger</span></a></li><li class=""><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><img alt="16312 SE 48th St, Bellevue, WA 98006" href="http://photos2.zillowstatic.com/p_h/ISp98i3ktctnvt1000000000.jpg" id="X1-IA7un32ktctnvt1000000000_kn2lm" class="hip-photo"></img><span class="zsg-image-caption zsg-image-caption_br view-larger-btn">View larger</span></a></li><li class=""><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><img alt="16312 SE 48th St, Bellevue, WA 98006" href="http://photos2.zillowstatic.com/p_h/IS1jb0nzy9pzum1000000000.jpg" id="X1-IAj3rllzy9pzum1000000000_mforc" class="hip-photo"></img><span class="zsg-image-caption zsg-image-caption_br view-larger-btn">View larger</span></a></li><li class=""><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><img alt="16312 SE 48th St, Bellevue, WA 98006" href="http://photos3.zillowstatic.com/p_h/ISh366ldp4lqvt1000000000.jpg" id="X1-IAznlrjdp4lqvt1000000000_koh63" class="hip-photo"></img><span class="zsg-image-caption zsg-image-caption_br view-larger-btn">View larger</span></a></li><li class=""><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><img alt="16312 SE 48th St, Bellevue, WA 98006" href="http://photos3.zillowstatic.com/p_h/IStc9o4tu1h2vm1000000000.jpg" id="X1-IAbxo93tu1h2vm1000000000_mh3bt" class="hip-photo"></img><span class="zsg-image-caption zsg-image-caption_br view-larger-btn">View larger</span></a></li><li class=""><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><img alt="16312 SE 48th St, Bellevue, WA 98006" href="http://photos1.zillowstatic.com/p_h/IS9x3u27lwctvt1000000000.jpg" id="X1-IArhjf17lwctvt1000000000_kpvqk" class="hip-photo"></img><span class="zsg-image-caption zsg-image-caption_br view-larger-btn">View larger</span></a></li><li class=""><span class="zsg-loading-spinner"></span><a data-za-href="!ignore" data-za-action="Photo Lightbox - Open" data-za-category="Homes" href="#hdp-photo-lightbox" title="View larger photos" class="show-lightbox za-track-event"><img alt="16312 SE 48th St, Bellevue, WA 98006" href="http://phot
><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="1"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="2"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="3"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="4"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="5"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="6"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="7"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="8"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="9"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="10"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="11"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="12"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="13"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="14"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="15"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="16"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="17"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="18"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="19"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="20"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li><li class="" data-thumbIndex="21"><span class="thumb-select"><span class="thumb-select-inner"></span></span></li></ol></div></div><span class="curtain-left hide"></span><span class="curtain-right"></span></div></li></ul></div></div></div></div></div><div role="main" class="hdp-content-wrapper zsg-content-section"><span data-ismobile="false" data-latitude="47.560442" id="hdp-map-coordinates" data-longitude="-122.122715" data-direction="http://maps.google.com/maps?daddr=16312+SE+48th+St+%2CBellevue%2C+WA+98006-4704&amp;f=d" data-mapmode="road" class="hide"></span><div class="zsg-lg-2-3 zsg-sm-1-1 hdp-header-description"><header class="zsg-content-header addr"> <h1>16312 SE 48th St, <span class="zsg-h2 addr_city">Bellevue, WA 98006</span> </h1> <h3 class="">  <span class="middle-dot" aria-hidden="true">&nbsp;</span><span class="addr_bbs">4 beds</span><span class="middle-dot" aria-hidden="true">&nbsp;</span><span class="addr_bbs">2.5 baths</span><span class="middle-dot" aria-hidden="true">&nbsp;</span><span class="addr_bbs">2,180 sqft</span>   </h3>  </header></div><div class="zsg-lg-1-3 mc-contact-wrapper"><div class="contact-position-wrapper"><div class="zsg-box zsg-content-item contact-wrapper full-c-col-only"><div id="contact-tall" class="ajax-form"><div class=" generic-box yui3-widget-stdmod module"><div class="module-body yui3-widget-bd clearfix"><div class="bal-refactor   featured ">  <h2 class="form-title">Contact Agent</h2>    <form id="lead-form_contact-tall" action="https://www.zillow.com/contact/ContactSubmit.htm" class="multi-zuid-select zsg-form validation-above contact-tall" method="get">    <div id="premier-tooltip-contact-tall" class="zsg-tooltip"><p> Premier Agents specialize in this area and can assist you in seeing a home or answer your questions. </p><p> Are you an agent looking for more exposure for yourself or your listings? Call Zillow at <span class="phone">866-324-4005</span></p></div>    <div class="column ">   <div class="signature-refactor has-pal " data-zuid="X1-ZUz2z8gewe87bd_6msnz"><div class="zsg-form-field zsg-form-field_checkbox sig-col ">   <div class="photo sig-col">   <a href="/profile/torij/">  <img alt="Profile picture for Tori Johnson" src="http://photos3.zillowstatic.com/h_n/ISz4zqs412yx7n.jpg" width="60px" height="60px" class="zsg-image-profile"/>   </a>  </div>  </div>      <div class="info flat-star-ratings sig-col">  <span class="snl name notranslate"><a href="/profile/torij/">Tori Johnson</a></span>    <span class="snl lender-rating-large">   <a href="/profile/torij/Reviews/" class="rating"><span class="zsg-rating r500 zsg-rating_500"></span></a>       <span class="reviews">(<a href="/profile/torij/Reviews/">7</a>)</span>   </span>   <span class="snl past-sales">  <a href="/profile/torij/"><span class="sales-count">27</span> Recent sales</a>   </span>    <span class="snl company-name">John L Scott Real Estate</span>      <span class="snl phone">(206) 430-5019 </span>       </div>   <span class='hide agent-type'>Premier Agent</span>    <span class='hide first-name'>Tori</span>   </div>     </div><div class="column ajax-form-content">   <div class="form-input-fields">   <div class="form-input contact-fields zsg-form-field field-name  "><input id="name_contact-tall" type="text" title="Please enter your name." placeholder="Your Name" name="name" required="required" value="Michael Hood" pattern=^[^!@#$%&amp;*+=]+$  ></div>  <div class="form-input contact-fields zsg-form-field field-phone  "><input id="phone_contact-tall" type="tel" title="Please enter a valid phone number, beginning with + for international numbers." placeholder="Phone" name="phone" required="required"   data-intl="true" maxlength="23"></div>  <div class="form-input contact-fields zsg-form-field field-email  "><input id="email_contact-tall" type="email" title="Please enter a valid email address." placeholder="Email" name="email" required="required" value="hoodmichaelallen@gmail.com"   ></div> <div class="form-input zsg-form-field form_textarea">  <textarea id="message_contact-tall" maxlength="500" rows="3" name="message" data-edited="0">I am interested in 16312 SE 48th St, Bellevue, WA 98006.</textarea>  </div></div>   <div class="lender-details form-input show-border lender-details-above">  <div class="form-preferred-lender pal-lender-box hdp-pal"> <div class="pals-tooltip"><a href="#preferred-lender-contact-tall" class="zsg-tooltip-launch zsg-icon-circle-question" data-placement="auto"></a><div id="preferred-lender-contact-tall" class="zsg-tooltip"><h4>What is a Premier Lender?</h4><p> The premier lender and the agent have a financial relationship and pay to advertise on this page. Zillow and the agents do not recommend or endorse any of the premier lenders. For more information on Zillow advertising practices, see Zillow’s Terms of Use &amp; Privacy. <a href="/comarketing/lender/" rel="nofollow" href="@">Learn more here</a></p></div></div> <div class="pal-signature-image">  <a href="/profile/Greg-Legas/"><img alt="Profile picture for Greg Legas" src="http://photos2.zillowstatic.com/h_b/IS9hf8dc28lkqq1000000000.jpg"></a></div><div class="pal-signature-info-list"><div class="preferred-lender-title">Premier Lender</div><div class="pal-lender-name"><a class="name" href="/profile/Greg-Legas/">Greg Legas</a></div><div class="pal-lender-phone">   (253) 431-2651     | NMLS 16690  </div></div></div>   <div class="zsg-form-field zsg-form-field_checkbox "><input id="preapproval-cb-contact-tall" class="preapproval_toggle lender_autocheck " type="checkbox" name="preapproval" value="true"  checked="checked"/><label for="preapproval-cb-contact-tall" id="preapproval-label" class="preapproval-label preapproval " for="preapproval-cb-contact-tall" data-edited="0">I want financing information   </label><div class="preapproval-enabled zsg-fineprint">A Zillow confirmed lender will contact you.</div></div>  </div>    <div class="form-input zsg-form-actions zsg-form-actions_collapsed "><p class="validation-above-messaging zsg-form-error-text"></p>  <button id="lead-form-submit-button_contact-tall" class="contact-submit zsg-button_primary" type="submit">Contact Agent</button>    </div>   </div>  <div class="hide">  <input type="hidden" name="variant" value="featured"/>  <input type="hidden" name="zpid" value="48749340"/>  <input type="hidden" name="mlsCode" value="811989"/>  <input type="hidden" name="onlyPreapprovalContact" value="false"/>  <input type="hidden" name="showNameField" value="true"/>  <input type="hidden" name="showPhoneField" value="true"/>  <input type="hidden" name="showPhoneMandatoryField" value="true"/>  <input type="hidden" name="palZuids" value="{&quot;X1-ZUz2z8gewe87bd_6msnz&quot;:&quot;X1-ZU10dt3ti60cd1l_68qz9&quot;}"/>  <input type="hidden" name="pcm" value="1"/>  <input type="hidden" name="subject" value="2"/>  <input type="hidden" name="pixelId" value="0ccf2066-c3ab-4efa-83be-aa3fb750013e"/>  <input type="hidden" name="formLocationType" value="41"/>  </div>  <div class='preapproval-info hide'><span class='property-value'>679500</span><span class='zipcode'>98006</span><span class='state-abbr'>WA</span></div>     </form>   <div class="tips"> <p><span class="zsg-tooltip-launch zsg-link bal-agent-upsell-trigger" data-target-id="bal-agent-upsell-tooltip-41"> Learn how to appear as the agent above </span></p><div class="zsg-tooltip" id="bal-agent-upsell-tooltip-41"> Want to learn more about appearing in the list of agents above? <a href="/feedback/AdvertiserSignup.htm?action=BAL+Popup+-+Inside&source=Agent+Leads&label=Contact+us+here" class="bal-agent-upsell-inside">Contact us here</a> or call us at 
            (855) 840-3292 </div> </div>  <div class="footer lead-form-footer ">   </div>    </div></div></div><div id="contact-tall-response" class="hide post-submit-upsell-response messaging"><div class="yui3-widget-hd"><h4>Contact Successful!</h4></div><div class="yui3-widget-bd"><p class="message"></p><div class="zmm-hdp-upsell-copy success zmm-upsell-msg default-zmm-msg"><div>Are you pre-approved already?</div><p>Find out how much house you can afford and get pre-approved for a mortgage in minutes.</p><ul><li><span class="fne icon"></span><span>Fast &amp; Easy</span></li><li><span class="tnl icon"></span><span>Top-Notch Lenders</span></li><li><span class="sns icon"></span><span>Safe &amp; Secure</span></li></ul><p class="button-wrapper"><a href="/mortgage-rates/" data-za-category="Mortgages" class="get-pre-approved-now button zsg-button_primary za-track-event" data-za-label="HDP:PostAgentContact" data-za-action="Upsell click"> Get Pre-Approved </a></p></div><div class="zmm-hdp-upsell-copy success zmm-upsell-msg pre-approved-zmm-msg lender-upsell-msg"><div>Next: Get Pre-Approved</div><p>A Lender can assist you with pre-approval process and answer any question you have.</p><p class="button-wrapper"><a class="button pre-approval-button zsg-button_primary">Yes, contact me</a></p></div><div class="zmm-hdp-upsell-copy success zmm-upsell-msg agent-lender-confirmation-zmm-msg thanks-pals-msg"><p>A Lender will also be calling you back to assist with pre-approval.</p><p><strong>Thanks for using Zillow!</strong></p></div><div class="zmm-hdp-upsell-copy success zmm-upsell-msg thanks-zmm-msg"><p>We'll send you an email with a link to get pre-approved on Zillow or you can get started by clicking below.</p><p class="button-wrapper"><a href="/mortgage-rates/" data-za-category="Mortgages" class="get-pre-approved-now button zsg-button_primary za-track-event" data-za-label="HDP:PostAgentContact" data-za-action="Upsell click"> Get Pre-Approved </a></p></div><div class="zmm-hdp-upsell-copy success zmm-upsell-msg pals-error-msg"><p>We weren't able to process your pre-approval request. Please go to Zillow Mortgage Marketplace directly by clicking below.</p><p class="button-wrapper"><a href="/mortgage-rates/" data-za-category="Mortgages" class="get-pre-approved-now button zsg-button_primary za-track-event" data-za-label="HDP:PostAgentContact" data-za-action="Upsell click"> Get Pre-Approved </a></p></div></div></div></div></div></div></div><div class="zsg-lg-2-3 hdp-summary"><div id="home-value-wrapper" class="   hotelCalifornia-wrapper "><div class="estimates">  <div class=" status-icon-row for-sale-row home-summary-row">  <span id="listing-icon" data-icon-class="zsg-icon-for-sale" class="zsg-icon-for-sale for-sale"></span>  For Sale <span class=""><span class="value-suffix"></span></span>     </div>  <div class="main-row  home-summary-row">   <span class="">$679,500<span class="value-suffix"></span></span>     </div>  <div class="price-cut-row  home-summary-row">  Price cut: <span class="">-$10,450<span class="value-suffix"></span></span>  <span class="home-value-hint">(9/2)</span>     </div>  <div class="  home-summary-row">   <span class="zsg-tooltip-launch zsg-tooltip-launch_keyword" data-target-id="zest-tip-hdp">Zestimate<sup>&reg;</sup>:</span>  <span class="">$680,819<span class="value-suffix"></span></span>     </div>     </div>  <span class="loan-calculator-label zsg-content_collapsed" aria-label="Estimated Mortgage">Est. Mortgage</span><div data-property-state="WA" data-property-value="679500" data-fixed-30-rate="3.737" data-property-tax-assessed-value="574000" data-property-tax-rate="0.0077" data-property-city="Bellevue" data-arm-5-rate="2.697" data-type="Single Family" data-property-zipcode="98006" id="loan-calculator-container" class="loan-calculator_loading" data-fixed-15-rate="2.913"><div class="zsg-loading-spinner"></div><div class="loan-calculator-loading-wrapper"><span class="loan-calculator-estimate"><span class="hlc-output-fixed30"></span><span aria-label="Per month">/mo</span></span><a class="zsg-menu-launch calculator-launch" data-horizontal-align="left" data-target-id="monthly-payment-options"><span class="zsg-icon-calculator"></span><span class="zsg-icon-arrow-menu-down"></span></a></div><div class="zsg-menu" id="monthly-payment-options"><h4 class="zsg-menu-header">Estimated Monthly Payment</h4><div class="zsg-menu-content zsg-form"><div class="zsg-separator zsg-form_right zsg-form_right-1-2"><div class="zsg-form-field"><label for="hlc-input-price">Price</label><div class="zsg-input-overlay_left zsg-form-size-l"><div class="zsg-input-overlay-text_left">$</div><input type="text" id="hlc-input-price"/></div><p class="zsg-form-error-text">Please enter a dollar amount between $0 and $200,000,000</p></div><div class="zsg-form-field"><label for="hlc-input-down-payment-percent">Down payment</label><div class="hlc-input-down-payment-percent-container"><input type="text" id="hlc-input-down-payment-percent"/></div><span class="zsg-form-help-text">(<span class="hlc-output-down-payment"></span>)</span><p class="zsg-form-error-text">Please enter a percent between 0% and 100%</p></div><div><a href="/mortgage-calculator/" target="_blank">Advanced calculator <span class="zsg-icon-pop-up"></span></a></div></div><div class="zsg-separator"><div class="hlc-outputs zsg-content-item zsg-g"><div class="zsg-lg-1-2">30 Year Fixed:</div><div class="zsg-lg-1-2"><span class="hlc-output-rate hlc-output-fixed30"></span><span aria-label="Per month">/mo</span></div><div class="zsg-lg-1-2">15 Year Fixed:</div><div class="zsg-lg-1-2"><span class="hlc-output-rate hlc-output-fixed15"></span><span aria-label="Per month">/mo</span></div><div class="zsg-lg-1-2">5/1 ARM:</div><div class="zsg-lg-1-2"><span class="hlc-output-rate hlc-output-arm5"></span><span aria-label="Per month">/mo</span></div></div><span class="zsg-fineprint">Estimated taxes &amp; insurance of <span class="hlc-output-taxes-and-insurance"></span> are not included.</span></div><a class="zmm-shopping-link zsg-button_primary za-track-event" data-za-category="Mortgages" data-za-action="Upsell click" data-za-label="HDP:HeaderLoanCalculator">See current rates</a><span> On </span><a class="zmm-shopping-link za-track-event" data-za-category="Mortgages" data-za-action="Upsell click" data-za-label="HDP:HeaderLoanCalculator"><span class="zmm-logo-color"></span></a></div></div></div><div class="partner-link prop-value-mortgage-ad"><a href="/mortgage-rates/?auto=true&value=679500&zip=98006" class="za-track-event zmm-shopping-link" data-za-category="Mortgages" data-za-action="Upsell click" data-za-label="!zmm" data-zmm-component="See current rates">See current rates</a></div><div class="partner-link prop-value-ad"><div style="display: none;" data-frame-id="gpt-ad-3bd278aa-ce28-4f4c-8e30-59fccd17ab2a" id="gpt-ad-3bd278aa-ce28-4f4c-8e30-59fccd17ab2a-config" class="google-ad-config">{"targetDiv":"gpt-ad-3bd278aa-ce28-4f4c-8e30-59fccd17ab2a","slot":"zillow/property_details/buy_agent/t_main_p1","network":"7449","sizes":"[256,13]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","yrblt":"1980-1989","zestimate":"680819","ab_zmm_upsell":"SEE_CURRENT_RATES","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":false,"explicit_defer_ad":false}</div><div id="gpt-ad-3bd278aa-ce28-4f4c-8e30-59fccd17ab2a" class="deferred-iframe-target"></div></div>  </div><div id="zest-tip-hdp" class="zsg-tooltip"><div id="zestimate-tip-table"><p> A <strong>Zestimate&reg;</strong> home valuation is Zillow's estimated market value. It is not an appraisal. Use it as a starting point to determine a home's value. <a href="/wikipages/What-is-a-Zestimate/" href="#">Learn more</a></p><p> If your home facts are wrong this will cause an incorrect Zestimate, <a href="/editing/EditHomeFacts.htm?cid=1442206872374&amp;entry=false&amp;section=HomeFacts&amp;zpid=48749340">click here to update them</a>. </p></div></div></div><!--Direct hit only. Magic Carpet transitions are profiled through YUI in the app transition--><section class="zsg-content-section narrow-two-column-facts"><div class="zsg-lg-1-1 hdp-header-description"><div id="home-description-fav-note" class="hide zsg-content-component zsg-annotation-area prop-mod prop-notes"><h4>My Notes</h4><span id="fav-note-text" data-zpid="48749340" class="prop-mod-bd"></span><span class="prop-notes-edit edit-note"><a id="edit-note-btn" class="show-lightbox" href="#add-note-code"> Edit</a></span></div><div class="zsg-content-component"><div class="notranslate">This 4 bdrm is perfectly located near churches, grocery, parks, Newcastle Golf Course &amp; freeway access and on a corner lot. A beautiful pergola &amp; river rock wall along w/easy to care wooded yard/patio &amp; fruit trees make this your perfect hideaway! Cool lower level family rm w/a wall of windows &amp; access to patio. You'll love the granite counters, window above the sink, open style kitchen/eating bar. The unique master is awesome: double sinks/granite counters, walk-in closet and a sunken bedroom!</div></div></div><div class="hdp-facts zsg-content-component z-moreless"><div class="fact-group-container zsg-content-component top-facts"><h4 itemprop="category" class="zsg-content_collapsed">Facts</h4><ul class="zsg-list_square zsg-lg-1-2 zsg-sm-1-1"><li>Lot: 9,147 sqft</li><li>Single Family</li><li>Built in 1985</li><li>66 days on Zillow</li><li>Views: 5,262 all time views</li></ul><ul class="zsg-list_square zsg-lg-1-2 zsg-sm-1-1"><li>40 shoppers saved this home</li><li>Heating: Forced air</li><li>Last sold: Apr 2008 for $530,000</li><li>Price/sqft: $312</li><li>MLS #: 811989</li></ul></div><div class="fact-group-container zsg-content-component top-facts"><h4 itemprop="category" class="zsg-content_collapsed">Features</h4><ul class="zsg-list_square zsg-lg-1-2 zsg-sm-1-1"><li>Finished basement, 480 sqft</li><li>Fireplace</li><li>Flooring: Hardwood</li><li>Lawn</li></ul><ul class="zsg-list_square zsg-lg-1-2 zsg-sm-1-1"><li>Parking: Garage - Attached, 100 sqft</li><li>Patio</li><li>Skylight</li><li>Vaulted Ceiling</li></ul></div><div class="fact-group-container zsg-content-component z-moreless-content hide"><h4 itemprop="category" class="zsg-content_collapsed">Appliances Included</h4><ul class="zsg-list_square zsg-lg-1-2 zsg-sm-1-1"><li>Dishwasher</li><li>Dryer</li><li>Garbage disposal</li><li>Microwave</li><li>Range / Oven</li><li>Refrigerator</li><li>Washer</li></ul></div><div class="fact-group-container zsg-content-component z-moreless-content hide"><h4 itemprop="category" class="zsg-content_collapsed">Room Types</h4><ul class="zsg-list_square zsg-lg-1-2 zsg-sm-1-1"><li>Walk-in closet</li></ul></div><div class="fact-group-container zsg-content-component z-moreless-content hide"><h4 itemprop="category" class="zsg-content_collapsed">Construction</h4><ul class="zsg-list_square zsg-lg-1-2 zsg-sm-1-1"><li>Roof type: Composition</li><li>Stories: 2</li><li>Unit count: 1</li></ul></div><div class="fact-group-container zsg-content-component z-moreless-content hide"><h4 itemprop="category" class="zsg-content_collapsed">Other</h4><ul class="zsg-list_square zsg-lg-1-2 zsg-sm-1-1"><li>Floor size: 2,180 sqft</li><li>Last remodel year: 2006</li><li>Laundry: In Unit</li><li>Parcel #: 1687910030</li><li>Zillow Home ID: 48749340</li></ul></div><div class="prop-fact-links zsg-content-component"><div class="zsg-g_gutterless"><div class="zsg-lg-1-1"><a class="z-moreless-toggle z-moreless-content za-track-event" data-za-category="Homes" data-za-action="Expand Section" data-za-label="Facts">More <span class="zsg-icon-expando-down"></span></a><a class="z-moreless-toggle z-moreless-content hide za-track-event" data-za-category="Homes" data-za-action="Expand Section" data-za-label="Facts">Less <span class="zsg-icon-expando-up"></span></a><span class="additional-links"><span class="county-link"><a data-za-action="CountyLink" rel="nofollow" data-za-category="CountyLink" href="http://www.zillow.com/CountyAssessorPage.htm?COUNTY_ID=53033&amp;FORCE_GENERIC=false&amp;LINK_LOCATION=Description&amp;PARCEL_NUM=1687910030" class="za-track-event" data-za-label="Description" target="_blank">County website</a></span><span class="data-sources"><a href="#home-facts-comparison" class="za-track-event show-lightbox" data-za-category="Homes" data-za-action="See Data Sources Link" data-za-href="!ignore"><span class="zbt"></span>See data sources</a></span></span></div></div></div></div></section><section class="zsg-content-section  collapsible collapsed"><h2 data-module="zestimate">Zestimate Details</h2><div class="zsg-content-component">    <div class="zest-container"><div class="zsg-g ">  <div class="zest zsg-lg-1-3 zsg-md-1-1"><div class="zest-inner"><div class="zsg-g_gutterless zest-content"><div class="zsg-lg-1-1 zsg-md-1-2"><div class="zest-title">Zestimate <span data-target-id="zest-tip-table" class="zsg-tooltip-launch zsg-icon-circle-question"></span><div class="zsg-tooltip" id="zest-tip-table"> A <strong>Zestimate</strong> home valuation is Zillow's estimated market value. It is not an appraisal. Use it as a starting point to determine a home's value. <a href="/wikipages/What-is-a-Zestimate/" href="#">Learn more</a><br/><br/> The <strong>Value Range</strong> is the high and low estimate market value for which Zillow values a home. The more information, the smaller the range, and the more accurate the Zestimate. <a href="/howto/DataCoverageZestimateAccuracy.htm" href="#">See data coverage and accuracy table</a><br/><br/><strong>Don't agree with your home's Zestimate?</strong> Owners can  edit their home facts  to make the Zestimate more accurate. Plus, you can leave an opinion on your Zestimate value below. Just click "Owner Estimate". </div></div><div class="zest-value">$680,819</div>  <div class="zest-change"><span class="zest-change-value ">+$3,268</span><span class="zsg-fineprint"> Last 30 days</span></div>  </div><div class="zsg-lg-1-1 zsg-md-1-2"><div class="zest-range"><div class="zest-range-bar zsg-fineprint"><span class="zest-range-bar-low">$647K</span><div class="zest-range-bar-sep" style="left: 50%"></div><span class="zest-range-bar-high">$715K</span></div><div class="zest-range-caption zsg-fineprint">Zestimate range</div></div></div>  </div></div></div>  <div class="zest zsg-lg-1-3 zsg-md-1-1"><div class="zest-inner"><div class="zsg-g_gutterless zest-content"><div class="zsg-lg-1-1 zsg-md-1-2"><div class="zest-title">Rent Zestimate <span data-target-id="rzest-tip-table" class="zsg-tooltip-launch zsg-icon-circle-question"></span><span class="zsg-tooltip" id="rzest-tip-table"> A <strong>Rent Zestimate</strong> is Zillow's estimated monthly rental price, computed using a proprietary formula. It is a starting point in determining the monthly rental price for a specific property. <a href="/wikipages/What-is-a-Rent-Zestimate/" href="#">Learn more</a><br/><br/> The <strong>Rent Range</strong> is the high and low estimate for which an apartment or home could rent. The more information we have, the smaller the range, and the more accurate the Rent Zestimate. <a href="/howto/DataCoverageRentZestimateAccuracy.htm" href="#">See data coverage and accuracy table</a></span></div><div class="zest-value">$2,750/mo</div>  <div class="zest-change"><span class="zest-change-value ">+$50</span><span class="zsg-fineprint"> Last 30 days</span></div>  </div><div class="zsg-lg-1-1 zsg-md-1-2"><div class="zest-range"><div class="zest-range-bar zsg-fineprint"><span class="zest-range-bar-low">$2.5K</span><div class="zest-range-bar-sep" style="left: 37%"></div><span class="zest-range-bar-high">$3.3K</span></div><div class="zest-range-caption zsg-fineprint">Zestimate range</div></div></div>  </div></div></div>    <div class="zest zsg-lg-1-3 zsg-md-1-1 "><div class="zest-inner"><div class="zsg-g_gutterless zest-content"><div class="zsg-lg-1-1 zsg-md-1-2"><div class="zest-title">Zestimate forecast <span data-target-id="zest-forecast-tip" class="zsg-tooltip-launch zsg-icon-circle-question"></span><span class="zsg-tooltip" id="zest-forecast-tip"> The <strong>Zestimate forecast</strong> is a prediction of a home's Zestimate&reg; home value one year from now, based on current home and market information. Use it as a starting point to estimate this home's future value. <a href="/help/zestimate-forecast/" href="#">Learn more</a></span></div><div class="zest-value">$702,878</div></div><div class="zest-forecast zsg-lg-1-1 zsg-md-1-2"><span class="zsg-icon-circle-arrow-up "></span><div class="zest-forecast-change"><div class="zest-forecast-change-percent">+3.2%</div><div class="zsg-fineprint">One year</div></div></div>   </div></div></div>   </div></div><div class="zsg-g">  </div></div><div id="hdp-home-value-chart" class="clearfix zsg-content-component"><div id="paparazzi-chart"><div id="hdp-metric-filter" class="hdp-chart-filters chart-metrics"><div class="zsg-toolbar"><ul class="zsg-toolbar-left"><li><a href="#home-value-chart-menu" class="zsg-menu-launch zsg-toolbar-button zsg-button"><span id="home-value-chart-dropdown">Zestimate&nbsp;</span><span class="zsg-icon-arrow-menu-down"></span></a></li></ul><ul class="zsg-toolbar-right"><li class="time-period"><ul class="zsg-toolbar-tabs zsg-tabs"><li class="month hide"><a id="tp-month" class="time">1 month</a></li><li class="year"><a id="tp-year" class="time">1 year</a></li><li class="five-years"><a id="tp-fiveYears" class="time">5 years</a></li><li class="ten-years"><a id="tp-tenYears" class="time">10 years</a></li></ul></li></ul></div><div class="zsg-menu" id="home-value-chart-menu"><ul class="zsg-menu-linklist"><li><a id="mt-1" class="metric" data-chart-img="http://ppz.zillowstatic.com:80/hdp_chart/render.png?v=2&amp;zpid=48749340&amp;m=1&amp;t=tenYears&amp;size=standard&amp;showForecast=true&amp;signedIn=true&amp;h=qwogczMDE%2BUalcCX8suV%2B5d4P69NX6ciOVEEBsnvbcw%3D">Zestimate</a></li><li><a id="mt-3" class="metric" data-chart-img="http://ppz.zillowstatic.com:80/hdp_chart/render.png?v=2&amp;zpid=48749340&amp;m=3&amp;t=tenYears&amp;size=standard&amp;showForecast=true&amp;signedIn=true&amp;h=qwogczMDE%2BUalcCX8suV%2B5d4P69NX6ciOVEEBsnvbcw%3D">Listing price</a></li><li><a id="mt-9" class="metric" data-chart-img="http://ppz.zillowstatic.com:80/hdp_chart/render.png?v=2&amp;zpid=48749340&amp;m=9&amp;t=tenYears&amp;size=standard&amp;showForecast=true&amp;signedIn=true&amp;h=qwogczMDE%2BUalcCX8suV%2B5d4P69NX6ciOVEEBsnvbcw%3D">Rent Zestimate</a></li><li><a id="mt-2" class="metric" data-chart-img="http://ppz.zillowstatic.com:80/hdp_chart/render.png?v=2&amp;zpid=48749340&amp;m=2&amp;t=tenYears&amp;size=standard&amp;showForecast=true&amp;signedIn=true&amp;h=qwogczMDE%2BUalcCX8suV%2B5d4P69NX6ciOVEEBsnvbcw%3D">Zestimate (% change)</a></li><li><a id="mt-4" class="metric" data-chart-img="http://ppz.zillowstatic.com:80/hdp_chart/render.png?v=2&amp;zpid=48749340&amp;m=4&amp;t=tenYears&amp;size=standard&amp;showForecast=true&amp;signedIn=true&amp;h=qwogczMDE%2BUalcCX8suV%2B5d4P69NX6ciOVEEBsnvbcw%3D">Tax assessment</a></li><li><a id="mt-5" class="metric" data-chart-img="http://ppz.zillowstatic.com:80/hdp_chart/render.png?v=2&amp;zpid=48749340&amp;m=5&amp;t=tenYears&amp;size=standard&amp;showForecast=true&amp;signedIn=true&amp;h=qwogczMDE%2BUalcCX8suV%2B5d4P69NX6ciOVEEBsnvbcw%3D">Tax paid</a></li><li><a id="mt-6" class="metric" data-chart-img="http://ppz.zillowstatic.com:80/hdp_chart/render.png?v=2&amp;zpid=48749340&amp;m=6&amp;t=tenYears&amp;size=standard&amp;showForecast=true&amp;signedIn=true&amp;h=qwogczMDE%2BUalcCX8suV%2B5d4P69NX6ciOVEEBsnvbcw%3D">Page views</a></li></ul></div></div><div class="fig-spinner"><div class="zsg-loading-spinner_lg"></div><p>Loading chart...</p></div><div id="fig"><div id="paparazzi-legend" class="legend"><table><tbody class="legendBody"></tbody></table></div><div id="chart"><a href="/search/ResurrectionSearchPageWithHomeDetail,initialHomeDetailComponent.$homedetail$HomeValueChart.$links$RegisterLink.sdirect?form:search/ResurrectionSearchPageWithHomeDetail=ZH4sIAAAAAAAAALVUPW8TQRCdM6TgI1ICEkUEEoXrEyAKGiQSImSLyERcpEQWBeu9ib1mb2czu%2BfDDYIGClroKCgo81coqWgQDRW0SFTs5bAhyFKkXNzcaefrzXs7s%2FvfYaHIAGApgu2mQ8Fy0EwOfpuij%2FeIPHIcHBSs1KFEMmn9xyyFIaOk0BvKPHEJ8khJjIekzLpilJ54XHpg0SI75TymCbG3
="left: 48.43559277514253%" data-zpid="48781378" class="comps-price-graph-home_placeholder"></div><div data-price="685000" style="left: 50.75323310826471%" data-zpid="48730805" class="comps-price-graph-home_placeholder"></div><div data-price="692500" style="left: 53.65028352466742%" data-zpid="48785617" class="comps-price-graph-home_placeholder"></div><div data-price="695000" style="left: 54.61596699680166%" data-zpid="49129862" class="comps-price-graph-home_placeholder"></div><div data-price="737000" style="left: 70.83944932865684%" data-zpid="49129844" class="comps-price-graph-home_placeholder"></div><div class="comps-price-graph-boundary_right"><div class="comps-price-graph-boundary-value">$820K</div></div></div></div><ul id="comps-links"><a href="/homes/comps_for_sale/48749340_zpid/" class="noroute"><li id="fs-comps-link"><div class="comps-link-text"><h4 class="zsg-content_collapsed">For Sale</h4><div class="comps-link-sub-text">Comparable homes</div></div><div class="zsg-icon-expando-right"></div></li></a><a href="/homes/comps/48749340_zpid/" class="noroute"><li id="rs-comps-link"><div class="comps-link-text"><h4 class="zsg-content_collapsed">Recently Sold</h4><div class="comps-link-sub-text">Comparable homes</div></div><div class="zsg-icon-expando-right"></div></li></a></ul></section><input id="mobileWebInput" type="hidden" value="false"></input><section id="seller-metrics" class="zsg-content-section collapsible collapsed"><h2>Popularity on Zillow</h2><div class="zsg-notification-text-confirmation zsg-separator"><strong>Trending!</strong> This home is one of the top 10% most visited in the neighborhood this week. </div><div class="seller-metric-old zsg-md-1-1 seller-metrics-block zsg-lg-1-2 zsg-separator_secondary"><div class="seller-metrics-icon"><div class="zsg-icon-eye"></div></div><div class="seller-metrics-text"><header class="seller-metrics-header"><strong>4,880 views since listing</strong></header><div>5,262 all-time (<a href="#" class="seller-metrics-chart-link">chart</a>) </div><div class="zsg-fineprint"></div></div></div><div class="seller-metric-old zsg-md-1-1 seller-metrics-block zsg-lg-1-2 zsg-separator_secondary"><div class="seller-metrics-icon"><div class="zsg-icon-heart-filled"></div></div><div class="seller-metrics-text"><header class="seller-metrics-header"><strong>40 shoppers saved</strong></header><div>this home to their list of favorites</div><div class="zsg-fineprint"></div></div></div></section><section id="hdp-mortgage-module-desktop" class="zsg-content-section  collapsible collapsed"><div class="zmm-api-config template hide"><!--{"zipcode":"98103","abs":{"MortgageAdvertise":"Control","MortgageMobileHDPUpsell":"GET_PREAPPROVED_ON_ZILLOW","MortgageStackNouveau":"CLIENT","MortgageSubnav":"FIND_A_LENDER","MortgagePreapprovalFlow":"MULTI_STEP_CREDIT_ASK_CONTACT_BEFORE_DOWN_NO_LENDER_SELECTION","MortgageMobilePreApproval":"PreApproval_OFF","MortgageResponsiveShopping":"ENABLED","MortgageUpsellTestingHDP":"SEE_CURRENT_RATES"},"stateAbbreviation":"WA","partnerId":"RD\-FVBXMBZ","userSessionId":"228b2902\-29f2\-40f7\-9544\-4faef9f09c9f","serverURLs":{"MIN":"https://www.zillow.com/mortgage/service/min","MAX":"https://mortgageapi.zillow.com","MCA":"http://mortgagechart.zillow.com"},"user":{"authenticated":false,"firstName":"Michael","lastName":"Hood","lender":false,"emailAddress":"hoodmichaelallen@gmail.com","logon":"hoodmichaelallen@gmail.com","admin":false,"id":"ZUxmuzyoen0tmx_17jmc"}}--></div><div data-quotes="true" data-purpose="Purchase" data-price="679500" id="zmm-mortgage-module-data" data-type="Single Family" data-zpid="48749340" data-zip="98006"></div><h2 data-module="mortgage">Mortgages</h2><a class="zmm-logo-color" href="/mortgage-rates/"></a><div id="hdp-mortgage-module" class="loading"><div class="zsg-loading-spinner_lg"></div></div></section><section id="home-other-costs" class="zsg-content-section oc-desktop hidden  collapsible collapsed"><h2 class="zsg-separator">Home Expenses</h2><div class="zsg-content-component"><div id="other-costs-list"><div class="details zsg-separator row open load-check"><div class="description zsg-h4">Internet, phone and TV</div><div class="vendor-inline"><div style="display: none;" data-frame-id="gpt-ad-f78680cf-ff4d-476e-a442-c9a1813ce973" id="gpt-ad-f78680cf-ff4d-476e-a442-c9a1813ce973-config" class="google-ad-config">{"targetDiv":"gpt-ad-f78680cf-ff4d-476e-a442-c9a1813ce973","slot":"zillow/property_details/buy_agent/c_main_p1","network":"7449","sizes":"[400,20]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","zcredit":"bad","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":true,"explicit_defer_ad":true,"load_event":"deferred:otherCostsIframe","show_override":"telecom"}</div><div id="gpt-ad-f78680cf-ff4d-476e-a442-c9a1813ce973" class="deferred-iframe-target"></div><input data-frame-id="gpt-ad-f78680cf-ff4d-476e-a442-c9a1813ce973" id="gpt-ad-f78680cf-ff4d-476e-a442-c9a1813ce973-rendered" type="hidden" value="false" class="explicitly-deferred-ad" data-url=""></input></div><span class="expander zsg-icon-expando-down" data-load-class="explicitly-deferred-ad-telecom" data-za-label="telecom"></span><div class="vendor-detail"><div style="display: none;" data-frame-id="gpt-ad-acb22b1d-20e2-40bf-ab20-de902c80ac55-telecom" id="gpt-ad-acb22b1d-20e2-40bf-ab20-de902c80ac55-telecom-config" class="google-ad-config">{"targetDiv":"gpt-ad-acb22b1d-20e2-40bf-ab20-de902c80ac55-telecom","slot":"zillow/property_details/buy_agent/c_coho_p1","network":"7449","sizes":"[630,188]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","zcredit":"bad","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":false,"explicit_defer_ad":true,"load_event":"deferred:otherCostsDetailIframe-telecom"}</div><div id="gpt-ad-acb22b1d-20e2-40bf-ab20-de902c80ac55-telecom" class="deferred-iframe-target"></div><input data-frame-id="gpt-ad-acb22b1d-20e2-40bf-ab20-de902c80ac55-telecom" id="gpt-ad-acb22b1d-20e2-40bf-ab20-de902c80ac55-telecom-rendered" type="hidden" value="false" class="explicitly-deferred-ad" data-url=""></input></div></div><div class="details zsg-separator row open load-check"><div class="description zsg-h4">Home security</div><div class="vendor-inline"><div style="display: none;" data-frame-id="gpt-ad-b74247a1-e7e6-4ac9-9155-2ffc9ab954c7" id="gpt-ad-b74247a1-e7e6-4ac9-9155-2ffc9ab954c7-config" class="google-ad-config">{"targetDiv":"gpt-ad-b74247a1-e7e6-4ac9-9155-2ffc9ab954c7","slot":"zillow/property_details/buy_agent/c_main_p3","network":"7449","sizes":"[400,20]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","zcredit":"bad","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":true,"explicit_defer_ad":true,"load_event":"deferred:otherCostsIframe","show_override":"security"}</div><div id="gpt-ad-b74247a1-e7e6-4ac9-9155-2ffc9ab954c7" class="deferred-iframe-target"></div><input data-frame-id="gpt-ad-b74247a1-e7e6-4ac9-9155-2ffc9ab954c7" id="gpt-ad-b74247a1-e7e6-4ac9-9155-2ffc9ab954c7-rendered" type="hidden" value="false" class="explicitly-deferred-ad" data-url=""></input></div><span class="expander zsg-icon-expando-down" data-load-class="explicitly-deferred-ad-security" data-za-label="security"></span><div class="vendor-detail"><div style="display: none;" data-frame-id="gpt-ad-f7d68cac-dd31-4568-80c0-e8a4233e2f76-security" id="gpt-ad-f7d68cac-dd31-4568-80c0-e8a4233e2f76-security-config" class="google-ad-config">{"targetDiv":"gpt-ad-f7d68cac-dd31-4568-80c0-e8a4233e2f76-security","slot":"zillow/property_details/buy_agent/c_coho_p3","network":"7449","sizes":"[630,188]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","zcredit":"bad","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":false,"explicit_defer_ad":true,"load_event":"deferred:otherCostsDetailIframe-security"}</div><div id="gpt-ad-f7d68cac-dd31-4568-80c0-e8a4233e2f76-security" class="deferred-iframe-target"></div><input data-frame-id="gpt-ad-f7d68cac-dd31-4568-80c0-e8a4233e2f76-security" id="gpt-ad-f7d68cac-dd31-4568-80c0-e8a4233e2f76-security-rendered" type="hidden" value="false" class="explicitly-deferred-ad" data-url=""></input></div></div><div class="details zsg-separator row open load-check"><div class="description zsg-h4">Home Insurance</div><div class="vendor-inline"><div style="display: none;" data-frame-id="gpt-ad-b85bb1c8-dc64-4099-96fb-dfa0587fbfcd" id="gpt-ad-b85bb1c8-dc64-4099-96fb-dfa0587fbfcd-config" class="google-ad-config">{"targetDiv":"gpt-ad-b85bb1c8-dc64-4099-96fb-dfa0587fbfcd","slot":"zillow/property_details/buy_agent/c_main_p2","network":"7449","sizes":"[400,20]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","zcredit":"bad","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":true,"explicit_defer_ad":true,"load_event":"deferred:otherCostsIframe","show_override":"insurance"}</div><div id="gpt-ad-b85bb1c8-dc64-4099-96fb-dfa0587fbfcd" class="deferred-iframe-target"></div><input data-frame-id="gpt-ad-b85bb1c8-dc64-4099-96fb-dfa0587fbfcd" id="gpt-ad-b85bb1c8-dc64-4099-96fb-dfa0587fbfcd-rendered" type="hidden" value="false" class="explicitly-deferred-ad" data-url=""></input></div><span class="expander zsg-icon-expando-down" data-load-class="explicitly-deferred-ad-insurance" data-za-label="insurance"></span><div class="vendor-detail"><div style="display: none;" data-frame-id="gpt-ad-6f07ca96-31a6-4f7f-91eb-f585838b9651-insurance" id="gpt-ad-6f07ca96-31a6-4f7f-91eb-f585838b9651-insurance-config" class="google-ad-config">{"targetDiv":"gpt-ad-6f07ca96-31a6-4f7f-91eb-f585838b9651-insurance","slot":"zillow/property_details/buy_agent/c_coho_p2","network":"7449","sizes":"[630,188]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","zcredit":"bad","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":false,"explicit_defer_ad":true,"load_event":"deferred:otherCostsDetailIframe-insurance"}</div><div id="gpt-ad-6f07ca96-31a6-4f7f-91eb-f585838b9651-insurance" class="deferred-iframe-target"></div><input data-frame-id="gpt-ad-6f07ca96-31a6-4f7f-91eb-f585838b9651-insurance" id="gpt-ad-6f07ca96-31a6-4f7f-91eb-f585838b9651-insurance-rendered" type="hidden" value="false" class="explicitly-deferred-ad" data-url=""></input></div></div><div class="details zsg-separator row open static-row hidden"><div class="description zsg-h4">Property tax</div><div class="vendor-inline"><span class="vendor-name"><a data-za-action="CountyLink" rel="nofollow" data-za-category="CountyLink" href="http://www.zillow.com/CountyAssessorPage.htm?COUNTY_ID=53033&amp;FORCE_GENERIC=false&amp;LINK_LOCATION=OtherCosts&amp;PARCEL_NUM=1687910030" class="za-track-event" data-za-label="OtherCosts" target="_blank">County website</a></span><span class="vendor-cost"><strong>$5,575</strong>/yr</span></div></div></div></div></section><div id="other-costs-scroll-tracker"></div><section id="hdp-neighborhood" class="zsg-content-section  collapsible collapsed"><h2>Neighborhood: Somerset</h2><div class="zsg-content-component"><div class="za-track-event zsg-content-component notranslate" data-za-category="Homes" data-za-action="Market Guide - expand">Zillow predicts  <a href="http://www.zillow.com/somerset-bellevue-wa/home-values/">Somerset home values</a> will increase 8.2% next year, compared to a 8.6% increase for Bellevue as a whole. Among Somerset homes, this home is 12.2% less expensive than the midpoint (median) home, but is priced 10.3% more per square foot.<br><br>Foreclosures will be a factor impacting home values in the next several years.  In Somerset, the number of foreclosures waiting to be sold is 32.1% lower than in Bellevue, and 47.6% less than the national average. This lower local number could help Somerset home values rise more quickly than other regions in Bellevue.</div><h4>Nearby</h4><div class="homeMarkerData template hide"><!--["HouseSmallRed","http://photos1.zillowstatic.com/p_a/ISpximk0uuc31d0000000000.jpg",47560442,\-122122715]--></div><div id="neighborhood-map"><div id="inner-map-container"><div id="map-menu-container"><input id="photo-bubble-enabled" type="hidden" value="true"></input><div id="map-view-type-control" class="map-view-type-control"><form action=""><ul id="map-view-types" class="zsg-tabs"><li><input name="HDPMapType" checked="checked" id="show-Zestimates" type="radio" class="radio clickable"></input><label for="show-Zestimates" class="clickable map-view-type-label selected">Home Values</label></li><li><input name="HDPMapType" id="show-Listings" type="radio" class="radio clickable"></input><label for="show-Listings" class="clickable map-view-type-label">Listings</label></li></ul></form></div><div class="map-message loading hide"></div></div><div id="map-view" class="hdp-list map-view zsg-lg-1-1"><div id="map-container" class="map-container"><div id="hdp-map-parent-container" class="map-parent-container"></div></div><div class="zsg-g"><ul id="walkscore-target" class="walkscore zsg-lg-2-3"></ul><ul class="zsg-lg-1-3 related-map-links"><li><span data-za-action="Nearby homes toggle" class="show-nearby-homes zsg-link hide">List of nearby homes</span></li></ul></div></div><div class="zsg-g"><div id="hdp-listings-list" class="zsg-lg-1-1 hdp-listings-wrap hide"><div id="hdp-listings-forsale" class="zsg-lg-1-2 zsg-sm-1-1 listings-for-sale hdp-listings-list yui3-toggle-content-maximized"><h4 class="forSale hdp-list-header"><span class="zsg-icon-for-sale"></span>For Sale</h4><ul id="ForSale-hdp-list-results" class="hdp-list-column"><li id="zpid_48749367" class="hdp-list-result "><div class="property-info"><div class="home-photo"><div class="photo-container"><a href="/homedetails/16217-SE-48th-St-Bellevue-WA-98006/48749367_zpid/"><img alt="16217 SE 48th St" href="http://photos1.zillowstatic.com/p_a/ISlut1oylobuhz0000000000.jpg" class="hdp-listing-img"></img><span class="hdp-list-price">
map-control-container z-map-button location-control"><a href="#" class="map-control z-map-button-icon commute-enable-button square pair-top" title="Enable Commute Info" data-value="commuteEnable"><div class="commute-enable zsg-icon-car"></div></a><a href="#" class="map-control z-map-button-icon commute-add-button square" title="Drop a new pin" data-value="commuteAdd"><div class="commute-add zsg-icon-car-plus"></div></a></div></div><div style="display: none;" data-frame-id="gpt-ad-0455cb55-ae7b-4d1e-96a8-a318a1afe075" id="gpt-ad-0455cb55-ae7b-4d1e-96a8-a318a1afe075-config" class="google-ad-config">{"targetDiv":"gpt-ad-0455cb55-ae7b-4d1e-96a8-a318a1afe075","slot":"zillow/property_details/buy_agent/t_nhood_p1","network":"7449","sizes":"[560,25]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","zcredit":"bad","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":false,"explicit_defer_ad":false}</div><div id="gpt-ad-0455cb55-ae7b-4d1e-96a8-a318a1afe075" class="deferred-iframe-target"></div></div></section><section id="nearbySchools" class="zsg-content-section  collapsible collapsed"><h2 data-tracking-label="Nearby Schools"><span> Nearby Schools  in <span class="notranslate">Bellevue</span></span></h2><div id="gs-rating-tip" class="zsg-tooltip">
    <div>
        <p>GreatSchools ratings give an overview of a school's test results. The ratings are based on a comparison of test results for all schools in the state.</p>
        <p><strong>Disclaimer:</strong> School attendance zone boundaries are supplied by <a href="http://www.maponics.com/" rel="nofollow" target="_blank">Maponics</a> and are subject to change. Check with the applicable school district prior to making a decision based on these boundaries.</p>
    </div>
</div>
<div class="zsg-content-item">
    <ul class="nearby-schools-list">
        <li class="nearby-schools-header">
            <h4 class="nearby-schools-rating">School Rating</h4>
            <div class="nearby-schools-info">
                <h4 class="nearby-schools-name zsg-sm-hide">&nbsp;</h4>
                <h4 class="nearby-schools-grades zsg-sm-hide">Grades</h4>
                <h4 class="nearby-schools-distance zsg-sm-hide">Distance</h4>
            </div>
        </li>

        <li class="nearby-school assigned-school  clearfix"
                >
            <div class="nearby-schools-rating">
                <span class="gs-rating-number gs-rating-10">10</span><div class="zsg-fineprint"> out of 10</div>
            </div>
            <div class="nearby-schools-info">
                <div class="nearby-schools-name">
                    
                        <a href="/renton-wa/schools/cougar-ridge-elementary-school-97806/"
                                class="za-track-event school-name notranslate"
                                data-za-action="School details click"
                                data-za-label="HDP AB Module"
                                data-za-category="Homes"
                                data-za-standard-href="true">Cougar Ridge Elementary</a>
                        
                     <span class="assigned-label zsg-fineprint">(assigned)</span>
                </div>
                <div class="nearby-schools-grades">K-5</div>
                <div class="nearby-schools-distance">0.4 mi</div>
            </div>
        </li>
        <li class="nearby-school assigned-school  clearfix"
                >
            <div class="nearby-schools-rating">
                <span class="gs-rating-number gs-rating-9">9</span><div class="zsg-fineprint"> out of 10</div>
            </div>
            <div class="nearby-schools-info">
                <div class="nearby-schools-name">
                    
                        <a href="/issaquah-wa/schools/issaquah-middle-school-97809/"
                                class="za-track-event school-name notranslate"
                                data-za-action="School details click"
                                data-za-label="HDP AB Module"
                                data-za-category="Homes"
                                data-za-standard-href="true">Issaquah Middle</a>
                        
                     <span class="assigned-label zsg-fineprint">(assigned)</span>
                </div>
                <div class="nearby-schools-grades">6-8</div>
                <div class="nearby-schools-distance">5.9 mi</div>
            </div>
        </li>
        <li class="nearby-school assigned-school  clearfix"
                >
            <div class="nearby-schools-rating">
                <span class="gs-rating-number gs-rating-9">9</span><div class="zsg-fineprint"> out of 10</div>
            </div>
            <div class="nearby-schools-info">
                <div class="nearby-schools-name">
                    
                        <a href="/issaquah-wa/schools/issaquah-high-school-97810/"
                                class="za-track-event school-name notranslate"
                                data-za-action="School details click"
                                data-za-label="HDP AB Module"
                                data-za-category="Homes"
                                data-za-standard-href="true">Issaquah High</a>
                        
                     <span class="assigned-label zsg-fineprint">(assigned)</span>
                </div>
                <div class="nearby-schools-grades">9-12</div>
                <div class="nearby-schools-distance">6.4 mi</div>
            </div>
        </li>
    </ul>
</div>
<p class="attribution">
    Data by <a href="http://www.greatschools.org/" rel="nofollow" target="_blank">GreatSchools.org</a>
        <a class="zsg-tooltip-launch zsg-icon-circle-question" href="#gs-rating-tip"></a>
</p>
<div class="nearby-schools-footer"><a href="/bellevue-wa/schools/" data-za-action="Schools on map click" data-za-category="Homes" class="za-track-event" data-za-label="HDP AB Module"> More schools in <span class="notranslate">Bellevue</span></a></div></section><section data-zmm-component="FooterContactButton" class="zsg-content-section contact-wrapper-wide collapsible_disabled"><div id="contact-wide" class="ajax-form"><div class=" generic-box yui3-widget-stdmod module"><div class="module-body yui3-widget-bd clearfix"><div class="bal-refactor   featured ">  <h2 class="form-title">Contact Agent</h2>    <form id="lead-form_contact-wide" action="https://www.zillow.com/contact/ContactSubmit.htm" class="multi-zuid-select zsg-form validation-above contact-wide" method="get">    <div id="premier-tooltip-contact-wide" class="zsg-tooltip"><p> Premier Agents specialize in this area and can assist you in seeing a home or answer your questions. </p><p> Are you an agent looking for more exposure for yourself or your listings? Call Zillow at <span class="phone">866-324-4005</span></p></div>    <div class="column ">   <div class="signature-refactor has-pal " data-zuid="X1-ZUz2z8gewe87bd_6msnz"><div class="zsg-form-field zsg-form-field_checkbox sig-col ">   <div class="photo sig-col">   <a href="/profile/torij/">  <img alt="Profile picture for Tori Johnson" src="http://photos3.zillowstatic.com/h_n/ISz4zqs412yx7n.jpg" width="60px" height="60px" class="zsg-image-profile"/>   </a>  </div>  </div>      <div class="info flat-star-ratings sig-col">  <span class="snl name notranslate"><a href="/profile/torij/">Tori Johnson</a></span>    <span class="snl lender-rating-large">   <a href="/profile/torij/Reviews/" class="rating"><span class="zsg-rating r500 zsg-rating_500"></span></a>       <span class="reviews">(<a href="/profile/torij/Reviews/">7</a>)</span>   </span>   <span class="snl past-sales">  <a href="/profile/torij/"><span class="sales-count">27</span> Recent sales</a>   </span>    <span class="snl company-name">John L Scott Real Estate</span>      <span class="snl phone">(206) 430-5019 </span>       </div>   <span class='hide agent-type'>Premier Agent</span>    <span class='hide first-name'>Tori</span>   </div>     </div><div class="column ajax-form-content">   <div class="form-input-fields">   <div class="form-input contact-fields zsg-form-field field-name  "><input id="name_contact-wide" type="text" title="Please enter your name." placeholder="Your Name" name="name" required="required" value="Michael Hood" pattern=^[^!@#$%&amp;*+=]+$  ></div>  <div class="form-input contact-fields zsg-form-field field-phone  "><input id="phone_contact-wide" type="tel" title="Please enter a valid phone number, beginning with + for international numbers." placeholder="Phone" name="phone" required="required"   data-intl="true" maxlength="23"></div>  <div class="form-input contact-fields zsg-form-field field-email  "><input id="email_contact-wide" type="email" title="Please enter a valid email address." placeholder="Email" name="email" required="required" value="hoodmichaelallen@gmail.com"   ></div> <div class="form-input zsg-form-field form_textarea">  <textarea id="message_contact-wide" maxlength="500" rows="3" name="message" data-edited="0">I am interested in 16312 SE 48th St, Bellevue, WA 98006.</textarea>  </div></div>   <div class="lender-details form-input show-border lender-details-above">  <div class="form-preferred-lender pal-lender-box hdp-pal"> <div class="pals-tooltip"><a href="#preferred-lender-contact-wide" class="zsg-tooltip-launch zsg-icon-circle-question" data-placement="auto"></a><div id="preferred-lender-contact-wide" class="zsg-tooltip"><h4>What is a Premier Lender?</h4><p> The premier lender and the agent have a financial relationship and pay to advertise on this page. Zillow and the agents do not recommend or endorse any of the premier lenders. For more information on Zillow advertising practices, see Zillow’s Terms of Use &amp; Privacy. <a href="/comarketing/lender/" rel="nofollow" href="@">Learn more here</a></p></div></div> <div class="pal-signature-image">  <a href="/profile/Greg-Legas/"><img alt="Profile picture for Greg Legas" src="http://photos2.zillowstatic.com/h_b/IS9hf8dc28lkqq1000000000.jpg"></a></div><div class="pal-signature-info-list"><div class="preferred-lender-title">Premier Lender</div><div class="pal-lender-name"><a class="name" href="/profile/Greg-Legas/">Greg Legas</a></div><div class="pal-lender-phone">   (253) 431-2651     | NMLS 16690  </div></div></div>   <div class="zsg-form-field zsg-form-field_checkbox "><input id="preapproval-cb-contact-wide" class="preapproval_toggle lender_autocheck " type="checkbox" name="preapproval" value="true"  checked="checked"/><label for="preapproval-cb-contact-wide" id="preapproval-label" class="preapproval-label preapproval " for="preapproval-cb-contact-wide" data-edited="0">I want financing information   </label><div class="preapproval-enabled zsg-fineprint">A Zillow confirmed lender will contact you.</div></div>  </div>    <div class="form-input zsg-form-actions zsg-form-actions_collapsed "><p class="validation-above-messaging zsg-form-error-text"></p>  <button id="lead-form-submit-button_contact-wide" class="contact-submit zsg-button_primary" type="submit">Contact Agent</button>    </div>   </div>  <div class="hide">  <input type="hidden" name="variant" value="featured"/>  <input type="hidden" name="zpid" value="48749340"/>  <input type="hidden" name="mlsCode" value="811989"/>  <input type="hidden" name="onlyPreapprovalContact" value="false"/>  <input type="hidden" name="showNameField" value="true"/>  <input type="hidden" name="showPhoneField" value="true"/>  <input type="hidden" name="showPhoneMandatoryField" value="true"/>  <input type="hidden" name="palZuids" value="{&quot;X1-ZUz2z8gewe87bd_6msnz&quot;:&quot;X1-ZU10dt3ti60cd1l_68qz9&quot;}"/>  <input type="hidden" name="pcm" value="1"/>  <input type="hidden" name="subject" value="2"/>  <input type="hidden" name="pixelId" value="0ccf2066-c3ab-4efa-83be-aa3fb750013e"/>  <input type="hidden" name="formLocationType" value="40"/>  </div>  <div class='preapproval-info hide'><span class='property-value'>679500</span><span class='zipcode'>98006</span><span class='state-abbr'>WA</span></div>    <img height="1" alt="" width="1" class="bal-record" src="http://www.zillow.com/app?record_mechanism=IMG&amp;render_id=0ccf2066-c3ab-4efa-83be-aa3fb750013e&amp;service=adimpressionservice"></img>   </form>   <div class="tips"> <p><span class="zsg-tooltip-launch zsg-link bal-agent-upsell-trigger" data-target-id="bal-agent-upsell-tooltip-40"> Learn how to appear as the agent above </span></p><div class="zsg-tooltip" id="bal-agent-upsell-tooltip-40"> Want to learn more about appearing in the list of agents above? <a href="/feedback/AdvertiserSignup.htm?action=BAL+Popup+-+Inside&source=Agent+Leads&label=Contact+us+here" class="bal-agent-upsell-inside">Contact us here</a> or call us at 
            (855) 840-3292 </div> </div>  <div class="footer lead-form-footer ">   </div>    </div></div></div><div id="contact-wide-response" class="hide post-submit-upsell-response messaging"><div class="yui3-widget-hd"><h4>Contact Successful!</h4></div><div class="yui3-widget-bd"><p class="message"></p><div class="zmm-hdp-upsell-copy success zmm-upsell-msg default-zmm-msg"><div>Are you pre-approved already?</div><p>Find out how much house you can afford and get pre-approved for a mortgage in minutes.</p><ul><li><span class="fne icon"></span><span>Fast &amp; Easy</span></li><li><span class="tnl icon"></span><span>Top-Notch Lenders</span></li><li><span class="sns icon"></span><span>Safe &amp; Secure</span></li></ul><p class="button-wrapper"><a href="/mortgage-rates/" data-za-category="Mortgages" class="get-pre-approved-now button zsg-button_primary za-track-event" data-za-label="HDP:PostAgentContact" data-za-action="Upsell click"> Get Pre-Approved </a></p></div><div class="zmm-hdp-upsell-copy success zmm-upsell-msg pre-approved-zmm-msg lender-upsell-msg"><div>Next: Get Pre-Approved</div><p>A Lender can assist you with pre-approval process and answer any question you have.</p><p class="button-wrapper"><a class="button pre-approval-button zsg-button_primary">Yes, contact me</a></p></div><div class="zmm-hdp-upsell-copy success zmm-upsell-msg agent-lender-confirmation-zmm-msg thanks-pals-msg"><p>A Lender will also be calling you back to assist with pre-approval.</p><p><strong>Thanks for using Zillow!</strong></p></div><div class="zmm-hdp-upsell-copy success zmm-upsell-msg thanks-zmm-msg"><p>We'll send you an email with a link to get pre-approved on Zillow or you can get started by clicking below.</p><p class="button-wrapper"><a href="/mortgage-rates/" data-za-category="Mortgages" class="get-pre-approved-now button zsg-button_primary za-track-event" data-za-label="HDP:PostAgentContact" data-za-action="Upsell click"> Get Pre-Approved </a></p></div><div class="zmm-hdp-upsell-copy success zmm-upsell-msg pals-error-msg"><p>We weren't able to process your pre-approval request. Please go to Zillow Mortgage Marketplace directly by clicking below.</p><p class="button-wrapper"><a href="/mortgage-rates/" data-za-category="Mortgages" class="get-pre-approved-now button zsg-button_primary za-track-event" data-za-label="HDP:PostAgentContact" data-za-action="Upsell click"> Get Pre-Approved </a></p></div></div></div></div></section><section id="listing-provided-by-module" class="zsg-content-section"></section></div><div class="zsg-g_gutterless"><div class="zsg-lg-1-1"><div style="display: none;" data-frame-id="gpt-ad-caccbe30-12e3-488d-ae78-1b829290e91e" id="gpt-ad-caccbe30-12e3-488d-ae78-1b829290e91e-config" class="google-ad-config">{"targetDiv":"gpt-ad-caccbe30-12e3-488d-ae78-1b829290e91e","slot":"zillow/property_details/buy_agent/b_right_p3","network":"7449","sizes":"[300,250]","targets":{"aamgnrc1":"16312 SE 48th St","aamgnrc4":"98006 Somerset Bellevue King WAWashington","bd":"4","aamgnrc3":"WA","fsbid":"10787","city":"Bellevue","proptp":"sfh","vers":"ADS_NavAdInterval:10,ADS_ZipCountThreshold:2","pid":"48749340","zpfc":"yes","lot":"2","residenceType":"9","listtp":"buy_agent","zguidh":"-9188277982520026610","sqftrange":"2000-2499","price":"679500","sqft":"2180","state":"WA","pis":"1","cnty":"King","park":"yes","prange":"600-699k","zip":"98006","mlb":"pr5","z_listing_image_url":"http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg","zusr":"true","zncon":"yes","zc2":"55","zc1":"47","price_band":"z600","zipextension":"4704","zc3":"27","hood":"Somerset","generic":"98006","zcredit":"bad","yrblt":"1980-1989","zestimate":"680819","premieragent":"no","mover":"forsale","zfc":"yes","dma":"206"},"defer_ad":true,"explicit_defer_ad":false}</div><div id="gpt-ad-caccbe30-12e3-488d-ae78-1b829290e91e" class="generic-box ad third-party-ad wide third-party-iframe-ad-container"></div></div></div><div id="hdp-scroll-bottom" style="float:left"></div><div id="home-facts-comparison_src" class="template hide"><!--<div id="home\-facts\-comparison_content" class="dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"><div id="home\-facts\-comparison\-list" class="lightbox\-block current"></div></div></div>--></div><div id="property-subscription-metadata" class="template hide"><!--{ "asyncSubmit": true, "multiEntry" : false, "propertyId" : 48749340, "url": {  "homeValueReport": "http://www.zillow.com/myzillow/UpdateEmailSubscription.htm?csrfToken=0gOw629LJcxdfoBB12ku4jJJaRge_0Fa14Pga54v3OQ&currentlySubscribed=false&subscriptionType=property&zestimateAvailable=true&zpid=48749340", "propertyAlerts" : "http://www.zillow.com/myzillow/UpdateEmailSubscription.htm?csrfToken=0gOw629LJcxdfoBB12ku4jJJaRge_0Fa14Pga54v3OQ&currentlySubscribed=false&subscriptionType=propertyAlerts&zestimateAvailable=true&zpid=48749340",  "similarListings": "http://www.zillow.com/search/CreateSubscriptionRequest.htm?msg=48749340&type=forSaleSimilar&zpid=48749340" } }--></div><div id="property-subscription_src" class="template hide"><!--<div id="property\-subscription_content" class="lightbox\-subscription body\-text property\-subscription dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"><div id="property\-subscription\-confirm" class="lightbox\-block current"><div><h2>Get Zillow Email Alerts:</h2><form method="post" action="/search/ResurrectionSearchPageWithHomeDetail,initialHomeDetailComponent.$search$PropertyReportSubscription.baseSearchForm.sdirect" name="baseSearchForm" id="baseSearchForm">
<div style="display:none;"><input type="hidden" name="formids" value="If_1,If_2,propertyAlertsSubCheckbox,If_3,homeReportSubCheckbox,If_4,If_5,If_6,linkSubmit"/>
<input type="hidden" name="form:search/ResurrectionSearchPageWithHomeDetail" value="..."/>
<input type="hidden" name="reservedids" value="form:search/ResurrectionSearchPageWithHomeDetail"/>
<input type="hidden" name="submitmode" value=""/>
<input type="hidden" name="submitname" value=""/>
<input type="hidden" name="If_1" value="T"/>
<input type="hidden" name="If_2" value="T"/>
<input type="hidden" name="If_3" value="T"/>
<input type="hidden" name="If_4" value="F"/>
<input type="hidden" name="If_5" value="T"/>
<input type="hidden" name="If_6" value="F"/>
</div><dl class="listingoptions clearfix"><div class="zsg\-form\-field zsg\-form\-field_checkbox"><input type="checkbox" name="propertyAlertsSubCheckbox" checked="checked" id="propertyAlertsSubCheckbox" class="checkbox propertyAlerts"/><label for="propertyAlertsSubCheckbox">Get notified when this home's price or status changes</label></div><div class="zsg\-form\-field zsg\-form\-field_checkbox"><input type="checkbox" name="homeReportSubCheckbox" checked="checked" id="homeReportSubCheckbox" class="checkbox homeValueReport"/><label for="homeReportSubCheckbox">Get regular updates on this home and on regional market activity</label></div></dl><ul class="zsg\-button\-group"><li><a href="javascript:Tapestry.submit_form('baseSearchForm', 'linkSubmit');" id="linkSubmit" class="submit zsg\-button_primary">Submit</a></li><li><button class="zsg\-button cancel">Cancel</button></li></ul></form></div></div><div id="property\-subscription\-success" class="lightbox\-block"><div class="success\-thanks hide"><div><h2>Thanks for Signing Up</h2><p class="hr\-and\-simlist hide">You will receive the updates you requested.</p><p class="hr\-only hide"><span class="hr hide">You will now receive a monthly Zillow Home Value Report email about this home.</span><span class="pa hide">You will now receive updates when the listing price or sale status changes for this home.</span><span class="hr\-pa hide">You will receive the updates you requested.</span></p><p class="daily\-simlist\-only hide">You will now receive a daily email about homes listed for sale that are similar to this home.</p><p class="weekly\-simlist\-only hide">You will now receive a weekly email about homes listed for sale that are similar to this home.</p><p class="default\-alerts hide">You will begin receiving email reports filled with data, home values, and trends.</p><div class="must\-login hide"><h2>Just One More Step</h2><p>Please sign in or register (don't worry, it's quick) to complete your email alerts request.</p><button class="submit primary continue"><span>Continue</span></button></div><div class="signin\-error hide"><h2>Error</h2><p>Sorry, but we could not complete your subscription at this time. Please try again later.</p></div><div class="social\-buttons\-block"><span>Share this home:</span><a data\-za\-action="Share on Facebook" rel="nofollow" data\-za\-category="Share" shareUrl="http://u.zillow.com/p3IXvg/" href="javascript: void(0);" title="Share on Facebook" class=" zsg\-icon\-facebook fb_share za\-track\-event" data\-za\-label="HDP Social Upsell"><span>Share on Facebook</span></a><a data\-za\-href="!ignore" data\-share\-message="Check out this 4bd 2.5ba 2180 sqft home at 16312 SE 48th St that I found on #Zillow http://u.zillow.com/p3IXvg/" data\-za\-action="Share on Twitter" rel="nofollow" data\-za\-category="Share" href="#" title="Share on Twitter" class=" zsg\-icon\-twitter share\-on\-twitter za\-track\-event" data\-za\-label="HDP Social Upsell"><span>Tweet this home</span></a><a data\-za\-action="Share on Google Plus" data\-za\-category="Share" href="https://plus.google.com/share?url=http://u.zillow.com/p3IXvg/" class="zsg\-icon\-google\-plus za\-track\-event" data\-za\-label="HDP Social Upsell"><span>Share on Google+</span></a></div></div></div></div><div id="property\-subscription\-failure" class="lightbox\-block"><div><h2>Subscription Sign\-up Failure</h2><p>Sorry, but we could not complete your subscription at this time. Please try again later.</p></div></div></div></div>--></div><div id="agent-contact-preapproval_src" class="template hide"><!--<div id="agent\-contact\-preapproval_content" class="legacy\-lightbox dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix
</a> in <a href="/bellevue-wa/">Bellevue</a> is comparable and for sale for $665,000.  This home is located  in Somerset, Bellevue in  zip code 98006. <a href="/bridle-trails-bellevue-wa/">Bridle Trails</a> and <a href="/crossroads-bellevue-wa/">Crossroads</a> are  nearby neighborhoods.  Nearby ZIP codes include <a href="/bellevue-wa-98008/">98008</a> and <a href="/bellevue-wa-98007/">98007</a>. <a href="/renton-wa/">Renton</a>, <a href="/redmond-wa/">Redmond</a>, and <a href="/issaquah-wa/">Issaquah</a> are nearby cities. </p></div></div></footer></div><footer id="footer" class="search-page-footer zsg-footer"><div class="zsg-footer-nav zsg-separator zsg-separator_narrow"><nav class="zsg-footer-row zsg-footer-linklist-container"><ul class="zsg-list_inline zsg-footer-linklist zsg-fineprint-header" data-za-category="Navigation" data-za-action="Footer"><li><a href="/corp/About.htm" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="About">About</a></li><li><a href="/zestimate/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event" data-za-label="Zestimates">Zestimates</a></li><li><a href="/jobs/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Jobs">Jobs</a></li><li><a href="/help/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Help">Help</a></li><li><a href="/advertise/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Advertise">Advertise</a></li><li><a href="/corp/Terms.htm" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Terms">Terms of use &amp; Privacy</a></li><li><a href="/corp/Privacy.htm#behavioralAdvertising" class="za-track-event zsg-link_primary" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Ad Choice">Ad Choice</a></li><li><div id="teconsent" class="za-track-event zsg-link_primary" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Cookie Preferences"></div></li><li><a href="/blog" class="za-track-event zsg-link_primary" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Blog">Blog</a></li><li><a href="/mobile/" data-za-action="!inherit" data-za-category="!inherit" class="za-track-event zsg-link_primary" data-za-label="Mobile Site">Mobile Apps</a></li></ul><span class="zsg-icon-expando-down zsg-footer-nav-arrow zsg-footer-nav-arrow-open"></span><span class="zsg-icon-expando-up zsg-footer-nav-arrow zsg-footer-nav-arrow-close"></span></nav></div><div class="zsg-footer-copyright zsg-footer-row"><ul class="zsg-list_inline"><li></li><li>&copy; 2006-2015 Zillow</li><li><div class="zsg-footer-follow" data-za-category="Homepage" data-za-action="Social Icon"><span>Follow us</span><a href="http://www.facebook.com/Zillow" target="_blank" class="za-track-event" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Facebook"><span class="zsg-icon-facebook"></span></a><a href="http://twitter.com/zillow" target="_blank" class="za-track-event" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Twitter"><span class="zsg-icon-twitter"></span></a><a href="http://plus.google.com/+Zillow" target="_blank" class="za-track-event" data-za-category="!inherit" data-za-action="!inherit" data-za-label="Google+"><span class="zsg-icon-google-plus"></span></a></div></li></ul></div></footer></div></div><!-- / inner-c-column --></div></div><!-- end c-column --><div id="content"><div data-zmm-page="Search-Bubble" id="map-parent-container" class="map-parent-container"><div id="search-messaging-container" class="hide"><div id="info-message-bar" class="hide map-message"><div class="zsg-notification-bar"><a class="zsg-notification-bar-close" title="Close"><span class="zsg-icon-x-thick"></span></a><div id="info-message-wrapper" class="search-message-bar"><span class="message"></span></div></div></div></div><div id="disabled-map-cover"></div><div id="map-container" class="map-container"><input name="list" id="list" class="hidden" type="hidden"/><input name="spt" id="spt" class="hidden" type="hidden"/><div id="showing-unmapped-message" class="hide map-message"><ul><li><span class="map-info-message-body"><strong>Displaying unmapped homes.</strong>&nbsp;<a id="mapped-result-count" class="zsg-link_darkbg">See mappable homes</a>.</span></li></ul></div><div id="map-rollup-info-message" class="loading hide map-message"><ul><li class="map-info-message-container"><span class="map-info-message-body"><strong>Only showing 500 homes.</strong> Zoom in, or use filters to narrow your search.</span><span class="schools-info-message hide">&nbsp;Zoom in to see schools on the map.</span></li></ul></div><div class="hidden zsg-hide"><div class="map-control-container z-map-button zoom-control"><div class="map-control z-map-button-icon round pair-top" data-value="zoomIn"><div class="zoom-in zsg-icon-plus"></div></div><div class="map-control z-map-button-icon round" data-value="zoomOut"><div class="zoom-out zsg-icon-minus"></div></div></div><div class="map-control-container z-map-button type-control"><div class="map-control z-map-button-icon zsg-menu-launch" data-horizontal-align="right"><div class="map-mode">Map<span class="arrow-down"></span></div></div><div class="map-type-dropdown zsg-menu zsg-menu_shrinkwrap"><ul><li><input id="map-type-automatic" type="radio" value="4" checked="checked"/><label for="map-type-automatic">Automatic</label></li><li><input id="map-type-aerial" type="radio" value="3"/><label for="map-type-aerial">Aerial</label></li><li><input id="map-type-street" type="radio" value="1"/><label for="map-type-street">Street</label></li></ul></div></div><div class="map-control-container z-map-button schools-control"><a href="#" class="map-control z-map-button-icon schools-enable-button square" title="Enable Schools Info" data-value="schoolsEnable"><div class="schools zsg-icon-school"></div></a><div class="school-filter-view-container hide"></div></div><div class="map-control-container z-map-button picasso-control"><a href="#" class="map-control z-map-button-icon square" title="Draw a custom region" data-alttitle="Disable drawn region"><div class="picasso zsg-icon-draw"></div></a></div><div class="map-control-container z-map-button location-control"><a href="#" class="map-control z-map-button-icon commute-enable-button square pair-top" title="Enable Commute Info" data-value="commuteEnable"><div class="commute-enable zsg-icon-car"></div></a><a href="#" class="map-control z-map-button-icon commute-add-button square" title="Drop a new pin" data-value="commuteAdd"><div class="commute-add zsg-icon-car-plus"></div></a></div></div><!-- Picasso Message Bar --><div class="zsg-hide"><div id="picasso-message-bar" class="map-message-bar"><div><strong>Draw a shape</strong> around the region(s) you would like to live in</div><a href="#" class="cancel-btn">Cancel</a><a href="#" class="apply-btn">Apply</a></div></div></div></div></div></div></div><div id="resurrection-page-state" class="template hide"><!--{ "pageStateString":"\\/homes\\/for_sale\\/Bellevue\-Washington\\/48749340_zpid\\/", "mapState": { "boundingRect": { "sw": { "lat": 47.560441000000004, "lon": \-122.122716 }, "ne": { "lat": 47.560443, "lon": \-122.122714 } }, "zoomLevel": 14, "orientation": "MapConstants.Orientation.North", "mapModeType": "MapConstants.MapModeType.Auto", "selectionBoundingRect": null, "mapResultsMode": "MapConstants.MapResultsMode.Default" }, "displayMode":"SearchConstants.DisplayMode.Map", "displayState":{ "displayMode":"SearchConstants.DisplayMode.Map", "sortField": "days" , "zpid": "48749340"  }, "filterState":{ "laundry":"0", "yr":",", "zso":"0", "spt":"homes", "list":"", "sf":",", "bd":",", "pho":"0", "pmf":"1", "ds":"all", "status":"110001", "lt":"111101", "att":"", "days":"any", "red":"0", "mp":",", "pnd":"0", "pr":",", "sort":"days", "ht":"111111", "pets":"0", "ba":",", "lot":",", "pf":"1", "parking":"0" }, "binCounts":{"totalResultCount":15,"forSaleCount":11,"makeMeMoveCount":3,"recentlySoldCount":269,"forRentCount":10,"fsbaCount":9,"fsboCount":0,"foreclosuresCount":0,"bankOwnedCount":0,"foreclos
180,"label":"$680K","isPropertyTypeVacantLand":false,"datasize":9,"title":"$680K","bath":2.5,"flexData":[3,"$10,450","(Sep 2)"]} } , "enrollmentId":"", "sortControl":"<ul id=\\"property\-sort\-control\\" class=\\"zsg\-tabs zsg\-tabs_lg\\"><li class=\\"\\"><a href=\\"\\/homes\\/for_sale\\/featured_sort\\/47.566232657079624,\-122.10983991622925,47.5546487399603,\-122.13558912277222_rect\\/14_zm\\/1_p\\/\\" data\-value=\\"featured\\">Featured<\\/a><\\/li><li class=\\"zsg\-tab_active\\"><a href=\\"\\/homes\\/for_sale\\/47.566232657079624,\-122.10983991622925,47.5546487399603,\-122.13558912277222_rect\\/14_zm\\/1_p\\/\\" data\-value=\\"days\\">Newest<\\/a><\\/li><li class=\\"second\-unselected\\"><a href=\\"\\/homes\\/for_sale\\/priced_sort\\/47.566232657079624,\-122.10983991622925,47.5546487399603,\-122.13558912277222_rect\\/14_zm\\/1_p\\/\\" data\-value=\\"priced\\">Cheapest<\\/a><\\/li><li id=\\"property\-sort\-control\-more\-btn\\" class=\\"hide\\"><a href=\\"#property\-sort\-options\\" class=\\"more\-btn zsg\-menu\-launch\\" data\-horizontal\-align=\\"right\\">More<\\/a><div id=\\"property\-sort\-options\\" class=\\"zsg\-menu\\"><ul class=\\"zsg\-menu\-linklist\\"><li class=\\"second\-unselected\\"><a href=\\"#\\" data\-value=\\"priced\\">Cheapest<\\/a><\\/li><li class=\\"\\"><a href=\\"#\\" data\-value=\\"pricea\\">Price (High to Low)<\\/a><\\/li><li class=\\"\\"><a href=\\"#\\" data\-value=\\"beds\\">Bedrooms<\\/a><\\/li><li class=\\"\\"><a href=\\"#\\" data\-value=\\"baths\\">Bathrooms<\\/a><\\/li><li class=\\"\\"><a href=\\"#\\" data\-value=\\"size\\">Square Feet<\\/a><\\/li><li class=\\"\\"><a href=\\"#\\" data\-value=\\"built\\">Year Built<\\/a><\\/li><li class=\\"\\"><a href=\\"#\\" data\-value=\\"lot\\">Lot Area<\\/a><\\/li><li class=\\"\\"><a href=\\"#\\" data\-value=\\"zest\\">Zestimate (High to Low)<\\/a><\\/li><li class=\\"\\"><a href=\\"#\\" data\-value=\\"zesta\\">Zestimate (Low to High)<\\/a><\\/li><\\/ul><\\/div><\\/li><\\/ul>" }--></div><div id="search-filters" class="zsg-nav-item search-filters"><form name="searchfilters" id="searchfilters" class="zsg-form" action="#"><fieldset class="filter-menu listings-menu"><legend data-za-label="Listing Type"><a class="menu-label" tabIndex="0"><div id="listings-menu-label"> Listing Type <span class="zsg-icon-arrow-menu-down"></span></div></a></legend><div class="filter-pane"><div id="category-entries" class="search-entry category-entries zsg-content-item zsg-separator"><ul class="home-icons"><li id="fs-listings" class="listing-type selected"><div class="listing-category"><input data-menu-label="For Sale" data-icon-class="zsg-icon-for-sale" name="fs-listings-input" id="fs-listings-input" type="checkbox" class="checkbox"></input><label for="fs-listings-input"><span class="zsg-icon-for-sale">&nbsp;</span><span class="listing-type-text">For Sale </span><span id="fs-listings-resultCountWrapper"></span></label></div><ul id="listing-entries" class="listing-entries"><li id="fs-agent" class="selected zsg-form-field"><input name="fs-agent-input" id="fs-agent-input" class="checkbox" type="checkbox"/><label for="fs-agent-input"> By Agent <span id="fs-agent-resultCountWrapper"></span></label></li><li id="fs-owner" class="selected zsg-form-field"><input name="fs-owner-input" id="fs-owner-input" class="checkbox" type="checkbox"/><label for="fs-owner-input"> By Owner <span id="fs-owner-resultCountWrapper"></span></label></li><li id="fs-new" class="selected zsg-form-field"><input name="fs-new-input" id="fs-new-input" class="checkbox" type="checkbox"/><label for="fs-new-input"> New Construction <span id="fs-new-resultCountWrapper"></span></label></li><li id="fs-foreclosures" class="selected zsg-form-field"><input name="fs-foreclosures-input" id="fs-foreclosures-input" class="checkbox" type="checkbox"/><label for="fs-foreclosures-input"> Foreclosures <span id="fs-foreclosures-resultCountWrapper"></span></label><a href="#fore-tip-filters" class="zsg-tooltip-launch zsg-icon-circle-question"></a><div class="zsg-tooltip" id="fore-tip-filters"><p>These properties are currently listed for sale. They are owned by a bank or a lender who took ownership through foreclosure proceedings. These are also known as bank-owned or real estate owned (REO).</p></div></li><li id="fs-comingsoon" class="selected zsg-form-field"><input name="fs-comingsoon-input" id="fs-comingsoon-input" class="checkbox" type="checkbox"/><label for="fs-comingsoon-input"> Coming Soon <span id="fs-comingsoon-resultCountWrapper"></span></label><a href="#coming-soon-tip-filters" class="zsg-tooltip-launch zsg-icon-circle-question"></a><div class="zsg-tooltip" id="coming-soon-tip-filters"><p>Coming Soon listings are homes that will soon be on the market. The listing agent for these homes has added a Coming Soon note to alert buyers in advance. <a href="/help/coming-soon/">Learn more</a>.</p></div></li></ul></li><li id="pm-listings" class="listing-type selected"><div class="listing-category"><input data-menu-label="Potential &lt;span class='ten-fifty-hide' &gt;Listings&lt;/span&gt;" data-icon-class="zsg-icon-pre-market" name="pm-listings-input" id="pm-listings-input" type="checkbox" class="checkbox"></input><label for="pm-listings-input"><span class="zsg-icon-pre-market">&nbsp;</span><span class="listing-type-text">Potential Listings </span><span id="pm-listings-resultCountWrapper"></span></label><a href="#pm-tip-filters" class="zsg-tooltip-launch zsg-icon-circle-question"></a><div class="zsg-tooltip" id="pm-tip-filters"><p>Properties that may be coming to the market soon but are not yet found on a multiple listing service (MLS). They include pre-foreclosures, foreclosed homes and homes with a Make Me Move<sup>&reg;</sup> price. Most of these properties are only found on Zillow.</p></div></div><ul id="pre-market-entries" class="pre-market-entries"><li id="pm-foreclosed" class="selected zsg-form-field"><input name="pm-foreclosed-input" id="pm-foreclosed-input" class="checkbox" type="checkbox"/><label for="pm-foreclosed-input"> Foreclosed <span id="pm-foreclosed-resultCountWrapper"></span></label><a href="#pmf-tip-filters" class="zsg-tooltip-launch zsg-icon-circle-question"></a><div class="zsg-tooltip" id="pmf-tip-filters"><p>These properties are owned by a bank or a lender who took ownership through foreclosure proceedings. They may soon be listed for sale. These properties are not found on a multiple listing service (MLS).</p></div></li><li id="pm-pre-foreclosure" class="selected zsg-form-field"><input name="pm-pre-foreclosure-input" id="pm-pre-foreclosure-input" type="checkbox" class="checkbox"></input><label for="pm-pre-foreclosure-input"> Pre-Foreclosure <span id="pm-pre-foreclosure-resultCountWrapper"></span></label><a href="#pre-foreclosure-tip-filters" class="zsg-tooltip-launch zsg-icon-circle-question"></a><div class="zsg-tooltip" id="pre-foreclosure-tip-filters"><p>The lender initiated foreclosure proceedings on these properties because the owner(s) were in default on their loan obligations. Pre-foreclosures also include properties for which a foreclosure auction is scheduled. These properties are not found on a multiple listing service (MLS).</p></div></li><li id="pm-mmm" class="selected zsg-form-field"><input name="pm-mmm-input" id="pm-mmm-input" type="checkbox" class="checkbox"></input><label for="pm-mmm-input"> Make Me Move <span id="pm-mmm-resultCountWrapper"></span></label><a href="#mmm-tip-filters" class="zsg-tooltip-launch zsg-icon-circle-question"></a><div class="zsg-tooltip" id="mmm-tip-filters"><p>Homes that owner(s) have set a &ldquo;dream price&rdquo; &ndash; a price they'd be willing to sell it for, as well as to test the waters and gauge interest. These properties are only found on Zillow.</p></div></li></ul></li><li id="fr-listings" class="listing-type selected"><div class="listing-category"><input data-menu-label="For Rent" data-icon-class="zsg-icon-for-rent" name="fr-listings-input" id="fr-listings-input" type="checkbox" class="checkbox"></input><label for="fr-listings-input"><span class="zsg-icon-for-rent">&nbsp;</span><span class="listing-type-text">For Rent </span><span id="fr-listings-resultCountWrapper"></span></label></div></li><li id="rs-listings" class="listing-type selected"><div class="listing-category"><input data-menu-label="Recently Sold" data-icon-class="zsg-icon-recently-sold" name="rs-listings-input" id="rs-listings-input" type="checkbox" class="checkbox"></input><label for="rs-listings-input"><span class="zsg-icon-recently-sold">&nbsp;</span><span class="listing-type-text">Recently Sold </span><span id="rs-listings-resultCountWrapper"></span></label></div></li></ul></div><div id="only-entries" class="search-entry only-entries zsg-content-item"><ul><li class="for-sale-entries" id="open-houses"><input name="open-houses-input" id="open-houses-input" class="checkbox" type="checkbox" data-za-label="Open House"/><label for="open-houses-input"><span class="open-houses">Open Houses only</span></label></li><li class="for-sale-entries" id="pending-listings"><input name="pending-listings-input" id="pending-listings-input" class="checkbox" type="checkbox" data-za-label="Pending"/><label for="pending-listings-input"> Include Pending listings </label><a href="#pending-tip-filters" class="zsg-tooltip-launch zsg-icon-circle-question"></a><div class="zsg-tooltip" id="pending-tip-filters"><p>A pending listing means a seller has accepted an offer from a buyer. In some cases, the seller will accept backup offers.</p></div></li></ul></div></div></fieldset><fieldset class="filter-menu affordability-menu price-menu"><legend data-za-label="Price"><a id="price-menu-label" class="menu-label" tabIndex="0"><div> Any Price <span class="zsg-icon-arrow-menu-down"></span></div></a></legend><div class="filter-pane"><div id="price-entries" class="price-entries zsg-separator search-entry"><div class="dualboxes"><div class="box1"><input class="text commaFormat" maxlength="11" size="10" name="price-min" id="price-min" type="text" placeholder="Min"/></div><div class="dash">&nbsp;</div><div class="box2"><input class="text commaFormat" maxlength="11" size="11" name="price-max" id="price-max" type="text" placeholder="Max"/></div></div></div><div id="rent-entries" class="price-entries zsg-separator search-entry hide"><div class="dualboxes"><div class="box1"><input class="text commaFormat" maxlength="11" size="10" name="rental-payment-min" id="rental-payment-min" type="text" placeholder="Min"/></div><div class="dash">&nbsp;</div><div class="box2"><input class="text commaFormat" maxlength="11" size="11" name="rental-payment-max" id="rental-payment-max" type="text" placeholder="Max"/></div></div></div><div class="filter-price"><div id="price-min-options" class="price-options min-price-options custom-dropdown" data-dropdown-id="price-min"><ul class="zf-dropdown-options search-entry zsg-menu-linklist"><li data-value=""><a class="option" tabIndex="0">0</a></li><li data-value="50,000"><a class="option" tabIndex="0">$50,000+</a></li><li data-value="75,000"><a class="option" tabIndex="0">$75,000+</a></li><li data-value="100,000"><a class="option" tabIndex="0">$100,000+</a></li><li data-value="150,000"><a class="option" tabIndex="0">$150,000+</a></li><li data-value="200,000"><a class="option" tabIndex="0">$200,000+</a></li><li data-value="250,000"><a class="option" tabIndex="0">$250,000+</a></li><li data-value="300,000"><a class="option" tabIndex="0">$300,000+</a></li><li data-value="400,000"><a class="option" tabIndex="0">$400,000+</a></li><li data-value="500,000"><a class="option" tabIndex="0">$500,000+</a></li></ul></div><div id="rental-payment-min-options" class="price-options min-price-options custom-dropdown hide" data-dropdown-id="rental-payment-min"><ul class="zf-dropdown-options search-entry zsg-menu-linklist"><li data-value=""><a class="option" tabIndex="0">0</a></li><li data-value="500"><a class="option" tabIndex="0">$500+</a></li><li data-value="750"><a class="option" tabIndex="0">$750+</a></li><li data-value="1,000"><a class="option" tabIndex="0">$1,000+</a></li><li data-value="1,250"><a class="option" tabIndex="0">$1,250+</a></li><li data-value="1,500"><a class="option" tabIndex="0">$1,500+</a></li><li data-value="1,750"><a class="option" tabIndex="0">$1,750+</a></li><li data-value="2,000"><a class="option" tabIndex="0">$2,000+</a></li><li data-value="2,500"><a class="option" tabIndex="0">$2,500+</a></li><li data-value="3,000"><a class="option" tabIndex="0">$3,000+</a></li></ul></div><div id="price-max-options" class="price-options max-price-options custom-dropdown hide" data-dropdown-id="price-max"><ul class="zf-dropdown-options search-entry zsg-menu-linklist"><li data-value="100,000"><a class="option" tabIndex="0">$100,000</a></li><li data-value="200,000"><a class="option" tabIndex="0">$200,000</a></li><li data-value="300,000"><a class="option" tabIndex="0">$300,000</a></li><li data-value="400,000"><a class="option" tabIndex="0">$400,000</a></li><li data-value="500,000"><a class="option" tabIndex="0">$500,000</a></li><li data-value="600,000"><a class="option" tabIndex="0">$600,000</a></li><li data-value="700,000"><a class="option" tabIndex="0">$700,000</a></li><li data-value="800,000"><a class="option" tabIndex="0">$800,000</a></li><li data-value="900,000"><a class="option" tabIndex="0">$900,000</a></li><li data-value=""><a class="option" tabIndex="0">Any Price</a></li></ul></div><div id="rental-payment-max-options" class="price-options max-price-options custom-dropdown hide" data-dropdown-id="rental-payment-max"><ul class="zf-dropdown-options search-entry zsg-menu-linklist"><li data-value="1,000"><a class="option" tabIndex="0">$1,000</a></li><li data-value="1,500"><a class="option" tabIndex="0">$1,500</a></li><li data-value="2,000"><a class="option" tabIndex="0">$2,000</a></li><li data-value="2,500"><a class="option" tabIndex="0">$2,500</a></li><li data-value="3,000"><a class="option" tabIndex="0">$3,000</a></li><li data-value="3,500"><a class="option" tabIndex="0">$3,500</a></li><li data-value="4,000"><a class="option" tabIndex="0">$4,000</a></li><li data-value="4,500"><a class="option" tabIndex="0">$4,500</a></li><li data-value="5,000"><a class="option" tabIndex="0">$5,000</a></li><li data-value=""><a class="option" tabIndex="0">Any Price</a></li></ul></div><div class="saf-entry-link-section"><div class="saf-bottom-entry"><a class="saf-entry-link">How much can I afford?</a></div></div></div><div class="filter-price-affordability hide"><div class="saf-root saf-annual-income"><div class="zsg-form-field saf-annual-income"><label for="saf-annual-income-input">Annual income</label><div class="zsg-input-overlay_left zsg-input-overlay_right"><div class="zsg-input-overlay-text_left">$</div><input id="saf-annual-income-input" type="text" value="70,000"></input><div class="zsg-input-overlay-text_right">/yr</div></div><p class="zsg-form-help-text">Calculate by <a href="#payment" class="saf-mode-link">payment</a></p></div><div class="zsg-form-field saf-monthly-payment"><label for="saf-monthly-payment-input">Maximum payment</label><div class="zsg-input-overlay_left zsg-input-overlay_right"><div class="zsg-input-overlay-text_left">$</div><input id="saf-monthly-payment-input" type="text" value="1,850"></input><div class="zsg-input-overlay-text_right">/mo</div></div><p class="zsg-form-help-text">Calculate by <a href="#income" class="saf-mode-link">income</a></p></div><div class="zsg-form-field"><label for="saf-down-payment-input">Down payment</label><div class="zsg-input-overlay_left"><div class="zsg-input-overlay-text_left">$</div><input id="saf-down-payment-input" type="text" value="20,000"></input></div></div><div class="zsg-form-field saf-annual-income"><label for="saf-monthly-debts-input">Monthly debts</label><div class="zsg-input-overlay_left zsg-input-overlay_right"><div class="zsg-input-overlay-text_left">$</div><input id="saf-monthly-debts-input" type="text" value="250"></input><div class="zsg-input-overlay-text_right">/mo</div></div></div><h4 class="saf-max-price-label zsg-content_collapsed">Your max house price:</h4><h6 class="zsg-h2">$<span class="saf-max-price-value">-</span></h6><ul class="zsg-button-group"><li><a href="#" class="saf-apply zsg-button_primary">Apply</a></li><li><a class="saf-close zsg-button">Cancel</a></li></ul><input type="text" class="saf-rate hide" value="3.737"></input></div><div class="saf-bottom-entry"><h4 class="saf-pre-approval-next zsg-content_collapsed">NEXT STEP</h4><a class="saf-pre-approval-link">Get Pre-Approved on Zillow</a></div><div class="saf-bottom-entry hide"><p class="saf-pre-approval-upsell-header">Getting pre-approved will let your agent know you're serious about buying.</p><button class="saf-pre-approval-link zsg-button_primary">Get Pre-Approved</button></div></div></div></fieldset><fieldset class="filter-menu beds-menu custom-dropdown" data-dropdown-id="beds-select"><legend data-za-label="Beds"><a id="beds-menu-label" class="menu-label" tabIndex="0"><div><span class="options-display" data-za-action="Beds">0+</span> Beds <span class="zsg-icon-arrow-menu-down"></span></div></a></legend><div class="filter-pane"><div id="beds-entries" class="search-entry"><ul id="bed-options" class="bed-options zf-dropdown-options zsg-menu-linklist"><li data-value="0,"><a class="option" tabIndex="0">0+</a></li><li data-value="1,"><a class="option" tabIndex="0">1+</a></li><li data-value="2,"><a class="option" tabIndex="0">2+</a></li><li data-value="3,"><a class="option" tabIndex="0">3+</a></li><li data-value="4,"><a class="option" tabIndex="0">4+</a></li><li data-value="5,"><a class="option" tabIndex="0">5+</a></li><li data-value="6,"><a class="option" tabIndex="0">6+</a></li></ul><select id="beds-select" class="hide"><option value="0,">0+</option><option value="1,">1+</option><option value="2,">2+</option><option value="3,">3+</option><option value="4,">4+</option><option value="5,">5+</option><option value="6,">6+</option></select></div></div></fieldset><fieldset class="filter-menu type-menu hometype-standalone custom-dropdown home-type-dropdown"><legend data-za-label="Home Type"><a id="type-menu-label" class="menu-label" tabIndex="0"><div> Home Type <span id="hometype-count"></span><span class="zsg-icon-arrow-menu-down"></span></div></a></legend><div class="filter-pane home-type-dropdown"><ul class="combobox-options zf-multicheck-dropdown-options hometype-options"><li id="hometype-sf-top-filters" class="hometype-sf selected"><input name="hometype-sf-input" tabIndex="-1" id="hometype-sf-top-filters-input" type="checkbox" class="hometype-sf-input checkbox" data-za-label="SFH"></input><label for="hometype-sf-top-filters-input"><span id="hometype-sf-top-filters-label" class="hometype-sf-label option">Houses</span></label></li><li id="hometype-mf-top-filters" class="hometype-mf selected"><input name="hometype-mf-input" tabIndex="-1" id="hometype-mf-top-filters-input" type="checkbox" class="hometype-mf-input checkbox" data-za-label="MFH"></input><label for="hometype-mf-top-filters-input"><span id="hometype-mf-top-filters-label" class="hometype-mf-label option">Apartments</span></label></li><li id="hometype-condo-top-filters" class="hometype-condo selected"><input name="hometype-condo-input" tabIndex="-1" id="hometype-condo-top-filters-input" type="checkbox" class="hometype-condo-input checkbox" data-za-label="Condo"></input><label for="hometype-condo-top-filters-input"><span id="hometype-condo-top-filters-label" class="hometype-condo-label option">Condos/co-ops</span></label></li><li id="hometype-townhome-top-filters" class="hometype-townhome selected"><input name="hometype-townhome-input" tabIndex="-1" id="hometype-townhome-top-filters-input" type="checkbox" class="hometype-townhome-input checkbox" data-za-label="Townhomes"></input><label for="hometype-townhome-top-filters-input"><span id="hometype-townhome-top-filters-label" class="hometype-townhome-label option">Townhomes</span></label></li><li id="hometype-manufactured-top-filters" class="hometype-manufactured selected"><input name="hometype-manufactured-input" tabIndex="-1" id="hometype-manufactured-top-filters-input" type="checkbox" class="hometype-manufactured-input checkbox" data-za-label="Manu"></input><label for="hometype-manufactured-top-filters-input"><span id="hometype-manufactured-top-filters-label" class="hometype-manufactured-label option">Manufactured</span></label></li><li id="hometype-land-top-filters" class="hometype-land selected"><input name="hometype-land-input" tabIndex="-1" id="hometype-land-top-filters-input" type="checkbox" class="hometype-land-input checkbox" data-za-label="Lot"></input><label for="hometype-land-top-filters-input"><span id="hometype-land-top-filters-label" class="hometype-land-label option">Lots/Land</span></label></li></ul></div></fieldset><fieldset class="filter-menu more-menu"><legend data-za-label="More"><a class="menu-label" tabIndex="0"><div> more <span id="applied-filter-count"></span><span class="zsg-icon-arrow-menu-down"></span></div></a></legend><div class="filter-pane more-filters"><div id="baths-entries" class="search-entry"><div class="title">Baths</div><div id="baths-dropdown" class="combobox custom-dropdown" data-dropdown-id="baths-select" tabIndex="0"><span id="baths-readout" class="options-display" data-za-action="Baths">&nbsp;</span><span class="zsg-icon-arrow-menu-down"></span><ul id="bath-options" class="zf-dropdown-options combobox-options zsg-menu-linklist"><li data-value="0,"><a class="option" tabIndex="-1">0+</a></li><li data-value="1.0,"><a class="option" tabIndex="-1">1+</a></li><li data-value="1.5,"><a class="option" tabIndex="-1">1.5+</a></li><li data-value="2.0,"><a class="option" tabIndex="-1">2+</a></li><li data-value="3.0,"><a class="option" tabIndex="-1">3+</a></li><li data-value="4.0,"><a class="option" tabIndex="-1">4+</a></li><li data-value="5.0,"><a class="option" tabIndex="-1">5+</a></li><li data-value="6.0,"><a class="option" tabIndex="-1">6+</a></li></ul></div><select id="baths-select" class="hide"><option value="0,">0+</option><option value="1.0,">1+</option><option value="1.5,">1.5+</option><option value="2.0,">2+</option><option value="3.0,">3+</option><option value="4.0,">4+</option><option value="5.0,">5+</option><option value="6.0,">6+</option></select></div><div id="sqft-entries" class="search-entry" data-za-label="Square Feet"><div class="title">Square Feet</div><div class="dualboxes"><div class="box1"><input class="text commaFormat" maxlength="11" size="10" name="sqft-min" id="sqft-min" type="text" placeholder="Min"/></div><div class="dash">&nbsp;</div><div class="box2"><input class="text commaFormat" maxlength="11" size="11" name="sqft-max" id="sqft-max" type="text" placeholder="Max"/></div></div></div><div id="lotsize-entries" class="search-entry" data-za-label="Lot Size"><div class="title">Lot Size (sqft)</div><div class="dualboxes"><div class="box1"><input class="text commaFormat" maxlength="11" size="10" name="lot-size-min" id="lot-size-min" type="text" placeholder="Min"/></div><div class="dash">&nbsp;</div><div class="box2"><input class="text commaFormat" maxlength="11" size="11" name="lot-size-max" id="lot-size-max" type="text" placeholder="Max"/></div></div></div><div id="yearbuilt-entries" class="search-entry" data-za-label="Year Built"><div class="title">Year Built</div><div class="dualboxes"><div class="box1"><input class="text" maxlength="4" size="10" name="year-built-min" id="year-built-min" type="text" placeholder="Min"/></div><div class="dash">&nbsp;</div><div class="box2"><input class="text" maxlength="4" size="11" name="year-built-max" id="year-built-max" type="text" placeholder="Max"/></div></div></div><div id="hometype-entries" class="search-entry hometype-original"><div id="hometype-title" class="title">Home type</div><div class="home-type-dropdown combobox custom-dropdown" tabIndex="0" data-za-label="Open"><span id="home-type-readout" class="options-display">&nbsp;</span><div class="dropdown-handle"><span class="zsg-icon-arrow-menu-down"></span></div><ul class="combobox-options zf-multicheck-dropdown-options hometype-options"><li id="hometype-sf-more-filters" class="hometype-sf selected"><input name="hometype-sf-input" tabIndex="-1" id="hometype-sf-more-filters-input" type="checkbox" class="hometype-sf-input checkbox" data-za-label="SFH"></input><label for="hometype-sf-more-filters-input"><span id="hometype-sf-more-filters-label" class="hometype-sf-label option">Houses</span></label></li><li id="hometype-mf-more-filters" class="hometype-mf selected"><input name="hometype-mf-input" tabIndex="-1" id="hometype-mf-more-filters-input" type="checkbox" class="hometype-mf-input checkbox" data-za-label="MFH"></input><label for="hometype-mf-more-filters-input"><span id="hometype-mf-more-filters-label" class="hometype-mf-label option">Apartments</span></label></li><li id="hometype-condo-more-filters" class="hometype-condo selected"><input name="hometype-condo-input" tabIndex="-1" id="hometype-condo-more-filters-input" type="checkbox" class="hometype-condo-input checkbox" data-za-label="Condo"></input><label for="hometype-condo-more-filters-input"><span id="hometype-condo-more-filters-label" class="hometype-condo-label option">Condos/co-ops</span></label></li><li id="hometype-townhome-more-filters" class="hometype-townhome selected"><input name="hometype-townhome-input" tabIndex="-1" id="hometype-townhome-more-filters-input" type="checkbox" class="hometype-townhome-input checkbox" data-za-label="Townhomes"></input><label for="hometype-townhome-more-filters-input"><span id="hometype-townhome-more-filters-label" class="hometype-townhome-label option">Townhomes</span></label></li><li id="hometype-manufactured-more-filters" class="hometype-manufactured selected"><input name="hometype-manufactured-input" tabIndex="-1" id="hometype-manufactured-more-filters-input" type="checkbox" class="hometype-manufactured-input checkbox" data-za-label="Manu"></input><label for="hometype-manufactured-more-filters-input"><span id="hometype-manufactured-more-filters-label" class="hometype-manufactured-label option">Manufactured</span></label></li><li id="hometype-land-more-filters" class="hometype-land selected"><input name="hometype-land-input" tabIndex="-1" id="hometype-land-more-filters-input" type="checkbox" class="hometype-land-input checkbox" data-za-label="Lot"></input><label for="hometype-land-more-filters-input"><span id="hometype-land-more-filters-label" class="hometype-land-label option">Lots/Land</span></label></li></ul></div></div><div id="days-entries" class="search-entry"><div id="days-on-title" class="title">Days on/Sold in last</div><div id="days-dropdown" class="combobox custom-dropdown" data-dropdown-id="days-on-select" tabIndex="0"><span id="days-readout" class="options-display" data-za-action="Days on Zillow">&nbsp;</span><div class="dropdown-handle"><span class="zsg-icon-arrow-menu-down"></span></div><ul id="days-options" class="zf-dropdown-options combobox-options zsg-menu-linklist"><li data-value="any"><a class="option" tabIndex="-1">Any</a></li><li data-value="1"><a class="option" tabIndex="-1">1 day</a></li><li data-value="7"><a class="option" tabIndex="-1">7 days</a></li><li data-value="14"><a class="option" tabIndex="-1">14 days</a></li><li data-value="30"><a class="option" tabIndex="-1">30 days</a></li><li data-value="90"><a class="option" tabIndex="-1">90 days</a></li><li data-value="6m"><a class="option" tabIndex="-1">6 months</a></li><li data-value="12m"><a class="option" tabIndex="-1">12 months</a></li><li data-value="24m"><a class="option" tabIndex="-1">24 months</a></li><li data-value="36m"><a class="option" tabIndex="-1">36 months</a></li></ul></div><select id="days-on-select" class="hide"><option value="any">Any</option><option value="1">1 day</option><option value="7">7 days</option><option value="14">14 days</option><option value="30">30 days</option><option value="90">90 days</option><option value="6m">6 months</option><option value="12m">12 months</option><option value="24m">24 months</option><option value="36m">36 months</option></select></div><div id="attribute-entry" class="search-entry" data-za-label="Keywords"><div class="title">Keywords</div><textarea id="attribute-terms" placeholder="e.g. pool, fireplace"></textarea></div><div id="rental-only-entries" class="search-entry only-entries"><div class="title rent-entries">Show only</div><ul><li class="rent-entries" id="pets-filter"><input name="pets-filter-input" id="pets-filter-input" class="checkbox" type="checkbox" data-za-label="Pets"/><label for="pets-filter-input"><span>Pets Allowed</span></label></li><li class="rent-entries" id="parking-filter"><input name="parking-filter-input" id="parking-filter-input" class="checkbox" type="checkbox" data-za-label="Parking"/><label for="parking-filter-input"><span>On-Site Parking</span></label></li><li class="rent-entries" id="laundry-filter"><input name="laundry-filter-input" id="laundry-filter-input" class="checkbox" type="checkbox" data-za-label="Laundry"/><label for="laundry-filter-input"><span>In-Unit Laundry</span></label></li></ul></div><a class="zsg-button_primary" rel="nofollow" id="filterSearchButton" onclick="return false;" title="Search"><span> Apply </span></a></div><div id="mapped-unmapped-selection" class="zsg-hide"> Show: <select id="data-source-select"><option id="mapped-list-results" value="all">Search results (0)</option><option id="unmapped-list-results" value="unmapped">Unmapped homes (#)</option></select></div></fieldset></form></div><div id="saveSearchLogin_src" class="template hide"><!--<div id="saveSearchLogin_content" class="z\-auth\-social save\-search\-lightbox dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"></div></div>--></div><div id="saveSearchRegister_src" class="template hide"><!--<div id="saveSearchRegister_content" class="z\-auth\-social save\-search\-lightbox dialog clearfix"><a class="close lightbox\-close zsg\-icon\-x\-thin" title="Close" tabindex="\-1"></a><div class="yui3\-widget\-bd lightbox\-body clearfix"></div></div>--></div><div id="map-personalization-test" class="hide"></div></div><span id="bluekai-target" class="hide"></span><script src="http://www.zillowstatic.com/yui/3.18.1/seed-3.18.1.72578fc-concat.js" type="text/javascript"></script><script>
        YUI.GlobalConfig = {"root":"3.18.1/","base":"http://www.zillowstatic.com/yui/3.18.1/","comboBase":"http://www.zillowstatic.com/c/yui?","staticDomain":"http://www.zillowstatic.com/","loggedIn":true,"vstatic":{"domain":"http://www.zillowstatic.com/","combo":"http://www.zillowstatic.com/c/34794f0/lib?","base":"http://www.zillowstatic.com/vstatic/34794f0/static/"},"zsgStatic":{"combo":"http://www.zillowstatic.com/c/static-zsg/13bacaa/lib?","base":"http://www.zillowstatic.com/static-zsg/13bacaa/static-zsg/"},"pagewrapperStatic":{"combo":"http://www.zillowstatic.com/c/static-pagewrapper/51b4137/lib?","base":"http://www.zillowstatic.com/static-pagewrapper/51b4137/static-pagewrapper/"},"mapStatic":{"combo":"http://www.zillowstatic.com/c/static-map/76fb8b8/lib?","base":"http://www.zillowstatic.com/static-map/76fb8b8/static-map/"},"searchStatic":{"combo":"http://www.zillowstatic.com/c/static-search/0f6b122/lib?","base":"http://www.zillowstatic.com/static-search/0f6b122/static-search/"},"hdpStatic":{"combo":"http://www.zillowstatic.com/c/static-hdp/bbaf37f/lib?","base":"http://www.zillowstatic.com/static-hdp/bbaf37f/static-hdp/"},"hiStatic":{"combo":"http://www.zillowstatic.com/c/static-hi/5d3aba3/lib?","base":"http://www.zillowstatic.com/static-hi/5d3aba3/static-hi/"}};
        window.zSDLConfig = {"staticDomain":"http://www.zillowstatic.com/","versions":{"zsgStatic":"static-zsg/13bacaa","pagewrapperStatic":"static-pagewrapper/51b4137","mapStatic":"static-map/76fb8b8","searchStatic":"static-search/0f6b122","hdpStatic":"static-hdp/bbaf37f","hiStatic":"static-hi/5d3aba3","static":"static/34794f0"}};
    </script><script src="http://www.zillowstatic.com/c/config/?vstatic/34794f0/static/js/static-seed-concat.js&amp;static-zsg/13bacaa/static-zsg/js/zsg-seed-concat.js&amp;static-search/0f6b122/static-search/js/search-seed-concat.js&amp;static-map/76fb8b8/static-map/js/map-seed-concat.js&amp;static-hi/5d3aba3/static-hi/js/hi-seed-concat.js&amp;static-hdp/bbaf37f/static-hdp/js/hdp-seed-concat.js&amp;static-pagewrapper/51b4137/static-pagewrapper/js/pagewrapper-seed-concat.js" type="text/javascript"></script><div id="analytics" class="hide"><!-- SiteCatalyst code version: H.22.1 Copyright 1997-2010 Adobe, Inc. More info available at http://www.omniture.com --><noscript><img src="http://b.scorecardresearch.com/b2?c1=2&amp;c2=6036206&amp;c3=&amp;c4=www.zillow.com/homes/48749340_zpid/&amp;c5=&amp;c6=&amp;c15=&amp;cv=1.3&amp;cj=1" alt="" width="0" style="display:none" height="0"></img></noscript></div><script>window.zBodyScripts=(function(){ClientProfiler.profile("body script request start");YUI().use("base-build","event-base","event-custom-base","html5-attr-placeholder","node-base","yui-later","z-managed-base","zillow-auth-required-plugin","zillow-node-methods","zsg-menus",function(d,c){if(c.success!==true){d.message(c.msg,"warn");return}YUI.applyConfig({csrfToken:"0gOw629LJcxdfoBB12ku4jJJaRge_0Fa14Pga54v3OQ"});if(YUI.GlobalConfig.debug){if(YUI.zDebugEvents===undefined){YUI.zDebugEvents={}}if(YUI.GlobalConfig.zonConsole&&d.log){window.zonLogString=window.zonLogString||"Zon Log Start";window.originalLog=d.log;window.zonLog=function(g,f,j,i,h){if(j!=="attribute"&&j!=="base"&&j!=="plugin"){window.zonLogString+="\n";window.zonLogString+=g+", "+f+", "+j+", "+i+", "+h}window.originalLog.call(this,g,f,j,i,h)};d.log=window.zonLog}function a(e){e.zFire=e.fire;e.fire=function(f){YUI.zDebugEvents[f]=(!YUI.zDebugEvents[f]?1:YUI.zDebugEvents[f]+1);e.zFire.apply(this,[].slice.call(arguments))}}a(d.Global);a(d)}ClientProfiler.profile("body script callback start");d.on("domready",function(f){d.use("querystring-parse","z-search-app",function(j){var h="false";var e="48749340";var g="false";if(h==="true"&&e&&g==="true"){j.io("/claiming/PostImplicitClaimPage.htm?implicitClaimType=3&zpid="+e,{on:{success:function(l,k){var m={category:"Claim Home",action:"ImplicitSellHomePage"};j.Z.Analytics.trackEvent(m)}}})}var i={staticConfig:{userMode:"defaultList",mapAddons:{addonsEnabled:true,defaultAddon:"schools",addons:{universities:{resultMgr:"z-universities-result-mgr",resultMgrConfig:{list:[{name:"Bellevue",lon:0,lat:0}]},enabled:false},schools:{resultMgr:"z-schools-result-mgr",paramKeys:["sch","sc"],plugin:"z-plugin-schools-map-addon",defaultState:{sc:[],sch:{lvl:"",rat:1,bnd:"",typ:"",iu:"u"}},maxZoom:20,minZoom:6,fillOrMask:"mask",enabled:true}},activeAddon:""},mapRollupThreshold:500,mapKey:"AmdvKO2hNoyLePakiVzRBZiGPKCxV6MtwWneohoPfmXclTaRTzvT6_Ict5-PBHO6",zoom:11,searchPageTitle:"Real Estate - 15 Homes For Sale  | Zillow",currentRate:3.737},viewsBeforeReload:20,isFirstSearchPageVisit:false};i=j.merge({viewContainer:"#detail-container-column",staticView:"hdp",activeItem:"48749340",isThreeColumnMode:false,activeItemData:{requirements:["z-collapsible-module","z-engagement-analytics","z-sel-metrics-widget","z-tab-content-mgr","zmm-analytics"],requestId:"t7IEA_2ySqqR741PnOxevQ",bodyScript:function(l){if(l.config.requestId&&l.config.requestId!="t7IEA_2ySqqR741PnOxevQ"){return}l.on("priorityUiReady",function(m){l.use("z-google-tag-manager","zillow-lightbox-manager",function(){l.Z.LightboxManager.addComponent({boundingBox:"#hdp-photo-lightbox",cfg:{boardCount:0,blocks:[{boundingBox:"#hdp-photo-lightbox-photos",url:"/AjaxRender.htm?encparams=8~5652835386849183250~ciFP1LZ0u-lR45ICp4IXPbQ8jkso27QnsDK2FJmZ408Z7BbtlH7913_QQR0WBTjTDjcNeBKpwZdpv4J_2DVVo27gwB_LWkRDWvHb2idcY5E2Mj87wvAmwlhHXk8ERFyU7txL5v6p5onoed8dy8bmQAA8J5duFctQMkxmansIgCQopoxx80JaX6uXNfoXniBT&rwebid=15305492&rhost=1"}],plugins:"HdpGalleryLightbox,CarouselSync,DigsGallerySave",zpid:48749340,digsAbTests:{DigsMobileWebDigFromHDP:{CONTROL:true}},zuid:"X1-ZUxmuzyoen0tmx_17jmc",hasUserDug:false,savedElement:"#oneClickfavoriteButton .fm-remove-event",klass:"GalleryLightbox",userBoardsPageUrl:"/digs/hoodmichaelallen-boards/",id:"hdp-photo-lightbox",imageIsVss:true,typeAndPrice:"For Sale: $679,500"},name:"hdp-photo-lightbox",global:false,jsModule:"z-gallery-lightbox",phaseType:"scroll",requires:["z-gallery-lightbox","z-plugin-carousel-sync","z-plugin-digs-gallery-save","z-plugin-hdp-gallery-lightbox"],initializer:"_create"});l.Z.LightboxManager.addComponent({boundingBox:"#home-facts-comparison",cfg:{klass:"LightboxBase",blocks:[{boundingBox:"#home-facts-comparison-list",url:"/AjaxRender.htm?encparams=6~8122490636764697485~2tpJynBuAwsjpr0l7KesJenDx6HqDNrzbxfJUHthRuz5C_oFXBX5oNTFb4V0brCS_liMrpmQSBWDJXHZqcRV1s99IYgAvsPIHKk0MYmKA6nd7jcty_dsDVfK7nYD4Z2zHsVGI2iIb8jTNnR7SvkGNteZx8aonGkrZPmrypz0I5AAMUWoq6ObL8DsqigWobWM&rwebid=15305492&rhost=1"}],plugins:"LightboxScroll",id:"home-facts-comparison"},name:"home-facts-comparison",global:false,jsModule:"zillow-lightbox-base",phaseType:"scroll",requires:["zillow-lightbox-base","zsg-plugin-lightbox-scroll"],initializer:"_create"});l.Z.LightboxManager.addComponent({boundingBox:"#property-subscription",cfg:{klass:"PropertyLightboxSubscription",plugins:"FacebookLike,GooglePlusOne,TwitterTweet",id:"property-subscription"},name:"property-subscription",global:false,jsModule:"zillow-property-lightbox-subscription",phaseType:"scroll",requires:["z-plugin-facebook-like","z-plugin-google-plus-one","z-plugin-twitter-tweet","zillow-property-lightbox-subscription"],initializer:"_create"});l.Z.LightboxManager.addComponent({boundingBox:"#agent-contact-preapproval",cfg:{klass:"LightboxBase",id:"agent-contact-preapproval"},name:"agent-contact-preapproval",global:false,jsModule:"zillow-lightbox-base",phaseType:"scroll",requires:["zillow-lightbox-base"],initializer:"_create"});l.Z.GoogleTagManager.addData({property:{zipcode:"98006",isForSale:true,price:679500,isForeclosure:false,isForRent:false,isRecentlySold:false,isMMM:false},event:"HomeDetailsView"})})});l.after("priorityUiReady",function(m){l.use("z-truste-loader",function(){l.Z.TrusteLoader.init()})});new l.Z.TabContentMgr({boundingBox:"#map-tabs"});var k=l.one("#hdp-content");if(k){k.plug(l.Z.Plugin.CollapsibleModule,{clickArea:".collapsible h2, .collapsible .hdp-collapse-title",targetAncestor:".collapsible",collapsibleToggleClass:"collapsed",trackingCategory:"Homes",trackingLabelSuffix:" - Magic Carpet"})}l.Z.SelMetricsWidget.init();l.applyConfig({veConfig:{baseUrl:"tiles.virtualearth.net/tiles/",hybrid:{prefix:"h",suffix:".jpeg?g=3577&mkt=en-us"},aerial:{prefix:"a",suffix:".jpeg?g=3577&mkt=en-us"},street:{prefix:"r",suffix:".png?g=3577&mkt=en-us&shading=hill&lbl=l1&stl=fb"},oblique:{prefix:"cmd/svhybrid?a=",suffix:"&g=3577&dir=dir_n&n=z"},apiKey:"AmdvKO2hNoyLePakiVzRBZiGPKCxV6MtwWneohoPfmXclTaRTzvT6_Ict5-PBHO6",metadataEnabled:true},mapTileConfig:{hosts:["http://map.zillowstatic.com"],comboHost:"http://vo-map-zillow.elasticbeanstalk.com"}});new l.Z.EngagementAnalytics({pageUrl:"Magic Carpet HDP",subscriptions:[{event:"scrolleventtracker:bottom",category:"Engagement",action:"Scrolled to bottom"}]})},bodyScriptDomReady:function(k){k.on("domready",function(l){k.use("z-comps-price-graph","zillow-link-tracking",function(){k.one("doc").delegate("click",function(m){k.Z.Analytics.trackEvent({category:"Homes",action:"HDP tooltip",label:"Home Summary - Coming Soon"})},"#coming-soon-tooltip");new k.Z.CompsPriceGraph({lowestPrice:553608,priceRange:258884,zpid:48749340,isForRent:false,isMobileApp:false})})})},bodyScriptLoad:function(k){k.on("load",function(l){k.use("ajax-form-wrapper","hdp-chart-loader","z-analytics","z-async-content-mgr","z-complaint-manager-async-block","z-expando-table","z-hdp-async-mortgage-module","z-hdp-auto-quotes-trigger","z-hdp-delight-manager","z-hdp-map-view","z-hdp-other-costs","z-hdp-photo-carousel","z-hdp-price-history","z-moreless","z-plugin-collapse-contact-info","z-plugin-hdp-facts-suite","z-plugin-message","z-scroll-event-tracker","z-toggle-content","zillow-async-block","zillow-async-loader","zillow-hdp-contact-plugin","zillow-hdp-map-loader",function(){var n=new k.Z.AsyncLoader();n.load({boundingBox:"#map-tabs",jsModule:"zillow-async-block",phaseType:"scroll"});n.load({mapMarkerClass:"hdp-map-view-marker-birdseye",boundingBox:"#hdp-map-view-birdseye",disableKeyboardInput:true,latitude:47.560442,mapType:"birdseye",showScalebar:true,zoom:18,jsModule:"z-hdp-map-view",phaseType:"custom",disableZooming:false,customEvent:"tabContentMgr:birdseye",mapMarkerDimension:25,longitude:-122.122715});n.load({mapMarkerClass:"forSale hdp-home-circle hdp-map-view-marker-home",boundingBox:"#hdp-map-view",disableKeyboardInput:true,latitude:47.560442,mapType:"road",showScalebar:false,zoom:14,jsModule:"z-hdp-map-view",phaseType:"custom",disableZooming:false,customEvent:"tabContentMgr:map",mapMarkerDimension:17,longitude:-122.122715});n.load({boundingBox:"#home-image-preview",gaPrefix:"HDP",enableDigsUpsell:false,enableShare:false,jsModule:"z-hdp-photo-carousel",isForRent:false,stripConfig:{imgPerStrip:7,strips:["http://iss.zillowstatic.com/sheet/ZILLOW/p_a_8/NObcqWixGipktvF6jsV_R4tnJT4/ISpximk0uuc31d0000000000/ISxfaulqxk1lvt1000000000/IS9pdc563ixwum1000000000/ISp98i3ktctnvt1000000000/IS1jb0nzy9pzum1000000000/ISh366ldp4lqvt1000000000/IStc9o4tu1h2vm1000000000/IS9x3u27lwctvt1000000000","http://iss.zillowstatic.com/sheet/ZILLOW/p_a_8/g0cRP28UBH0Q2ceh3eu2BSdypg0/IS9x3u27lwctvt1000000000/ISl67cmmqt85vm1000000000/IS1r1ik0ho4wvt1000000000/ISd0504gml08vm1000000000/IStkz52ucgwyvt1000000000/IS5u2ol9idsavm1000000000/ISlextjn88o1wt1000000000/ISxn0c33e5kdvm1000000000","http://iss.zillowstatic.com/sheet/ZILLOW/p_a_8/TLILeyRVu797nHV4kSExdTSInK0/ISxn0c33e5kdvm1000000000/ISd8vh1h40g4wt1000000000/IS99xovc5halir1000000000/IShbwn2q5p3jvm1000000000/IS52t5ja0s77wt1000000000/IS1zrz1dx8novm1000000000/IS1bptgmf5t6xq1000000000/IStkbvpyff72mm1000000000","http://iss.zillowstatic.com/sheet/ZILLOW/p_a_8/Xc8B07TYflhEd7BowtM5fc-bs-s/IStkbvpyff72mm1000000000"]},enableThumbs:true,phaseType:"load",baseFluid:true,enableAdUpsell:true,enableStreetEasyUpsell:false});ZILLOW.AsyncContentMgr.addComponent({boundingBox:"#carousel-img-ad",cfg:{klass:"AsyncBlock",blocks:[{boundingBox:"#carousel-img-ad-upsell",url:"/AjaxRender.htm?encparams=10~8438874730875864030~-EAa0xoDgj8QPOyHWQAqHBgNllX3Il4qLOem4zfZPS4irKiKIHmBsGOKmS80YewhSTVNMd8qAiO_bBTrMz4QrTmC3ipnxx434xkjtFBuuLJdxs92CE1D9EQPnmDKFTgwLNOXK7Ij80oVowSGHG_WsmXdyxjDc-JirrbVcyxTx7SG3dnrRGVcSg==&rwebid=15305492&rhost=1",divId:"carousel-img-ad"}],id:"carousel-img-ad"},customEvent:"carouselAdUpsell:renderUpsell",name:"carousel-img-ad",global:false,jsModule:"zillow-async-block",phaseType:"scroll",requires:["zillow-async-block"],initializer:"_create"});new k.Z.AjaxFormWrapper({id:"contact-tall",jsModule:"zillow-hdp-contact-plugin",pluginList:"HDPContact",fieldAncestorSelector:"li,div.form-input",submitViaIO:true});k.all("#lead-form_contact-tall, #lead-form_contact-wide, #lead-form_contact, #lead-form_contact-mobile-dialog, #lead-form_contact-tablet-mini").plug(k.Z.Plugin.CollapseContactInfo,{target:".contact-edit"});if(k.one("#contact-tall-response")){k.one("#contact-tall-response").plug(k.Z.Plugin.Message,{trackUrl:""})}var m=k.one("#hdp-content");if(m){m.plug(k.Z.Plugin.HDPFactsSuite,{ignoreReorgClassName:""})}k.Z.UI.MoreLess.init({selector:".hdp-facts",toggleEvent:"hdp-facts"});new k.Z.HdpChartLoader({chartDivId:"paparazzi-chart",showForecast:true,collapsedHdp:true,metricMetaData:{"1":{st:"linear",tp:"tenYears",ft:"dollar",vt:"line"},"2":{st:"linear",tp:"tenYears",ft:"percent",vt:"line"},"3":{st:"linear",tp:"year",ft:"dollar",vt:"line"},"4":{st:"linear",tp:"fiveYears",ft:"dollar",vt:"stack"},"5":{st:"linear",tp:"fiveYears",ft:"dollar",vt:"line"},"6":{st:"log",tp:"month",ft:"raw",vt:"line"},"7":{st:"linear",tp:"year",ft:"dollar",vt:"line"},"8":{st:"linear",tp:"year",ft:"dollar",vt:"line"},"9":{st:"linear",tp:"year",ft:"dollar",vt:"line"},index:[1,2,3,4,5,6],"10":{st:"linear",tp:"year",ft:"dollar",vt:"line"}},state:{rt:"6,7,8",size:"standard",mt:1,zpid:48749340},paparazziEnabled:true,jsonRequestUrl:"http://ppz.zillowstatic.com:80/hdp_chart/render.json?v=2&h=qwogczMDE%2BUalcCX8suV%2B5d4P69NX6ciOVEEBsnvbcw%3D",epochs:{tenYears:[1126594800000,1442127600000],month:[1439449200000,1442127600000],year:[1410591600000,1442127600000],fiveYears:[1284361200000,1442127600000],day:[1442041200000,1442127600000]}});n.load({ajaxURL:"/AjaxRender.htm?encparams=1~1664839609729548281~1xVFLllSPwqwJFeGziK5YUqNPY4vgj3c3y4rjakZ4H7eml9PIKxoCgfS6O1KIdv3Fyh9mzJK-vzq_KDjFeFL5xDYJj86I_Mj1WH5mZt12VZE61ep6X5hBHzq5YB575z4OuCufnnlmsnpLHhXJ1Svl3mr4SO0cO03&rwebid=15305492&rhost=1",jsModule:"z-hdp-auto-quotes-trigger",phaseType:"scroll",divId:"hdp-auto-quotes-trigger"});n.load({ajaxURL:"/AjaxRender.htm?encparams=3~3979710813549789790~fX9o1Pia_3-8o5VqJ2YJyGihHQJDdtAe2TT3nNNwNPwyOXfI0coRUsTn9s9IXhfjeQxG4g5DTfRAdl9shfnIZxR9KrctDJgAVMamJiRKVr6LD79Fk4oFnoYoRLvecRskybvpt24teo50RZAc1ped5BpwwLMPZrYn7g2SR-xEPGT70xVfGBmPdsWIWHrqSq6Pxk49YKFwumRn03VMcbMuRvAEuOJK_3q_mH7pJT
ings-forsale").plug(k.Z.Plugin.ToggleContent);k.one("#hdp-listings-forrent").plug(k.Z.Plugin.ToggleContent);k.one("#walkscore-target").delegate("click",function(o){k.Z.Analytics.trackEvent({category:"Homes",action:o.target.getAttribute("data-za-action")})},".zsg-tooltip-launch");new k.Z.AjaxFormWrapper({id:"contact-wide",jsModule:"zillow-hdp-contact-plugin",pluginList:"HDPContact",fieldAncestorSelector:"li,div.form-input",submitViaIO:true});if(k.one("#contact-wide-response")){k.one("#contact-wide-response").plug(k.Z.Plugin.Message,{trackUrl:""})}n.load({ajaxURL:"/AjaxRender.htm?encparams=6~7621612589617052610~_ku_-PPUgMBo-VidBFU3yU1UWRC4v8rxhxK2uROWX--qYSdfrV7DfdMlSrujnMcWDjVl6OLYZezomGclHYJB-FYxElNWzYCAqOtFjrq-nCkncjlQiuqer6_dwFhfFmYO9-5xLPUwxhPSj4i2tk3J3LwEKtYsC7Cae8YTPPdXiSWpJr-r4_124jNvXKwUzsJT&rwebid=15305492&rhost=1",jsModule:"z-complaint-manager-async-block",phaseType:"scroll",divId:"listing-provided-by-module"});n.load({ajaxURL:"/AjaxRender.htm?encparams=4~7864409830261631287~ZKiHIMQyQEICKE7scz2xczBJcoWrIy0E0hNsLQnjUdqxPCO87RmT52ZTov_2UPkpxaBalLf9NLv9mUUn1xewQV30SU-4i_g_sQ_9i9pSrIYiF1X9ACpWLue9U9Vwh5eVR1hBougho2yyZwHx9H1iZma61CeD1N8JZlEDOqtZMvCCITEZ-cSnqISrgr8-9sOGotoNfUYxTl8fU2Mf8Q_06A==&rwebid=15305492&rhost=1",jsModule:"z-scroll-event-tracker",phaseType:"scroll",divId:"hdp-scroll-bottom",notificationEvent:"scrolleventtracker:bottom"});new k.Z.HDPDelightManager()})});k.after("load",function(l){k.use("event-base","hdp-mortgage-calc","node-base","tooltip-launcher","z-facebook-share","z-plugin-list-drawer","z-twitter-share","zsg-tooltips",function(){k.ZSG.Tooltips.init();new k.Z.HDP.HdpHeaderLoanCalculator({boundingBox:"#loan-calculator-container"});k.Z.TooltipLauncher.init();k.Z.FacebookShare.create().render();k.Z.TwitterShare.create().render();k.all(".zsg-subfooter .list-drawer").plug(k.Z.Plugin.ListDrawer);(function(){var m=k.one(".zsg-footer-nav");if(m){m.all(".zsg-footer-nav-arrow").on("click",function(n){m.toggleClass("zsg-footer-nav_open")})}})()})})}},},i);j.Z.SearchApp.create(i);if(!("placeholder" in document.createElement("input"))){j.use("html5-attr-placeholder",function(){j.Plugin.AttrPlaceholder.loadAll()})}})});d.on("load",function(f){d.use("hdp-action-bar","z-analytics","z-plugin-collapse-contact-info","zillow-link-tracking",function(e){e.all("#lead-form_contact-tall, #lead-form_contact-wide, #lead-form_contact, #lead-form_contact-mobile-dialog, #lead-form_contact-tablet-mini").plug(e.Z.Plugin.CollapseContactInfo,{target:".contact-edit"});new e.Z.HDP.ActionBar();e.Z.Analytics.init({isWebView:false,platform:"OSX"})})});d.on("priorityUiReady",function(f){d.use("z-google-tag-manager","z-plugin-list-drawer","z-top-nav","zillow-lightbox-manager",function(h){var g=h.one(".nav-top_temp"),e=h.one(".nav-top_full");if(g&&e){g.replace(e)}(function(){var i;i=h.one("body").hasClass("pinnable-header_enabled");new h.Z.TopNav({priorityInitEvent:"priorityUiReady",preventScrollBubbling:i,wideNavCapable:true,fetchUserNav:true})})();h.all(".list-drawer").plug(h.Z.Plugin.ListDrawer);h.Z.LightboxManager.addComponent({boundingBox:"#contact-lightbox",cfg:{fieldAncestorSelector:"li,div.form-input",klass:"AjaxFormLightbox",plugins:"HDPContact",id:"contact-lightbox"},name:"contact-lightbox",global:false,jsModule:"zillow-ajax-form-lightbox",phaseType:"scroll",requires:["zillow-ajax-form-lightbox","zillow-hdp-contact-plugin"],initializer:"_create"});h.Z.LightboxManager.addComponent({boundingBox:"#add-note-code",cfg:{klass:"LightboxBase",id:"add-note-code"},name:"add-note-code",global:false,jsModule:"zillow-lightbox-base",phaseType:"scroll",requires:["zillow-lightbox-base"],initializer:"_create"});h.Z.LightboxManager.addComponent({boundingBox:"#send-to-friend-lightbox",cfg:{klass:"EmailAFriendMgr",plugins:"FacebookShare,TwitterShare,GooglePlusOne",defaultMessage:"Check out this home I found on Zillow.",id:"send-to-friend-lightbox",captchaPublicKey:"6Lf2nvMSAAAAAMQ5p6WlAfDEixMdOQgJsij-3_ud"},name:"send-to-friend-lightbox",global:false,jsModule:"z-email-a-friend-mgr",phaseType:"scroll",requires:["z-email-a-friend-mgr","z-plugin-facebook-share","z-plugin-google-plus-one","z-plugin-twitter-share"],initializer:"_create"});h.Z.LightboxManager.addComponent({boundingBox:"#agent-claim-box",cfg:{klass:"LightboxBase",id:"agent-claim-box"},name:"agent-claim-box",global:false,jsModule:"zillow-lightbox-base",phaseType:"scroll",requires:["zillow-lightbox-base"],initializer:"_create"});h.Z.GoogleTagManager.addData({event:"SearchPageView"});h.Z.LightboxManager.addComponent({boundingBox:"#saveSearchLogin",cfg:{klass:"InlineAuthLightbox",id:"saveSearchLogin",url:"/user/account/SaveSearchLogin.htm"},name:"saveSearchLogin",global:true,jsModule:"zillow-inline-auth-lightbox",phaseType:"scroll",requires:["zillow-inline-auth-lightbox"],initializer:"_create"});h.Z.LightboxManager.addComponent({boundingBox:"#saveSearchRegister",cfg:{klass:"InlineAuthLightbox",id:"saveSearchRegister",url:"/user/account/SaveSearchRegister.htm"},name:"saveSearchRegister",global:true,jsModule:"zillow-inline-auth-lightbox",phaseType:"scroll",requires:["zillow-inline-auth-lightbox"],initializer:"_create"})})});d.once("FilterManager:applyFilterState",function(f){d.use("z-search-exposed-filter-control","z-search-exposed-filter-linktrack",function(g){var e=g.one("#search-filters");if(e!==null){e.plug(g.Z.SearchExposedFilterControl);new g.Z.SearchExposedFilterLinktrack({filterNode:e,trackingActive:true})}})});d.once("priorityUiReady",function(f){d.use("autocomplete","jsonp","z-expand-async","z-scroll-image-loader","z-search-autocomplete","zillow-search-main",function(g){var e=new g.Z.AutoComplete({showCurrentLocation:false,showRecentSearches:true,showRegionAutocomplete:true,showAddressAutocomplete:true,resultListLocator:"names",resultHighlighter:"phraseMatch",activateFirstItem:false,maxResults:3,minQueryLength:3,centroid:{Latitude:47.56044069851996,Longitude:-122.12271451950073},region_autocomplete_source_url:"http://ac.zillowstatic.com/",address_autocomplete_source_url:"http://aac.zillowstatic.com/",inputNodeSelector:"#citystatezip",afterSelect:g.bind(g.Z.SearchMain.searchGo,g.Z.SearchMain),pageName:"search/ResurrectionSearchPageWithHomeDetail"});e.setACStyle("zIndex",99);e.setACStyle("textAlign","left");g.Z.SearchMain.setPageName("search/ResurrectionSearchPageWithHomeDetail");g.Z.ExpandAsync.init({rootSelector:"#container"});g.Z.ScrollImageLoader.init()})});d.after("load",function(f){d.use("event-base","favorite-manager","node-base","node-event-delegate","z-analytics","z-facebook-share","z-map-list-side-by-side","z-twitter-share","zsg-menus","zsg-tooltips",function(l){l.ZSG.Tooltips.init();var g=l.one("#add-note-btn");if(g){g.on("managedTeardown|click",l.Z.FavoriteManager.resetFormFields)}l.Z.FacebookShare.create().render();l.Z.TwitterShare.create().render();l.ZSG.Menus.init();function k(h){h.preventDefault();h.currentTarget.ancestor().addClass("show-all")}var j=l.one("#nearby-results");if(j){j.delegate("click",k,".show-more")}(function(){var h=l.one(".zsg-footer-nav");if(h){h.all(".zsg-footer-nav-arrow").on("click",function(m){h.toggleClass("zsg-footer-nav_open")})}})();l.Global.onceAfter("searchMain:initializePage",function(){l.Z.MapListSideBySide.init("5956A46F30CEA3B016C1147B2268D2B5")});var e=window.innerWidth||document.documentElement.clientWidth||document.body.clientWidth;var i=window.innerHeight||document.documentElement.clientHeight||document.body.clientHeight;l.Z.Analytics.setCustomVar({index:20,name:"BrowserSize",value:e+"x"+i})})});d.after("priorityUiReady",function(f){d.use("event-custom","event-delegate","event-mouseenter","favorite-manager","node-base","node-core","z-bluekai-reporter","z-building-list","z-building-search-list","z-google-gpt-loader","z-google-tag-manager","z-hidden-property-manager","z-plugin-comma-format","z-search-affordability-filter-exposed","z-search-analytics-log-sender","z-search-map-upsells","z-truste-loader","zsg-responsive-subnav","zsg-tooltips",function(k){k.Global.on("Marketing:TrackedEvent",function(o){var m=o.marketingEventName,n=o.marketingData;if(n){k.Z.GoogleTagManager.addData(n)}if(m){k.Z.GoogleTagManager.addEvent(m,o.marketingParams)}});k.Z.GoogleTagManager.load({isTablet:false,isPhone:false,isMobile:false,isMobileApp:false});k.Z.TrusteLoader.init();new k.Z.BuildingSearchList({isSEOListEnabled:false});var j=k.one("#search-filters");if(j!==null){j.plug(k.Z.SearchAffordabilityFilterExposed)}k.Z.SearchMapUpsells.init();k.Z.Plugin.CommaFormat.plugAll();k.ZSG.Tooltips.init();k.io("/search/SavedSearchLightboxContent.htm",{on:{success:function(o,m,n){k.one("body").append(m.responseText);k.Z.LightboxManager.addLightbox("saved-search-lightbox",{contentBox:"#saved-search-lightbox-content",klass:"UssSaveSearchLightbox"},["z-uss-save-search-lightbox"])}}});var e="false";if(e==="true"){var i={category:"Claim Home",action:"ImplicitSingleAddress"};k.Z.Analytics.trackEvent(i)}k.fire("searchAnalytics:sync");var h={};h.aamgnrc1="16312 SE 48th St";h.aamgnrc4="98006 Somerset Bellevue King WAWashington";h.bd="4";h.aamgnrc3="WA";h.fsbid="10787";h.city="Bellevue";h.proptp="sfh";h.vers="ADS_NavAdInterval:10,ADS_ZipCountThreshold:2";h.pid="48749340";h.zpfc="yes";h.lot="2";h.residenceType="9";h.listtp="buy_agent";h.zguidh="-9188277982520026610";h.sqftrange="2000-2499";h.price="679500";h.sqft="2180";h.state="WA";h.pis="1";h.cnty="King";h.park="yes";h.prange="600-699k";h.zip="98006";h.mlb="pr5";h.z_listing_image_url="http://photos1.zillowstatic.com/p_d/ISpximk0uuc31d0000000000.jpg";h.zusr="true";h.zncon="yes";h.zc2="55";h.zc1="47";h.price_band="z600";h.zipextension="4704";h.zc3="27";h.hood="Somerset";h.generic="98006";h.zcredit="bad";h.yrblt="1980-1989";h.zestimate="680819";h.premieragent="no";h.mover="forsale";h.zfc="yes";h.dma="206";var l=new k.Z.BluekaiReporter({javascriptUrl:"//tags.bkrtx.com/js/bk-coretag.js",bluekaiData:h,siteId:"5837",maxPixels:"6"});l.sendData();new k.ZSG.ResponsiveSubnav();k.Z.GoogleGptLoader.init();var g=k.one("#delay-load-zsg");if(g){g.setAttribute("href",g.getAttribute("data-delay-href"))}})});d.config.loggedIn=true;d.UA.zMobile=false;var b=d.Base.create("getUpdatesAuthRequire",d.Base,[d.Z.ManagedBase],{_nodes:null,initializer:function(){this._nodes=d.all(".hdp-menu-get-updates");this._nodes.plug(d.Z.Plugin.AuthRequired,{invoker:"click",preventLightbox:true,lightboxId:"login",lightboxAttributes:{authProcess:"hdp-get-updates"},enableReloadOnSuccess:true})},destructor:function(){if(this._nodes){this._nodes.unplug(d.Z.Plugin.AuthRequired)}this._nodes=null}});new b();d.on("domready",d.Plugin.AttrPlaceholder.loadAll);d.ZSG.Menus.init();d.applyConfig({veConfig:{baseUrl:"tiles.virtualearth.net/tiles/",hybrid:{prefix:"h",suffix:".jpeg?g=3577&mkt=en-us"},aerial:{prefix:"a",suffix:".jpeg?g=3577&mkt=en-us"},street:{prefix:"r",suffix:".png?g=3577&mkt=en-us&shading=hill&lbl=l1&stl=fb"},oblique:{prefix:"cmd/svhybrid?a=",suffix:"&g=3577&dir=dir_n&n=z"},apiKey:"AmdvKO2hNoyLePakiVzRBZiGPKCxV6MtwWneohoPfmXclTaRTzvT6_Ict5-PBHO6",metadataEnabled:true},mapTileConfig:{hosts:["http://map.zillowstatic.com"],comboHost:"http://vo-map-zillow.elasticbeanstalk.com"}});d.applyConfig({searchAppMode:"slidingSearchColumn"});d.applyConfig({womboCombo:false});d.applyConfig({commuteEnabled:false});ClientProfiler.profile("body script callback end")});ClientProfiler.profile("body script request end")});window.zBodyScripts();</script><script>(function(){var m="add_",p="handler",j=p+"s",c="_"+p,a=m+p,f="invalid_field"+c,x="find",l="form",s="abort",i="value",b="events",e="cancel",r=e+"_"+j,g="on",y="submit",w=g+y,o="pre"+y,q="post"+y,t=y+"mode",h=y+"name",u="refresh",n="reset",z="";var k={FORM_NOT_FOUND:{},default_invalid_field_handler:function(B,C,A){if(!B[s]&&!C.disabled){this.set_focus(C);window.alert(A);B[s]=true;B[r]=true}},find:function(A){return document.getElementById(A)},register_form:function(B){var A=this[x](B);if(!A){this.FORM_NOT_FOUND[B]=true;return}A[b]=new d(A)},onpresubmit:function(C,A){var B=this[x](C);B[b][m+o+c](A)},onsubmit:function(B,A){this[x](B)[b][m+y+c](A)},onpostsubmit:function(B,A){this[x](B)[b][m+q+c](A)},onreset:function(B,A){this[x](B)[b][m+n+c](A)},onrefresh:function(B,A){this[x](B)[b][m+u+c](A)},oncancel:function(B,A){this[x](B)[b][m+e+c](A)},set_focus:function(A){if(typeof A==="string"){A=this[x](A);if(A){if(!A.disabled&&A.style.visibility!=="hidden"&&A.style.display!=="none"&&A.clientWidth>0){if(A.focus){A.focus()}if(A.isContentEditable||A.isContentEditable===undefined){if(A.select){A.select()}}}}}},trim_field_value:function(A){var B=this[x](A);B[i]=B[i].replace(/^\s+/g,"").replace(/\s+$/g,"")},require_field:function(C,A,B){var D=this[x](A);if(D[i].length===0){C.invalid_field(D,B)}},submit_form:function(A,B){this[x](A)[b][y](B)}};function v(C,B,A){this[l]=C;this.type=B;this[s]=false;this[r]=false;this[f]=A}v.prototype={invalid_field:function(B,A){this[f].call(k,this,B,A)},toString:function(){return"FormSubmitEvent["+this[l].name+" "+this.type+" "+this[s]+"]"}};function d(A){var B=this;B[l]=A;B.handlers={};A.onsubmit=function(){return A[b].onsubmit_handler()};A.onreset=function(){return A[b].onreset_handler()};B[f]=k.default_invalid_field_handler}d.prototype={add_handler:function(B,A){var C=this.handlers[B];if(!C){C=[];this.handlers[B]=C}C.push(A)},invoke_handlers:function(B,D){if(D[r]){return}var E=this.handlers[B];if(!E){return}var C=E.length,A=0;for(;A<C;A++){E[A].call(window,D);if(D[r]){return}}},add_cancel_handler:function(A){this[a](e,A)},cancel:function(){var C=this,B=C[l],A=new v(B,e,C[f]);C.invoke_handlers(e,A);if(A[s]===false){B[t][i]=e;B[w]=null;B[y]()}},add_presubmit_handler:function(A){this[a](o,A)},add_submit_handler:function(A){this[a](y,A)},add_postsubmit_handler:function(A){this[a](q,A)},submit:function(A){var C=this,B=C[l];if(C.onsubmit_handler()){B[w]=null;B[h][i]=A;B[y]()}},onsubmit_handler:function(){var C=this,B=C[l],A=new v(B,y,C[f]);C.invoke_handlers(o,A);C.invoke_handlers(y,A);C.invoke_handlers(q,A);if(A[s]){return false}B[t][i]=y;B[h][i]=z;return true},add_refresh_handler:function(A){this[a](y,A);this[a](u,A)},refresh:function(A){var D=this,C=D[l],B=new v(C,u,D[f]);D.invoke_handlers(u,B);if(B[s]){return}C[t][i]=u;C[h][i]=A;C[w]=null;C[y]()},add_reset_handler:function(A){this[a](n,A)},onreset_handler:function(){var B=this,A=new v(B[l],n,B[f]);B.invoke_handlers(n,A);return !A[s]}};this.Tapestry=k}());</script><script language="JavaScript" type="text/javascript"><!--
Tapestry.register_form('baseSearchForm');
if(!window.ZMOB_nativeAPI||(window.ZMOB_nativeAPI&&!window.ZMOB_nativeAPI.trackWebviewEvent)){(function(){if(window.console&&window.console.log){window.console.log("Skipping GA initialization since we now use Universal Analytics exclusively.")}window._gaq=window._gaq||[];window._gaqBackup=window._gaqBackup||[];window._gaq.push(["_setAccount","UA-21174015-1"]);window._gaq.push(["_setDomainName",".zillow.com"]);window._gaqBackup=[["_setCustomVar",6,"Zip","98006"],["_setCustomVar",15,"Listing Type","For Sale (Broker)"],["_setCustomVar",8,"Address","16312 SE 48th St"],["_setCustomVar",22,"AccountCreationDate","2015-08-25",1],["_setCustomVar",14,"HDP Type","ForSale"],["_setCustomVar",1,"Guid","228b290229f240f795444faef9f09c9f/X1-ZUxmuzyoen0tmx_17jmc",1],["_setCustomVar",5,"City","Bellevue"],["_setCustomVar",7,"Neighborhood","Somerset"],["_setCustomVar",25,"Device Type","Desktop"],["_setCustomVar",99,"SearchListResultCount","4"],["_setCustomVar",3,"State","WA"],["_setCustomVar",10,"Price","$679,500"],["_setCustomVar",23,"SearchTypes","ForSale,MakeMeMove,PreMarket",2],["_setCustomVar",12,"UserType","Consumer",2],["_setCustomVar",2,"House ID / Zpid","48749340"],["_setCustomVar",4,"County","King"],["_setCustomVar",24,"ListingFeatureType","featured"],["_setCustomVar",40,"A/B Test 15","ADS_ZipCountThreshold.2",1],["_setCustomVar",50,"A/B Test 10","SHO_MAGIC_CARPET_SEO.HOTEL_CALIFORNIA",1],["_setCustomVar",36,"A/B Test 11","ADS_PALSCTA.WantFinancingInfo",1],["_setCustomVar",38,"A/B Test 13","ADS_BAL_MMM.CONTROL",1],["_setCustomVar",27,"TrackingContactModule","featured\\HDP:-Hotel-California-Mini\\21211\\2\\000\\1"],["_setCustomVar",26,"BrokerId","10787"],["_setCustomVar",18,"SearchScenario","Address"],["_setCustomVar",49,"A/B Test 9","ADS_ForeclosureHeader.ForeclosureAgent",1],["_setCustomVar",46,"A/B Test 6","MarketingPulse.CONTROL",1],["_setCustomVar",45,"A/B Test 5","RICH_HDP_ShowBuildingPermits.OFF_CONTROL",1],["_setCustomVar",48,"A/B Test 8","SELAgentButton.Estimate",1],["_setCustomVar",47,"A/B Test 7","ADS_OpaqueBAL.ON",1],["_setCustomVar",42,"A/B Test 2","SHO_DECLUTTER_DISAMBIG.CONTROL",1],["_setCustomVar",9,"PropertyType","Single Family"],["_setCustomVar",41,"A/B Test 1","MarketingMobileAppUpsellBanner.ONE_BUTTON_STYLE",1],["_setCustomVar",44,"A/B Test 4","TrafficHDPHomevalues.CONTROL",1],["_setCustomVar",43,"A/B Test 3","MarketingSegmentedHomepage.CONTROL",1],["_trackPageview","/homes/48749340_zpid/"],["_trackEvent","Search","AbExposureSHO_SEARCH_COOKIE_PERSISTENCE","CONTROL"],["_trackEvent","Search","AbExposureSHO_MAGIC_CARPET_SEO","HOTEL_CALIFORNIA"]];window._gaq.push.apply(window._gaq,window._gaqBackup)})();(function(d,e,j,h,f,c,b){d.GoogleAnalyticsObject=f;d[f]=d[f]||function(){(d[f].q=d[f].q||[]).push(arguments)},d[f].l=1*new Date();c=e.createElement(j),b=e.getElementsByTagName(j)[0];c.async=1;c.src=h;b.parentNode.insertBefore(c,b)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create","UA-21174015-56","auto");window.optimizely=window.optimizely||[];window.optimizely.push("activateUniversalAnalytics");ga("set",{dimension10:"$679,500",dimension12:"Consumer",dimension99:"4",dimension50:"SHO_MAGIC_CARPET_SEO.HOTEL_CALIFORNIA",dimension18:"Address",dimension14:"ForSale",dimension36:"ADS_PALSCTA.WantFinancingInfo",dimension38:"ADS_BAL_MMM.CONTROL",dimension15:"For Sale (Broker)",dimension8:"16312 SE 48th St",dimension9:"Single Family",dimension6:"98006",dimension7:"Somerset",dimension43:"MarketingSegmentedHomepage.CONTROL",dimension42:"SHO_DECLUTTER_DISAMBIG.CONTROL",dimension23:"ForSale,MakeMeMove,PreMarket",dimension45:"RICH_HDP_ShowBuildingPermits.OFF_CONTROL",dimension22:"2015-08-25",dimension44:"TrafficHDPHomevalues.CONTROL",dimension41:"MarketingMobileAppUpsellBanner.ONE_BUTTON_STYLE",dimension40:"ADS_ZipCountThreshold.2",dimension1:"228b290229f240f795444faef9f09c9f/X1-ZUxmuzyoen0tmx_17jmc",dimension25:"Desktop",dimension4:"King",dimension47:"ADS_OpaqueBAL.ON",dimension5:"Bellevue",dimension24:"featured",dimension46:"MarketingPulse.CONTROL",dimension2:"48749340",dimension27:"featured\\HDP:-Hotel-California-Mini\\21211\\2\\000\\1",dimension49:"ADS_ForeclosureHeader.ForeclosureAgent",dimension3:"WA",dimension26:"10787",dimension48:"SELAgentButton.Estimate"});ga("send","pageview","/homes/48749340_zpid/");ga("send",{hitType:"event",eventCategory:"Search",eventAction:"AbExposureSHO_SEARCH_COOKIE_PERSISTENCE",eventLabel:"CONTROL"});ga("send",{hitType:"event",eventCategory:"Search",eventAction:"AbExposureSHO_MAGIC_CARPET_SEO",eventLabel:"HOTEL_CALIFORNIA"})};
var _comscore=_comscore||[];_comscore.push({c1:2,c2:"6036206",c3:"",c4:"www.zillow.com/homes/48749340_zpid/",c5:"",c6:"",c15:""});var _comscoreBackup=_comscoreBackup||[];_comscoreBackup.push.apply(_comscoreBackup,_comscore);setTimeout(function(){var b=document.createElement("script");b.type="text/javascript";b.setAttribute("async",true);b.src=(document.location.protocol=="https:"?"https://sb":"http://b")+".scorecardresearch.com/beacon.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(b,a)},100);

// --></script></body>
</html><!-- H:056  T:197ms  S:287189  R:Sun Sep 13 22:01:12 PDT 2015  B:4.0.19615-release_20150908-endor.2fa5797~candidate.358c83d -->
'''

# %%
soup = BS(h, 'html.parser')

# %%
for thing in soup.find_all('p'):
    try:
        print thing['itemscope']
    except:
        continue
